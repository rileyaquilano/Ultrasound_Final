# %% [markdown]
# <a href="https://colab.research.google.com/github/Pankaj1357/HC18-Grand-Challenge/blob/master/HC18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import os
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # **Mask Generation**
# Done only once and replaced that  annotation with masks permanently
# Did not changed the annotation file name though

# %% [markdown]
# ## **Warning!!!**
# Do not run below cells as task is already completed

# %%
train_pixel_file = pd.read_csv('training_set_pixel_size_and_HC.csv')
train_pixel_file.head()
# This Dataframe will be used to extract image names hence by doing image_name + '_Annotation' we will get annotation names
# Out:
#      filename  pixel size(mm)  head circumference (mm)
# 0  000_HC.png        0.069136                    44.30
# 1  001_HC.png        0.089659                    56.81
# 2  002_HC.png        0.062033                    68.75
# 3  003_HC.png        0.091291                    69.00
# 4  004_HC.png        0.061240                    59.81

# %%
# This function takes annotation and spits out corresponding mask
def masking(image):
    imgray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(imgray, 127, 255, 0)
    contours,useless = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    ellipse = cv2.fitEllipse(contours[0])
    return cv2.ellipse(image, ellipse, (255,255,255), -1)

# %%
# to check if our masking function is working correctly
fig = plt.figure(figsize = (30,7))
for index in range(7):
  file_path = os.path.join('training_set', train_pixel_file.iloc[index, 0].replace('.png','_Annotation.png'))
  print(file_path)
  ax = fig.add_subplot(2, 7, index+1)             ## annoted plot
  plt.imshow(cv2.imread(file_path))
    
  ax = fig.add_subplot(2, 7, index+8)
  plt.imshow(masking(cv2.imread(file_path)))        ## mask plot
# Out:
# training_set/000_HC_Annotation.png
# training_set/001_HC_Annotation.png
# training_set/002_HC_Annotation.png
# training_set/003_HC_Annotation.png
# training_set/004_HC_Annotation.png
# training_set/005_HC_Annotation.png
# training_set/006_HC_Annotation.png

# %%
# Here we loop through training set and  take annotations one by one and replace them with corresponding masks
fig = plt.figure(figsize = (30,7))
for index in range(len(train_pixel_file)):
    file_path = os.path.join('training_set', train_pixel_file.iloc[index, 0].replace('.png','_Annotation.png'))
    image = cv2.imread(file_path)
    mask = masking(image)
    cv2.imwrite(file_path, mask)

# %% [markdown]
# ## **Warning!!!**
# **Done with mask generation. Don't run above cells ever again**

# %% [markdown]
# ### **Do all the imports in below cell**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from skimage import io, color
from PIL import Image
import cv2

import os
import random

import torch
from torch.utils.data  import Dataset, DataLoader
from torchvision import transforms
import torchvision.transforms.functional as TF
import torch.nn as nn
import torch.nn.functional as F
import torchvision

# %%
validation_set_size = 0.20            # fraction of dataset used for validation which will be splited randomly

# %%
# our dataset class
class HC18(Dataset):
  #""" train and validation dataset class"""
    def __init__(self, root_dir, train = True, transformX = None, transformY = None):
        self.pixel_file = pd.read_csv(os.path.join(root_dir, 'training_set_pixel_size_and_HC.csv'))
        self.root_dir = root_dir
        self.transformX = transformX
        self.transformY = transformY
        self.train = train
        
        # lets split the dataset in train and validation
        self.train_data, self.validation_data = train_test_split(self.pixel_file, test_size = validation_set_size, random_state = 5)
        
    def __len__(self):
        
        if self.train:
          length = len(self.train_data)
        else:
          length = len(self.validation_data)
        return length
    
    def __getitem__(self, index):
      
        if self.train:
          imx_name = os.path.join(self.root_dir, 'training_set', self.train_data.iloc[index, 0])
          imy_name = os.path.join(self.root_dir, 'training_set',self.train_data.iloc[index, 0].replace('.png','_Annotation.png'))

        else:
          imx_name = os.path.join(self.root_dir, 'training_set', self.validation_data.iloc[index, 0])
          imy_name = os.path.join(self.root_dir, 'training_set',self.validation_data.iloc[index, 0].replace('.png','_Annotation.png'))
        
        
        imx = Image.open(imx_name)
        imy = Image.open(imy_name).convert('L')
        
        ## tried some data augmentation techniques
        if self.train:
          # Random horizontal flipping
          if random.random() > 0.5:
              imx = TF.hflip(imx)
              imy = TF.hflip(imy)

          # Random vertical flipping
          if random.random() > 0.5:
              imx = TF.vflip(imx)
              imy = TF.vflip(imy)


          # Random rotation
          if random.random() > 0.8:
            angle = random.choice([-30, -90, -60, -45 -15, 0, 15, 30, 45, 60, 90])
            imx = TF.rotate(imx, angle)
            imy = TF.rotate(imy, angle)
        
        
        
        
        
        
        if self.transformX :
            imx = self.transformX(imx)
            imy = self.transformY(imy)
        
        sample = {'image': imx, 'annotation': imy}
        return sample

# %%
# our datasets
tx_X = transforms.Compose([ transforms.Resize((572, 572)),
                              transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,))
                              ])
tx_Y = transforms.Compose([ transforms.Resize((572, 572)),
                              transforms.ToTensor(),  ################ no need to normalize the maskk
                             # transforms.Normalize((0.5,), (0.5,))
                              ])
train_data = HC18('', train = True, transformX = tx_X, transformY = tx_Y)
validation_data = HC18('', train = False, transformX = tx_X, transformY = tx_Y )

# %%
# our dataloaders
train_loader = DataLoader(dataset = train_data, batch_size = 2, shuffle = True, num_workers = 2 )
validation_loader = DataLoader(dataset = validation_data, batch_size = 2, shuffle = True, num_workers = 2)

# %%
# this function will return numpy array from the transformed tensors which were
# obtained from our train_loader. Just to plot them and see if they are intact :) ha ha
def im_converterX(tensor):
    image = tensor.cpu().clone().detach().numpy() # make copy of tensor and converting it to numpy as we will need original later
    image = image.transpose(1,2,0) # swapping axes making (1, 28, 28) image to a (28, 28, 1)
 # print(image.shape)
    image = image * np.array((0.5, 0.5, 0.5)) + np.array((0.5, 0.5, 0.5)) # unnormalizing the image # this also outputs (28, 28, 3) which seems important for plt.imshow
    image = image.clip(0, 1) # to make sure final values are in range 0 to 1 as .ToTensor outputed
    return image

# %%
# this function will return numpy array from the transformed tensors which were
# obtained from our train_loader. Just to plot them and see if they are intact :) ha ha
def im_converterY(tensor):
    image = tensor.cpu().clone().detach().numpy() # make copy of tensor and converting it to numpy as we will need original later
    image = image.transpose(1,2,0) # swapping axes making (1, 28, 28) image to a (28, 28, 1)
 # print(image.shape)
    image = image * np.array((1, 1, 1)) # unnormalizing the image  not needed# this also outputs (28, 28, 3) which seems important for plt.imshow
    image = image.clip(0, 1) # to make sure final values are in range 0 to 1 as .ToTensor outputed
    return image

# %%
## Here we loop through our train_loader and see the images
## Looks good
fig = plt.figure(figsize = (15,6))
for ith_batch, sample_batched in enumerate(train_loader):
    print(ith_batch, sample_batched['image'].size(), sample_batched['annotation'].size())
    
    for index in range(2):
        ax = fig.add_subplot(2, 2 , index + 1)  # subplot index starts from 1
        plt.imshow(im_converterX(sample_batched['image'][index]))
        ax = fig.add_subplot(2, 2, index + 3)
        plt.imshow(im_converterY(sample_batched['annotation'][index]))
    break
# Out:
# 0 torch.Size([2, 1, 572, 572]) torch.Size([2, 1, 572, 572])

# %%
class double_conv(nn.Module):
    '''(conv => BN => ReLU) * 2'''

    def __init__(self, in_ch, out_ch):
        super(double_conv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            #nn.Dropout2d(0.7),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            #nn.Dropout2d(0.77),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x = self.conv(x)
        return x


class inconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(inconv, self).__init__()
        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x):
        x = self.conv(x)
        return x


class down(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(down, self).__init__()
        self.mpconv = nn.Sequential(
            nn.MaxPool2d(2),
            double_conv(in_ch, out_ch)
        )

    def forward(self, x):
        x = self.mpconv(x)
        return x


class up(nn.Module):
    def __init__(self, in_ch, out_ch, bilinear=True):
        super(up, self).__init__()

        if bilinear: #upsampling will not be learnable
            self.up = nn.Upsample(
                scale_factor=2, mode='bilinear', align_corners=True)
        else:  # it will be learnable here
            self.up = nn.ConvTranspose2d(in_ch // 2, in_ch // 2, 2, stride=2)
        
        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x1, x2):
        x1 = self.up(x1)

        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, (diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2))

        x = torch.cat([x2, x1], dim=1)
        x = self.conv(x)
        return x


class outconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(outconv, self).__init__()
        self.conv = nn.Conv2d(in_ch, out_ch, 1)

    def forward(self, x):
        x = self.conv(x)
        return x

# %%
class UNet(nn.Module):
    def __init__(self, n_channels, n_classes):
        super(UNet, self).__init__()
        self.inc = inconv(n_channels, 64)
        self.down1 = down(64, 128)
        self.down2 = down(128, 256)
        self.down3 = down(256, 512)
        self.down4 = down(512, 512)
        self.up1 = up(1024, 256, bilinear = False) # upsampling weights are made learnable
        self.up2 = up(512, 128, bilinear = False)
        self.up3 = up(256, 64, bilinear = False)
        self.up4 = up(128, 64, bilinear = False)
        self.outc = outconv(64, n_classes)
        self.dropout = torch.nn.Dropout2d(0.5)

    def forward(self, x):
        x = x.float()
        x1 = self.inc(x)
        x2 = self.down1(x1)
       # x2 = self.dropout(x2)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
       
        x = self.up1(x5, x4)
#         print(x.shape)
        x = self.up2(x, x3)
#         print(x.shape)
        x = self.dropout(x)
        x = self.up3(x, x2)
#         print(x.shape)
        #x = self.dropout(x) #
        x = self.up4(x, x1)
#         print(x.shape)
        x = self.outc(x)
#         print(x.shape)
        return torch.sigmoid(x)
      
      
      
      
      
      
model = UNet(1, 1)
model.to('cuda')
print("Model Loaded to GPU")
# Out:
# Model Loaded to GPU

# %%
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0077)

# %%
# calculates similarity index between predicted and actual segmentation
def dice_index(y_pred, y_actual):
    smooth = 0.000001
    size_of_batch = y_pred.size(0)
    
    p1 = y_pred.view(size_of_batch, -1)
    p2 = y_actual.view(size_of_batch, -1)
    
    intersection = (p1 * p2).sum()
    
    dice =  ((2.0 * intersection )+ smooth) / (p1.sum() + p2.sum() + smooth)
    #dice.requires_grad = True
    
    return dice

# %%
# calculate dice loss which will be later used in loss function calculation
def dice_loss(y_predict, y_train): ## to add in bce looss
  
  dice_loss = 1 -(dice_index(y_predict, y_train))
  
  return dice_loss

# %%
epochs = 100


train_running_loss_history = []
validation_running_loss_history =[]

for e in range(epochs):
  train_running_loss = 0.0
  validation_running_loss = 0.0
  
  model.train()
  
  for ith_batch, sample_batched in enumerate(train_loader):
    X_train = sample_batched['image'].to('cuda')
    y_train = sample_batched['annotation'].to('cuda')
    
    #X_train.requires_grad = True
    #y_train.requires_grad = True

    #print(ith_batch) #, X_train.size(), y_train.size())

    optimizer.zero_grad()
    y_pred = model(X_train)
   # out = (y_pred + 0.5).int().float()
    
    loss = 0.30 * dice_loss(y_pred, y_train) +  0.70 * criterion(y_pred, y_train)
    #loss = criterion(y_pred, y_train)
    loss.backward()
    optimizer.step()
    
    if ith_batch % 50 == 0:
      print('Epoch: ', e + 1, 'Batch: ', ith_batch, 'Current Loss: ', loss.item())
      
    train_running_loss += loss.item()
    
    
    
    
  else:
    with torch.no_grad():
      
      model.eval()
      
      for ith_batch, sample_batched in enumerate(validation_loader):
          X_val = sample_batched['image'].to('cuda')
          y_val = sample_batched['annotation'].to('cuda')
          
          
          
          y_out = model(X_val)
          out_val = (y_out + 0.5).int().float()
          
          val_loss = 0.3 * dice_loss(out_val, y_val)  + 0.7 * criterion(y_out, y_val)
          
          #val_loss = criterion(y_out, y_val)
          
          validation_running_loss += val_loss.item()
      print("================================================================================")
      print("Epoch {} completed".format(e + 1))
      
      train_epoch_loss = train_running_loss / len(train_loader)
      validation_epoch_loss = validation_running_loss / len(validation_loader)
      
      print("Average train loss is {}: ".format(train_epoch_loss))
      print("Average validation loss is {}".format(validation_epoch_loss))
      print("================================================================================")
      train_running_loss_history.append(train_epoch_loss)
      validation_running_loss_history.append(validation_epoch_loss)
  
  torch.cuda.empty_cache()
      #print(y_pred.shape)

    #y_pred = y_pred.to('cpu')
    #X_train = X_train.to('cpu')

    #del y_train
    #torch.cuda.empty_cache()
    #if ith_batch ==100:
    #break
  #for index in range(2):
  #         ax = gig.add_subplot(2, 2 , index + 1)  # subplot index starts from 1
   #         plt.imshow(im_converter(X_train[index]))
    #        ax = gig.add_subplot(2, 2, index + 3)
     #       plt.imshow(im_converter(y_pred[index]))
# Out:
# Epoch:  1 Batch:  0 Current Loss:  0.6356207728385925
# Epoch:  1 Batch:  50 Current Loss:  0.46971383690834045
# Epoch:  1 Batch:  100 Current Loss:  0.3187118172645569
# Epoch:  1 Batch:  150 Current Loss:  0.33061620593070984
# Epoch:  1 Batch:  200 Current Loss:  0.31316640973091125
# Epoch:  1 Batch:  250 Current Loss:  0.37536337971687317
# Epoch:  1 Batch:  300 Current Loss:  0.329255610704422
# Epoch:  1 Batch:  350 Current Loss:  0.3653486967086792
# ================================================================================
# Epoch 1 completed
# Average train loss is 0.3685015662014484:
# Average validation loss is 0.3161662745475769
# ================================================================================
# Epoch:  2 Batch:  0 Current Loss:  0.3761392831802368
# Epoch:  2 Batch:  50 Current Loss:  0.3624988794326782
# Epoch:  2 Batch:  100 Current Loss:  0.1810317039489746
# Epoch:  2 Batch:  150 Current Loss:  0.2543482482433319
# Epoch:  2 Batch:  200 Current Loss:  0.248984694480896
# Epoch:  2 Batch:  250 Current Loss:  0.18364092707633972
# Epoch:  2 Batch:  300 Current Loss:  0.29121044278144836
# Epoch:  2 Batch:  350 Current Loss:  0.20669370889663696
# ================================================================================
# Epoch 2 completed
# Average train loss is 0.2746659447625279:
# Average validation loss is 0.30602404475212097
# ================================================================================
# Epoch:  3 Batch:  0 Current Loss:  0.6227115988731384
# Epoch:  3 Batch:  50 Current Loss:  0.2975285053253174
# Epoch:  3 Batch:  100 Current Loss:  0.10652250796556473
# Epoch:  3 Batch:  150 Current Loss:  0.1452164649963379
# Epoch:  3 Batch:  200 Current Loss:  0.36765390634536743
# Epoch:  3 Batch:  250 Current Loss:  0.18252220749855042
# Epoch:  3 Batch:  300 Current Loss:  0.10264082252979279
# Epoch:  3 Batch:  350 Current Loss:  0.15354585647583008
# ================================================================================
# Epoch 3 completed
# Average train loss is 0.20803134754300118:
# Average validation loss is 0.18051698751747608
# ================================================================================
# Epoch:  4 Batch:  0 Current Loss:  0.11681320518255234
# Epoch:  4 Batch:  50 Current Loss:  0.06412901729345322
# Epoch:  4 Batch:  100 Current Loss:  0.2748381197452545
# Epoch:  4 Batch:  150 Current Loss:  0.08504039794206619
# Epoch:  4 Batch:  200 Current Loss:  0.0844840258359909
# Epoch:  4 Batch:  250 Current Loss:  0.19662441313266754
# Epoch:  4 Batch:  300 Current Loss:  0.19200178980827332
# Epoch:  4 Batch:  350 Current Loss:  0.08600907027721405
# ================================================================================
# Epoch 4 completed
# Average train loss is 0.16231798668392003:
# Average validation loss is 0.14887113023549317
# ================================================================================
# Epoch:  5 Batch:  0 Current Loss:  0.08318929374217987
# Epoch:  5 Batch:  50 Current Loss:  0.07375787198543549
# Epoch:  5 Batch:  100 Current Loss:  0.12528090178966522
# Epoch:  5 Batch:  150 Current Loss:  0.17580008506774902
# Epoch:  5 Batch:  200 Current Loss:  0.141961932182312
# Epoch:  5 Batch:  250 Current Loss:  0.12258907407522202
# Epoch:  5 Batch:  300 Current Loss:  0.168493390083313
# Epoch:  5 Batch:  350 Current Loss:  0.11328868567943573
# ================================================================================
# Epoch 5 completed
# Average train loss is 0.1343405098374933:
# Average validation loss is 0.16775279272347687
# ================================================================================
# Epoch:  6 Batch:  0 Current Loss:  0.10512562096118927
# Epoch:  6 Batch:  50 Current Loss:  0.10309987515211105
# Epoch:  6 Batch:  100 Current Loss:  0.053269606083631516
# Epoch:  6 Batch:  150 Current Loss:  0.18071556091308594
# Epoch:  6 Batch:  200 Current Loss:  0.07745307683944702
# Epoch:  6 Batch:  250 Current Loss:  0.09340239316225052
# Epoch:  6 Batch:  300 Current Loss:  0.09288977086544037
# Epoch:  6 Batch:  350 Current Loss:  0.3483705520629883
# ================================================================================
# Epoch 6 completed
# Average train loss is 0.1284715973213315:
# Average validation loss is 0.13493346732109784
# ================================================================================
# Epoch:  7 Batch:  0 Current Loss:  0.0821913331747055
# Epoch:  7 Batch:  50 Current Loss:  0.12069150805473328
# Epoch:  7 Batch:  100 Current Loss:  0.11068382859230042
# Epoch:  7 Batch:  150 Current Loss:  0.08897237479686737
# Epoch:  7 Batch:  200 Current Loss:  0.19951370358467102
# Epoch:  7 Batch:  250 Current Loss:  0.1992659568786621
# Epoch:  7 Batch:  300 Current Loss:  0.07786756008863449
# Epoch:  7 Batch:  350 Current Loss:  0.05154552310705185
# ================================================================================
# Epoch 7 completed
# Average train loss is 0.10690900997258723:
# Average validation loss is 0.14181583508849144
# ================================================================================
# Epoch:  8 Batch:  0 Current Loss:  0.05308646708726883
# Epoch:  8 Batch:  50 Current Loss:  0.0708494633436203
# Epoch:  8 Batch:  100 Current Loss:  0.07413756847381592
# Epoch:  8 Batch:  150 Current Loss:  0.18325698375701904
# Epoch:  8 Batch:  200 Current Loss:  0.25601571798324585
# Epoch:  8 Batch:  250 Current Loss:  0.038707900792360306
# Epoch:  8 Batch:  300 Current Loss:  0.10528630763292313
# Epoch:  8 Batch:  350 Current Loss:  0.13639937341213226
# ================================================================================
# Epoch 8 completed
# Average train loss is 0.10057857619598508:
# Average validation loss is 0.10945831548422574
# ================================================================================
# Epoch:  9 Batch:  0 Current Loss:  0.056413374841213226
# Epoch:  9 Batch:  50 Current Loss:  0.06951889395713806
# Epoch:  9 Batch:  100 Current Loss:  0.04757963865995407
# Epoch:  9 Batch:  150 Current Loss:  0.12125008553266525
# Epoch:  9 Batch:  200 Current Loss:  0.07352998107671738
# Epoch:  19 Batch:  150 Current Loss:  0.030709005892276764
# Epoch:  19 Batch:  200 Current Loss:  0.1610041856765747
# Epoch:  19 Batch:  250 Current Loss:  0.055051788687705994
# Epoch:  19 Batch:  300 Current Loss:  0.07060940563678741
# Epoch:  19 Batch:  350 Current Loss:  0.06191423162817955
# ================================================================================
# Epoch 19 completed
# Average train loss is 0.07201775277964771:
# Average validation loss is 0.07164604555815458
# ================================================================================
# Epoch:  20 Batch:  0 Current Loss:  0.07355210185050964
# Epoch:  20 Batch:  50 Current Loss:  0.059570133686065674
# Epoch:  20 Batch:  100 Current Loss:  0.08246249705553055
# Epoch:  20 Batch:  150 Current Loss:  0.10829401016235352
# Epoch:  20 Batch:  200 Current Loss:  0.040426287800073624
# Epoch:  20 Batch:  250 Current Loss:  0.04550592601299286
# Epoch:  20 Batch:  300 Current Loss:  0.05310048162937164
# Epoch:  20 Batch:  350 Current Loss:  0.20346476137638092
# ================================================================================
# Epoch 20 completed
# Average train loss is 0.07061100417282433:
# Average validation loss is 0.08794482603669167
# ================================================================================
# Epoch:  21 Batch:  0 Current Loss:  0.07322897762060165
# Epoch:  21 Batch:  50 Current Loss:  0.10601994395256042
# Epoch:  21 Batch:  100 Current Loss:  0.029910914599895477
# Epoch:  21 Batch:  150 Current Loss:  0.0839681550860405
# Epoch:  21 Batch:  200 Current Loss:  0.023649686947464943
# Epoch:  21 Batch:  250 Current Loss:  0.07378464937210083
# Epoch:  21 Batch:  300 Current Loss:  0.03380516171455383
# Epoch:  21 Batch:  350 Current Loss:  0.037505149841308594
# ================================================================================
# Epoch 21 completed
# Average train loss is 0.06807090465445072:
# Average validation loss is 0.06931820983067155
# ================================================================================
# Epoch:  22 Batch:  0 Current Loss:  0.0406775176525116
# Epoch:  22 Batch:  50 Current Loss:  0.09644262492656708
# Epoch:  22 Batch:  100 Current Loss:  0.14396516978740692
# Epoch:  22 Batch:  150 Current Loss:  0.11024172604084015
# Epoch:  22 Batch:  200 Current Loss:  0.07800457626581192
# Epoch:  22 Batch:  250 Current Loss:  0.13469991087913513
# Epoch:  22 Batch:  300 Current Loss:  0.08826380223035812
# Epoch:  22 Batch:  350 Current Loss:  0.03736265003681183
# ================================================================================
# Epoch 22 completed
# Average train loss is 0.07054941007401794:
# Average validation loss is 0.06893745075911284
# ================================================================================
# Epoch:  23 Batch:  0 Current Loss:  0.07352375239133835
# Epoch:  23 Batch:  50 Current Loss:  0.04795454442501068
# Epoch:  23 Batch:  100 Current Loss:  0.04748130217194557
# Epoch:  23 Batch:  150 Current Loss:  0.052532970905303955
# Epoch:  23 Batch:  200 Current Loss:  0.09780102223157883
# Epoch:  23 Batch:  250 Current Loss:  0.08037132024765015
# Epoch:  23 Batch:  300 Current Loss:  0.034271154552698135
# Epoch:  23 Batch:  350 Current Loss:  0.04605085402727127
# ================================================================================
# Epoch 23 completed
# Average train loss is 0.06551999248098582:
# Average validation loss is 0.07764567380771041
# ================================================================================
# Epoch:  24 Batch:  0 Current Loss:  0.07439451664686203
# Epoch:  24 Batch:  50 Current Loss:  0.14424535632133484
# Epoch:  24 Batch:  100 Current Loss:  0.08718544989824295
# Epoch:  24 Batch:  150 Current Loss:  0.058509595692157745
# Epoch:  24 Batch:  200 Current Loss:  0.0670609325170517
# Epoch:  24 Batch:  250 Current Loss:  0.03795505315065384
# Epoch:  24 Batch:  300 Current Loss:  0.05358654260635376
# Epoch:  24 Batch:  350 Current Loss:  0.081194669008255
# ================================================================================
# Epoch 24 completed
# Average train loss is 0.06868775104172528:
# Average validation loss is 0.06421400908380746
# ================================================================================
# Epoch:  25 Batch:  0 Current Loss:  0.0500013567507267
# Epoch:  25 Batch:  50 Current Loss:  0.04477353394031525
# Epoch:  25 Batch:  100 Current Loss:  0.09273623675107956
# Epoch:  25 Batch:  150 Current Loss:  0.07546006143093109
# Epoch:  25 Batch:  200 Current Loss:  0.07705900073051453
# Epoch:  25 Batch:  250 Current Loss:  0.04246129095554352
# Epoch:  25 Batch:  300 Current Loss:  0.06542962044477463
# Epoch:  25 Batch:  350 Current Loss:  0.0654863491654396
# ================================================================================
# Epoch 25 completed
# Average train loss is 0.06308481405023486:
# Average validation loss is 0.08229509035125375
# ================================================================================
# Epoch:  26 Batch:  0 Current Loss:  0.05146601051092148
# Epoch:  26 Batch:  50 Current Loss:  0.04187779873609543
# Epoch:  26 Batch:  100 Current Loss:  0.032463688403367996
# Epoch:  26 Batch:  150 Current Loss:  0.06864234060049057
# Epoch:  26 Batch:  200 Current Loss:  0.0650128573179245
# Epoch:  26 Batch:  250 Current Loss:  0.06546128541231155
# Epoch:  26 Batch:  300 Current Loss:  0.07485952228307724
# Epoch:  26 Batch:  350 Current Loss:  0.09920056909322739
# ================================================================================
# Epoch 26 completed
# Average train loss is 0.06816556101199239:
# Average validation loss is 0.06688100472092628
# ================================================================================
# Epoch:  27 Batch:  0 Current Loss:  0.07571481168270111
# Epoch:  27 Batch:  50 Current Loss:  0.036557652056217194
# Epoch:  27 Batch:  100 Current Loss:  0.09138006716966629
# Epoch:  27 Batch:  150 Current Loss:  0.026644688099622726
# Epoch:  27 Batch:  200 Current Loss:  0.031809497624635696
# Epoch:  27 Batch:  250 Current Loss:  0.08447430282831192
# Epoch:  27 Batch:  300 Current Loss:  0.044484373182058334
# Epoch:  27 Batch:  350 Current Loss:  0.02793053723871708
# ================================================================================
# Epoch 27 completed
# Average train loss is 0.06239321163855493:
# Average validation loss is 0.07864409292116761
# ================================================================================
# Epoch:  28 Batch:  0 Current Loss:  0.059516943991184235
# Epoch:  28 Batch:  50 Current Loss:  0.07886232435703278
# Epoch:  28 Batch:  100 Current Loss:  0.05861235782504082
# Epoch:  28 Batch:  150 Current Loss:  0.044697828590869904
# Epoch:  28 Batch:  200 Current Loss:  0.06120109558105469
# Epoch:  28 Batch:  250 Current Loss:  0.09262444078922272
# Epoch:  28 Batch:  300 Current Loss:  0.043227121233940125
# Epoch:  28 Batch:  350 Current Loss:  0.05568690598011017
# ================================================================================
# Epoch 28 completed
# Average train loss is 0.06261265276465565:
# Average validation loss is 0.07324366824701428
# ================================================================================
# Epoch:  29 Batch:  0 Current Loss:  0.07469573616981506
# Epoch:  29 Batch:  50 Current Loss:  0.036652952432632446
# Epoch:  29 Batch:  100 Current Loss:  0.0278759878128767
# Epoch:  29 Batch:  150 Current Loss:  0.1116592288017273
# Epoch:  29 Batch:  200 Current Loss:  0.03489277511835098
# Epoch:  29 Batch:  250 Current Loss:  0.03428321331739426
# Epoch:  29 Batch:  300 Current Loss:  0.04485633969306946
# Epoch:  29 Batch:  350 Current Loss:  0.03761926293373108
# ================================================================================
# Epoch 29 completed
# Average train loss is 0.06371097149793059:
# Average validation loss is 0.064647784139961
# ================================================================================
# Epoch:  30 Batch:  0 Current Loss:  0.05525866895914078
# Epoch:  30 Batch:  50 Current Loss:  0.04313679784536362
# Epoch:  30 Batch:  100 Current Loss:  0.1495596170425415
# Epoch:  30 Batch:  150 Current Loss:  0.04047400504350662
# Epoch:  30 Batch:  200 Current Loss:  0.08520957082509995
# Epoch:  30 Batch:  250 Current Loss:  0.05081344395875931
# Epoch:  30 Batch:  300 Current Loss:  0.06184519827365875
# Epoch:  30 Batch:  350 Current Loss:  0.039673998951911926
# ================================================================================
# Epoch 30 completed
# Average train loss is 0.059275045758113265:
# Average validation loss is 0.0745437578856945
# ================================================================================
# Epoch:  31 Batch:  0 Current Loss:  0.05932317674160004
# Epoch:  31 Batch:  50 Current Loss:  0.05127330496907234
# Epoch:  31 Batch:  100 Current Loss:  0.06290498375892639
# Epoch:  31 Batch:  150 Current Loss:  0.08525556325912476
# Epoch:  31 Batch:  200 Current Loss:  0.04572632908821106
# Epoch:  31 Batch:  250 Current Loss:  0.03872688487172127
# Epoch:  31 Batch:  300 Current Loss:  0.062136076390743256
# Epoch:  31 Batch:  350 Current Loss:  0.05195643752813339
# ================================================================================
# Epoch 31 completed
# Average train loss is 0.05755727095995098:
# Average validation loss is 0.0870600625500083
# ================================================================================
# Epoch:  32 Batch:  0 Current Loss:  0.05875473842024803
# Epoch:  32 Batch:  50 Current Loss:  0.03015047125518322
# Epoch:  32 Batch:  100 Current Loss:  0.04426461458206177
# Epoch:  32 Batch:  150 Current Loss:  0.047827593982219696
# Epoch:  32 Batch:  200 Current Loss:  0.11989231407642365
# Epoch:  32 Batch:  250 Current Loss:  0.04430771991610527
# Epoch:  32 Batch:  300 Current Loss:  0.04027099162340164
# Epoch:  32 Batch:  350 Current Loss:  0.1132134348154068
# ================================================================================
# Epoch 32 completed
# Average train loss is 0.06305287585128098:
# Average validation loss is 0.06310745602473616
# ================================================================================
# Epoch:  33 Batch:  0 Current Loss:  0.035991646349430084
# Epoch:  33 Batch:  50 Current Loss:  0.025142237544059753
# Epoch:  33 Batch:  100 Current Loss:  0.057298384606838226
# Epoch:  33 Batch:  150 Current Loss:  0.21009041368961334
# Epoch:  33 Batch:  200 Current Loss:  0.059828005731105804
# Epoch:  33 Batch:  250 Current Loss:  0.08357128500938416
# Epoch:  33 Batch:  300 Current Loss:  0.14001882076263428
# Epoch:  33 Batch:  350 Current Loss:  0.039226118475198746
# ================================================================================
# Epoch 33 completed
# Average train loss is 0.06045576102565974:
# Average validation loss is 0.0714571245200932
# ================================================================================
# Epoch:  34 Batch:  0 Current Loss:  0.033543795347213745
# Epoch:  34 Batch:  50 Current Loss:  0.07934945076704025
# Epoch:  34 Batch:  100 Current Loss:  0.06705118715763092
# Epoch:  34 Batch:  150 Current Loss:  0.07200013846158981
# Epoch:  34 Batch:  200 Current Loss:  0.029512200504541397
# Epoch:  34 Batch:  250 Current Loss:  0.050891902297735214
# Epoch:  34 Batch:  300 Current Loss:  0.05794302374124527
# Epoch:  34 Batch:  350 Current Loss:  0.029780741780996323
# ================================================================================
# Epoch 34 completed
# Average train loss is 0.05867609521839768:
# Average validation loss is 0.0645893393456936
# ================================================================================
# Epoch:  35 Batch:  0 Current Loss:  0.024508008733391762
# Epoch:  35 Batch:  50 Current Loss:  0.028686657547950745
# Epoch:  35 Batch:  100 Current Loss:  0.04977387562394142
# Epoch:  35 Batch:  150 Current Loss:  0.08015614748001099
# Epoch:  35 Batch:  200 Current Loss:  0.03544324263930321
# Epoch:  35 Batch:  250 Current Loss:  0.04362877458333969
# Epoch:  35 Batch:  300 Current Loss:  0.02586887590587139
# Epoch:  35 Batch:  350 Current Loss:  0.11760997772216797
# ================================================================================
# Epoch 35 completed
# Average train loss is 0.0575584363611415:
# Average validation loss is 0.08186196343973279
# ================================================================================
# Epoch:  36 Batch:  0 Current Loss:  0.04151839390397072
# Epoch:  36 Batch:  50 Current Loss:  0.09461109340190887
# Epoch:  36 Batch:  100 Current Loss:  0.049250632524490356
# Epoch:  36 Batch:  150 Current Loss:  0.029581241309642792
# Epoch:  36 Batch:  200 Current Loss:  0.03390397131443024
# Epoch:  36 Batch:  250 Current Loss:  0.14178195595741272
# Epoch:  36 Batch:  300 Current Loss:  0.10865432024002075
# Epoch:  36 Batch:  350 Current Loss:  0.07212477177381516
# ================================================================================
# Epoch 36 completed
# Average train loss is 0.05613857075106352:
# Average validation loss is 0.057994416784495115
# ================================================================================
# Epoch:  37 Batch:  0 Current Loss:  0.03883475065231323
# Epoch:  37 Batch:  50 Current Loss:  0.036460407078266144
# Epoch:  37 Batch:  100 Current Loss:  0.03385190665721893
# Epoch:  37 Batch:  150 Current Loss:  0.03848055377602577
# Epoch:  37 Batch:  200 Current Loss:  0.03838861733675003
# Epoch:  37 Batch:  250 Current Loss:  0.05509971082210541
# Epoch:  37 Batch:  300 Current Loss:  0.045456886291503906
# Epoch:  37 Batch:  350 Current Loss:  0.05375772714614868
# ================================================================================
# Epoch 37 completed
# Average train loss is 0.05821180799975991:
# Average validation loss is 0.0842051376402378
# ================================================================================
# Epoch:  38 Batch:  0 Current Loss:  0.03155972436070442
# Epoch:  38 Batch:  50 Current Loss:  0.05673093721270561
# Epoch:  38 Batch:  100 Current Loss:  0.06661683320999146
# Epoch:  38 Batch:  150 Current Loss:  0.03776024281978607
# Epoch:  38 Batch:  200 Current Loss:  0.03623597323894501
# Epoch:  38 Batch:  250 Current Loss:  0.03249211609363556
# Epoch:  38 Batch:  300 Current Loss:  0.08172107487916946
# Epoch:  38 Batch:  350 Current Loss:  0.04473240673542023
# ================================================================================
# Epoch 38 completed
# Average train loss is 0.057447740472853184:
# Average validation loss is 0.09971848312765359
# ================================================================================
# Epoch:  39 Batch:  0 Current Loss:  0.1172766238451004
# Epoch:  39 Batch:  50 Current Loss:  0.04785292595624924
# Epoch:  39 Batch:  100 Current Loss:  0.04119972884654999
# Epoch:  39 Batch:  150 Current Loss:  0.1047225147485733
# Epoch:  39 Batch:  200 Current Loss:  0.029258664697408676
# Epoch:  39 Batch:  250 Current Loss:  0.04092609882354736
# Epoch:  39 Batch:  300 Current Loss:  0.05405883491039276
# Epoch:  39 Batch:  350 Current Loss:  0.04040075093507767
# ================================================================================
# Epoch 39 completed
# Average train loss is 0.054911674056202175:
# Average validation loss is 0.06686603110283613
# ================================================================================
# Epoch:  40 Batch:  0 Current Loss:  0.06339745223522186
# Epoch:  40 Batch:  50 Current Loss:  0.021146994084119797
# Epoch:  40 Batch:  100 Current Loss:  0.04535403102636337
# Epoch:  40 Batch:  150 Current Loss:  0.054292771965265274
# Epoch:  40 Batch:  200 Current Loss:  0.0347086638212204
# Epoch:  40 Batch:  250 Current Loss:  0.04469269514083862
# Epoch:  40 Batch:  300 Current Loss:  0.20354288816452026
# Epoch:  40 Batch:  350 Current Loss:  0.03724897280335426
# ================================================================================
# Epoch 40 completed
# Average train loss is 0.056423934996128085:
# Average validation loss is 0.06187530053779483
# ================================================================================
# Epoch:  41 Batch:  0 Current Loss:  0.08151832222938538
# Epoch:  41 Batch:  50 Current Loss:  0.0682101920247078
# Epoch:  41 Batch:  100 Current Loss:  0.05015643686056137
# Epoch:  41 Batch:  150 Current Loss:  0.046335719525814056
# Epoch:  41 Batch:  200 Current Loss:  0.1403365433216095
# Epoch:  41 Batch:  250 Current Loss:  0.03521670401096344
# Epoch:  41 Batch:  300 Current Loss:  0.053677093237638474
# Epoch:  41 Batch:  350 Current Loss:  0.03901577740907669
# ================================================================================
# Epoch 41 completed
# Average train loss is 0.0536616152850911:
# Average validation loss is 0.05851862668991089
# ================================================================================
# Epoch:  42 Batch:  0 Current Loss:  0.04058946669101715
# Epoch:  42 Batch:  50 Current Loss:  0.027302760630846024
# Epoch:  42 Batch:  100 Current Loss:  0.07205450534820557
# Epoch:  42 Batch:  150 Current Loss:  0.0362825021147728
# Epoch:  42 Batch:  200 Current Loss:  0.04396127164363861
# Epoch:  42 Batch:  250 Current Loss:  0.10820052772760391
# Epoch:  42 Batch:  300 Current Loss:  0.04241662845015526
# Epoch:  42 Batch:  350 Current Loss:  0.038329266011714935
# ================================================================================
# Epoch 42 completed
# Average train loss is 0.05440164498984814:
# Average validation loss is 0.06196100164204836
# ================================================================================
# Epoch:  43 Batch:  0 Current Loss:  0.04884801432490349
# Epoch:  43 Batch:  50 Current Loss:  0.059014417231082916
# Epoch:  43 Batch:  100 Current Loss:  0.09554516524076462
# Epoch:  43 Batch:  150 Current Loss:  0.02762533724308014
# Epoch:  43 Batch:  200 Current Loss:  0.028882164508104324
# Epoch:  43 Batch:  250 Current Loss:  0.06448383629322052
# Epoch:  43 Batch:  300 Current Loss:  0.029956594109535217
# Epoch:  43 Batch:  350 Current Loss:  0.05384614318609238
# ================================================================================
# Epoch 43 completed
# ================================================================================
# Epoch 48 completed
# Average train loss is 0.04992937830276787:
# Average validation loss is 0.056427449360489844
# ================================================================================
# Epoch:  49 Batch:  0 Current Loss:  0.03900532424449921
# Epoch:  49 Batch:  50 Current Loss:  0.08217298984527588
# Epoch:  49 Batch:  100 Current Loss:  0.03092312067747116
# Epoch:  49 Batch:  150 Current Loss:  0.030644584447145462
# Epoch:  49 Batch:  200 Current Loss:  0.08168677985668182
# Epoch:  49 Batch:  250 Current Loss:  0.019205842167139053
# Epoch:  49 Batch:  300 Current Loss:  0.03349945694208145
# Epoch:  49 Batch:  350 Current Loss:  0.04980640858411789
# ================================================================================
# Epoch 49 completed
# Average train loss is 0.05249341517221182:
# Average validation loss is 0.07428953198716044
# ================================================================================
# Epoch:  50 Batch:  0 Current Loss:  0.0446808747947216
# Epoch:  50 Batch:  50 Current Loss:  0.0393834263086319
# Epoch:  50 Batch:  100 Current Loss:  0.0407961830496788
# Epoch:  50 Batch:  150 Current Loss:  0.0395577996969223
# Epoch:  50 Batch:  200 Current Loss:  0.05243654549121857
# Epoch:  50 Batch:  250 Current Loss:  0.02928885444998741
# Epoch:  50 Batch:  300 Current Loss:  0.04013513773679733
# Epoch:  50 Batch:  350 Current Loss:  0.06840679794549942
# ================================================================================
# Epoch 50 completed
# Average train loss is 0.048375667785294355:
# Average validation loss is 0.0696040034480393
# ================================================================================
# Epoch:  51 Batch:  0 Current Loss:  0.05442380905151367
# Epoch:  51 Batch:  50 Current Loss:  0.02734338492155075
# Epoch:  51 Batch:  100 Current Loss:  0.08508557826280594
# Epoch:  51 Batch:  150 Current Loss:  0.06128585338592529
# Epoch:  51 Batch:  200 Current Loss:  0.023898277431726456
# Epoch:  51 Batch:  250 Current Loss:  0.03311290591955185
# Epoch:  51 Batch:  300 Current Loss:  0.026255551725625992
# Epoch:  51 Batch:  350 Current Loss:  0.03301163762807846
# ================================================================================
# Epoch 51 completed
# Average train loss is 0.04800030192360282:
# Average validation loss is 0.053004522323608395
# ================================================================================
# Epoch:  52 Batch:  0 Current Loss:  0.042050451040267944
# Epoch:  52 Batch:  50 Current Loss:  0.06267036497592926
# Epoch:  52 Batch:  100 Current Loss:  0.049802541732788086
# Epoch:  52 Batch:  150 Current Loss:  0.023814264684915543
# Epoch:  52 Batch:  200 Current Loss:  0.029395954683423042
# Epoch:  52 Batch:  250 Current Loss:  0.022082490846514702
# Epoch:  52 Batch:  300 Current Loss:  0.03332345932722092
# Epoch:  52 Batch:  350 Current Loss:  0.03676459193229675
# ================================================================================
# Epoch 52 completed
# Average train loss is 0.04620276133995503:
# Average validation loss is 0.059375835899263624
# ================================================================================
# Epoch:  53 Batch:  0 Current Loss:  0.10434327274560928
# Epoch:  53 Batch:  50 Current Loss:  0.25168779492378235
# Epoch:  53 Batch:  100 Current Loss:  0.04680343717336655
# Epoch:  53 Batch:  150 Current Loss:  0.023259134963154793
# Epoch:  53 Batch:  200 Current Loss:  0.031603775918483734
# Epoch:  53 Batch:  250 Current Loss:  0.04485036060214043
# Epoch:  53 Batch:  300 Current Loss:  0.09015863388776779
# Epoch:  53 Batch:  350 Current Loss:  0.030188076198101044
# ================================================================================
# Epoch 53 completed
# Average train loss is 0.04885504413861781:
# Average validation loss is 0.05661716351285577
# ================================================================================
# Epoch:  54 Batch:  0 Current Loss:  0.06131371855735779
# Epoch:  54 Batch:  50 Current Loss:  0.035500504076480865
# Epoch:  54 Batch:  100 Current Loss:  0.0238150954246521
# Epoch:  54 Batch:  150 Current Loss:  0.03494000434875488
# Epoch:  54 Batch:  200 Current Loss:  0.03397669643163681
# Epoch:  54 Batch:  250 Current Loss:  0.021128952503204346
# Epoch:  54 Batch:  300 Current Loss:  0.03600114956498146
# Epoch:  54 Batch:  350 Current Loss:  0.07863996177911758
# ================================================================================
# Epoch 54 completed
# Average train loss is 0.050165916602127256:
# Average validation loss is 0.07673533409833908
# ================================================================================
# Epoch:  55 Batch:  0 Current Loss:  0.027191992849111557
# Epoch:  55 Batch:  50 Current Loss:  0.035066090524196625
# Epoch:  55 Batch:  100 Current Loss:  0.037379052489995956
# Epoch:  55 Batch:  150 Current Loss:  0.044119082391262054
# Epoch:  55 Batch:  200 Current Loss:  0.046439118683338165
# Epoch:  55 Batch:  250 Current Loss:  0.03519965335726738
# Epoch:  55 Batch:  300 Current Loss:  0.03115851804614067
# Epoch:  55 Batch:  350 Current Loss:  0.026047002524137497
# ================================================================================
# Epoch 55 completed
# Average train loss is 0.04886724864598364:
# Average validation loss is 0.16492650639265777
# ================================================================================
# Epoch:  56 Batch:  0 Current Loss:  0.022905101999640465
# Epoch:  56 Batch:  50 Current Loss:  0.09258782118558884
# Epoch:  56 Batch:  100 Current Loss:  0.03089751861989498
# Epoch:  56 Batch:  150 Current Loss:  0.034658707678318024
# Epoch:  56 Batch:  200 Current Loss:  0.03751775249838829
# Epoch:  56 Batch:  250 Current Loss:  0.024159375578165054
# Epoch:  56 Batch:  300 Current Loss:  0.055232107639312744
# Epoch:  56 Batch:  350 Current Loss:  0.0271509550511837
# ================================================================================
# Epoch 56 completed
# Average train loss is 0.046534471213817596:
# Average validation loss is 0.07163765134289861
# ================================================================================
# Epoch:  57 Batch:  0 Current Loss:  0.07863874733448029
# Epoch:  57 Batch:  50 Current Loss:  0.02729398012161255
# Epoch:  57 Batch:  100 Current Loss:  0.05844875052571297
# Epoch:  57 Batch:  150 Current Loss:  0.043247878551483154
# Epoch:  57 Batch:  200 Current Loss:  0.04000217467546463
# Epoch:  57 Batch:  250 Current Loss:  0.03373049944639206
# Epoch:  57 Batch:  300 Current Loss:  0.03500882163643837
# Epoch:  57 Batch:  350 Current Loss:  0.029313893988728523
# ================================================================================
# Epoch 57 completed
# Average train loss is 0.04435214667115361:
# Average validation loss is 0.05793227372691035
# ================================================================================
# Epoch:  58 Batch:  0 Current Loss:  0.02737182378768921
# Epoch:  58 Batch:  50 Current Loss:  0.028081925585865974
# Epoch:  58 Batch:  100 Current Loss:  0.03882677108049393
# Epoch:  58 Batch:  150 Current Loss:  0.04896240681409836
# Epoch:  58 Batch:  200 Current Loss:  0.04224931076169014
# Epoch:  58 Batch:  250 Current Loss:  0.0389830619096756
# Epoch:  63 Batch:  250 Current Loss:  0.037466131150722504
# Epoch:  63 Batch:  300 Current Loss:  0.02818106859922409
# Epoch:  63 Batch:  350 Current Loss:  0.05120145529508591
# ================================================================================
# Epoch 63 completed
# Average train loss is 0.04641316178720444:
# Average validation loss is 0.062189498245716096
# ================================================================================
# Epoch:  64 Batch:  0 Current Loss:  0.03345092758536339
# Epoch:  64 Batch:  50 Current Loss:  0.0590510219335556
# Epoch:  64 Batch:  100 Current Loss:  0.03737133741378784
# Epoch:  64 Batch:  150 Current Loss:  0.02089947834610939
# Epoch:  64 Batch:  200 Current Loss:  0.04431353509426117
# Epoch:  64 Batch:  250 Current Loss:  0.025309229269623756
# Epoch:  64 Batch:  300 Current Loss:  0.047593485563993454
# Epoch:  64 Batch:  350 Current Loss:  0.02952672354876995
# ================================================================================
# Epoch 64 completed
# Average train loss is 0.042416264130733905:
# Average validation loss is 0.07059568731114269
# ================================================================================
# Epoch:  65 Batch:  0 Current Loss:  0.04922637343406677
# Epoch:  65 Batch:  50 Current Loss:  0.04381589964032173
# Epoch:  65 Batch:  100 Current Loss:  0.03760038688778877
# Epoch:  65 Batch:  150 Current Loss:  0.04577898979187012
# Epoch:  65 Batch:  200 Current Loss:  0.03515220433473587
# Epoch:  65 Batch:  250 Current Loss:  0.06175462529063225
# Epoch:  65 Batch:  300 Current Loss:  0.04773322120308876
# Epoch:  65 Batch:  350 Current Loss:  0.04474862292408943
# ================================================================================
# Epoch 65 completed
# Average train loss is 0.045332874907180666:
# Average validation loss is 0.054733553174883126
# ================================================================================
# Epoch:  66 Batch:  0 Current Loss:  0.027580279856920242
# Epoch:  66 Batch:  50 Current Loss:  0.027859756723046303
# Epoch:  66 Batch:  100 Current Loss:  0.0778907909989357
# Epoch:  66 Batch:  150 Current Loss:  0.03953014314174652
# Epoch:  66 Batch:  200 Current Loss:  0.03341779112815857
# Epoch:  66 Batch:  250 Current Loss:  0.10615681111812592
# Epoch:  66 Batch:  300 Current Loss:  0.039496712386608124
# Epoch:  66 Batch:  350 Current Loss:  0.07534846663475037
# ================================================================================
# Epoch 66 completed
# Average train loss is 0.04477398153860122:
# Average validation loss is 0.06121228598058224
# ================================================================================
# Epoch:  67 Batch:  0 Current Loss:  0.025482911616563797
# Epoch:  67 Batch:  50 Current Loss:  0.028619829565286636
# Epoch:  67 Batch:  100 Current Loss:  0.12943126261234283
# Epoch:  67 Batch:  150 Current Loss:  0.02804570086300373
# Epoch:  67 Batch:  200 Current Loss:  0.042151372879743576
# Epoch:  67 Batch:  250 Current Loss:  0.05381866544485092
# Epoch:  67 Batch:  300 Current Loss:  0.02450406923890114
# Epoch:  67 Batch:  350 Current Loss:  0.02519470453262329
# ================================================================================
# Epoch 67 completed
# Average train loss is 0.04374083848204464:
# Average validation loss is 0.07128664650022984
# ================================================================================
# Epoch:  68 Batch:  0 Current Loss:  0.06517627835273743
# Epoch:  68 Batch:  50 Current Loss:  0.037677351385354996
# Epoch:  68 Batch:  100 Current Loss:  0.032669518142938614
# Epoch:  68 Batch:  150 Current Loss:  0.02381240762770176
# Epoch:  68 Batch:  200 Current Loss:  0.04572179168462753
# Epoch:  68 Batch:  250 Current Loss:  0.045426495373249054
# Epoch:  68 Batch:  300 Current Loss:  0.040141887962818146
# Epoch:  68 Batch:  350 Current Loss:  0.0282963365316391
# ================================================================================
# Epoch 68 completed
# Average train loss is 0.04516090331133455:
# Average validation loss is 0.0682879028096795
# ================================================================================
# Epoch:  69 Batch:  0 Current Loss:  0.03533289209008217
# Epoch:  69 Batch:  50 Current Loss:  0.05895444005727768
# Epoch:  69 Batch:  100 Current Loss:  0.040785957127809525

# %%
plt.plot(train_running_loss_history, label = 'Train Loss')
plt.plot(validation_running_loss_history, label = 'Validation Loss')
plt.legend()

# %%
model.eval()
X_train.size()

# %%
out = (y_pred + 0.5).int().float()

# %%
print(dice_index(y_train, out))
print(dice_loss(y_train, out))

# %%
# pig = plt.figure(figsize = (15, 6))

# a = pig.add_subplot(2, 3, 1)
# plt.imshow(im_converterX(X_train[0]))

# a = pig.add_subplot(2, 3, 2)
# plt.imshow(im_converterY(y_train[0]))

# a = pig.add_subplot(2, 3, 3)
# plt.imshow(im_converterY(out[0]))


# a = pig.add_subplot(2, 3, 4)
# plt.imshow(im_converterX(X_train[1]))

# a = pig.add_subplot(2, 3, 5)
# plt.imshow(im_converterY(y_train[1]))

# a = pig.add_subplot(2, 3, 6)
# plt.imshow(im_converterY(out[1]))

# %%
gg = dice_index(out, y_train)
print(gg)
print(dice_loss(out, y_train))

# %%
class HC18_test(Dataset):
    def __init__(self, root_dir, transformX = None):
        self.pixel_file = pd.read_csv(os.path.join(root_dir, 'test_set_pixel_size.csv'))
        self.root_dir = root_dir
        self.transformX = transformX
        
    def __len__(self):
        return len(self.pixel_file)
    
    def __getitem__(self, index):
        imx_name = os.path.join(self.root_dir, 'test_set', self.pixel_file.iloc[index, 0])
        
        imx = Image.open(imx_name)
        
        f_name = self.pixel_file.iloc[index, 0]
        
        if self.transformX :
            imx = self.transformX(imx)
        
        sample = {'image': imx, 'f_name': f_name}
        return sample

# %%
test_data = HC18_test('', transformX = tx_X)

# %%
test_data

# %%
test_loader = DataLoader(dataset = test_data, batch_size = 2, shuffle = True)

# %%
test_loader

# %%
## Here we loop through our train_loader and see the images
## Looks good
fig = plt.figure(figsize = (15,6))
#model.to('cpu')
for ith_batch, sample_batched in enumerate(test_loader):
  
    X_test = sample_batched['image'].to('cuda')
    print(ith_batch, X_test.size())
    
    y_test = (model(X_test) + 0.5).int().float()
    
    
    
    for index in range(2):
        ax = fig.add_subplot(2, 2 , index + 1)  # subplot index starts from 1
        plt.imshow(im_converterX(X_test[index]))
        
        ax  = fig.add_subplot(2, 2, index + 3)
        plt.imshow(im_converterY(y_test[index]))
    break

# %%
def avg_dice_index(dataloader):
  
    dice = 0.0
    model.eval()
    with torch.no_grad():
    
        for ith_batch, sample_batched in enumerate(dataloader):
  
            X_train = sample_batched['image'].to('cuda')
            y_train = sample_batched['annotation'].to('cuda')
            
            y_predict = (model(X_train) + 0.5).int().float()
            
            dice += dice_index(y_predict, y_train)
            
            
            
    avg_dice = dice / len(dataloader)
    return avg_dice.item()

# %%
avg_dice_index(validation_loader)    #### Dice index of validation data

# %%
avg_dice_index(train_loader)        ### Dice index of training data

# %%
test_loader = DataLoader(dataset = test_data, batch_size = 1, shuffle = True) # to write image files

# %% [markdown]
# ## **Warning!!!**
# ### Your are about to write on drive

# %%
transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((540, 800)),
        transforms.ToTensor()
        ])
    
with torch.no_grad():
      #model.eval()
      for ith_batch , sample in enumerate(test_loader):
        X_test = sample['image'].to('cuda')
        y_pred = (model(X_test) + 0.5).int().float().cpu()
#         print(335-ith_batch)
        
        file_names = sample['f_name']
        pankaj = transform(y_pred[0])
        #singh = transform(y_pred[1])
        torchvision.utils.save_image(pankaj , os.path.join('segmented', file_names[0]))
        #torchvision.utils.save_image(singh, os.path.join('/content/drive/My Drive/HC18/test_set', file_names[1].replace('.png','_Annotation.png')))
      print("Segmentation files written")

# %%
def fit_ellipse(im):    
    imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
    ret,thresh = cv2.threshold(imgray,127,255,0)
    contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    contour_sizes = [len(contour) for contour in contours]
    ellipse = cv2.fitEllipse(contours[np.argmax(contour_sizes)])
    return ellipse

# %%
file_names = sorted([file for _,_,files in os.walk('segmented/') for file in files])

# %%
df_pixel_size = pd.read_csv('test_set_pixel_size.csv')
submission = {'filename': [], 'center_x_mm': [], 'center_y_mm': [], 'semi_axes_a_mm': [],
             'semi_axes_b_mm': [], 'angle_rad': [], 'Index': []}

file_names = sorted([file for _,_,files in os.walk('segmented/') for file in files])

for i, file_name in enumerate(file_names):
    im = cv2.imread('segmented/'+file_name)
   # file_name = file_name.replace('_Segmented', '')
    ellipse = fit_ellipse(im)
    im_mask = cv2.ellipse(np.zeros_like(im),ellipse,(255,255,255),-1)
    image_name = file_name.split('.')[0] + '_Annotation_fit.png'
    #cv2.imwrite('/content/drive/My Drive/HC18/test_set/'+image_name, im_mask)
    
    pixel_size = df_pixel_size.loc[df_pixel_size['filename'] == file_name, 'pixel size(mm)'].iloc[0]
    submission['filename'].extend([file_name])
    submission['Index'].extend([int(file_name.split('_')[0])])
    center_x,  center_y = ellipse[0]
    submission['center_x_mm'].extend([pixel_size*center_x])
    submission['center_y_mm'].extend([pixel_size*center_y])
    semi_axes_b, semi_axes_a = ellipse[1]
    if semi_axes_b > semi_axes_a:
        semi_axes_b = semi_axes_b + semi_axes_a
        semi_axes_a = semi_axes_b - semi_axes_a
        semi_axes_b -= semi_axes_a
    submission['semi_axes_a_mm'].extend([semi_axes_a*pixel_size/2])
    submission['semi_axes_b_mm'].extend([semi_axes_b*pixel_size/2])
    angle = ellipse[2]
    if angle < 90:
        angle += 90
    else:
        angle -= 90
    submission['angle_rad'].extend([np.deg2rad(angle)])
    
submission = pd.DataFrame(submission)
submission = submission[['filename', 'center_x_mm', 'center_y_mm', 
                         'semi_axes_a_mm', 'semi_axes_b_mm', 'angle_rad', 'Index']]    
submission = submission.sort_values(['Index'])
submission = submission.drop('Index', axis=1)
submission.to_csv("UNET_30epoches.csv", index=False)
print('Required .csv file generated')

# %%
q = pd.read_csv('seventh_submit_data_aug.csv')  ## to check theck the generated csv

# %%
print('Length of csv file: ',len(q))

# %%
submission.head()
