# %% [markdown]
# <a href="https://colab.research.google.com/github/Pankaj1357/HC18-Grand-Challenge/blob/master/HC18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -r -f training_set/

# %%
# !unzip training_set\ \(2\).zip
# Out:
# Archive:  training_set (2).zip
#    creating: training_set/
#  extracting: training_set/000_HC.png
#   inflating: training_set/000_HC_Annotation.png
#  extracting: training_set/001_HC.png
#   inflating: training_set/001_HC_Annotation.png
#  extracting: training_set/002_HC.png
#   inflating: training_set/002_HC_Annotation.png
#  extracting: training_set/003_HC.png
#   inflating: training_set/003_HC_Annotation.png
#  extracting: training_set/004_HC.png
#   inflating: training_set/004_HC_Annotation.png
#  extracting: training_set/005_HC.png
#   inflating: training_set/005_HC_Annotation.png
#  extracting: training_set/006_HC.png
#   inflating: training_set/006_HC_Annotation.png
#  extracting: training_set/007_HC.png
#   inflating: training_set/007_HC_Annotation.png
#  extracting: training_set/008_HC.png
#   inflating: training_set/008_HC_Annotation.png
#  extracting: training_set/009_HC.png
#   inflating: training_set/009_HC_Annotation.png
#  extracting: training_set/010_2HC.png
#   inflating: training_set/010_2HC_Annotation.png
#  extracting: training_set/010_HC.png
#   inflating: training_set/010_HC_Annotation.png
#  extracting: training_set/011_HC.png
#   inflating: training_set/011_HC_Annotation.png
#  extracting: training_set/012_HC.png
#   inflating: training_set/012_HC_Annotation.png
#  extracting: training_set/013_HC.png
#   inflating: training_set/013_HC_Annotation.png
#  extracting: training_set/014_2HC.png
#   inflating: training_set/014_2HC_Annotation.png
#  extracting: training_set/014_3HC.png
#   inflating: training_set/014_3HC_Annotation.png
#  extracting: training_set/014_HC.png
#   inflating: training_set/014_HC_Annotation.png
#  extracting: training_set/015_HC.png
#   inflating: training_set/015_HC_Annotation.png
#  extracting: training_set/016_HC.png
#   inflating: training_set/016_HC_Annotation.png
#  extracting: training_set/017_2HC.png
#   inflating: training_set/017_2HC_Annotation.png
#  extracting: training_set/017_HC.png
#   inflating: training_set/017_HC_Annotation.png
#  extracting: training_set/018_HC.png
#   inflating: training_set/018_HC_Annotation.png
#  extracting: training_set/019_2HC.png
#   inflating: training_set/019_2HC_Annotation.png
#  extracting: training_set/019_HC.png
#   inflating: training_set/019_HC_Annotation.png
#  extracting: training_set/020_HC.png
#   inflating: training_set/020_HC_Annotation.png
#  extracting: training_set/021_HC.png
#   inflating: training_set/021_HC_Annotation.png
#  extracting: training_set/022_2HC.png
#   inflating: training_set/022_2HC_Annotation.png
#  extracting: training_set/022_HC.png
#   inflating: training_set/022_HC_Annotation.png
#  extracting: training_set/023_2HC.png
#   inflating: training_set/023_2HC_Annotation.png
#  extracting: training_set/023_HC.png
#   inflating: training_set/023_HC_Annotation.png
#  extracting: training_set/024_HC.png
#   inflating: training_set/024_HC_Annotation.png
#  extracting: training_set/025_HC.png
#   inflating: training_set/025_HC_Annotation.png
#  extracting: training_set/026_2HC.png
#   inflating: training_set/026_2HC_Annotation.png
#  extracting: training_set/026_HC.png
#   inflating: training_set/026_HC_Annotation.png
#  extracting: training_set/027_HC.png
#   inflating: training_set/027_HC_Annotation.png
#  extracting: training_set/028_HC.png
#   inflating: training_set/028_HC_Annotation.png
#  extracting: training_set/029_HC.png
#   inflating: training_set/029_HC_Annotation.png
#  extracting: training_set/030_HC.png
#   inflating: training_set/030_HC_Annotation.png
#  extracting: training_set/031_HC.png
#   inflating: training_set/031_HC_Annotation.png
#  extracting: training_set/032_2HC.png
#   inflating: training_set/032_2HC_Annotation.png
#  extracting: training_set/032_HC.png
#   inflating: training_set/032_HC_Annotation.png
#  extracting: training_set/033_2HC.png
#   inflating: training_set/033_2HC_Annotation.png
#  extracting: training_set/033_HC.png
#   inflating: training_set/033_HC_Annotation.png
#  extracting: training_set/034_HC.png
#   inflating: training_set/034_HC_Annotation.png
#  extracting: training_set/035_HC.png
#   inflating: training_set/035_HC_Annotation.png
#  extracting: training_set/036_HC.png
#   inflating: training_set/036_HC_Annotation.png
#  extracting: training_set/037_HC.png
#   inflating: training_set/037_HC_Annotation.png
#  extracting: training_set/038_HC.png
#   inflating: training_set/038_HC_Annotation.png
#  extracting: training_set/039_HC.png
#   inflating: training_set/039_HC_Annotation.png
#  extracting: training_set/040_HC.png
#   inflating: training_set/040_HC_Annotation.png
#  extracting: training_set/041_HC.png
#   inflating: training_set/041_HC_Annotation.png
#  extracting: training_set/042_HC.png
#   inflating: training_set/042_HC_Annotation.png
#  extracting: training_set/043_HC.png
#   inflating: training_set/043_HC_Annotation.png
#  extracting: training_set/044_HC.png
#   inflating: training_set/044_HC_Annotation.png
#  extracting: training_set/045_HC.png
#   inflating: training_set/045_HC_Annotation.png
#  extracting: training_set/046_HC.png
#   inflating: training_set/046_HC_Annotation.png
#  extracting: training_set/047_HC.png
#   inflating: training_set/047_HC_Annotation.png
#  extracting: training_set/048_HC.png
#   inflating: training_set/048_HC_Annotation.png
#  extracting: training_set/049_HC.png
#   inflating: training_set/049_HC_Annotation.png
#  extracting: training_set/050_2HC.png
#   inflating: training_set/050_2HC_Annotation.png
#  extracting: training_set/050_HC.png
#   inflating: training_set/050_HC_Annotation.png
#  extracting: training_set/051_HC.png
#   inflating: training_set/051_HC_Annotation.png
#  extracting: training_set/052_HC.png
#   inflating: training_set/052_HC_Annotation.png
#  extracting: training_set/053_HC.png
#   inflating: training_set/053_HC_Annotation.png
#  extracting: training_set/054_HC.png
#   inflating: training_set/054_HC_Annotation.png
#  extracting: training_set/055_HC.png
#   inflating: training_set/055_HC_Annotation.png
#  extracting: training_set/056_HC.png
#   inflating: training_set/056_HC_Annotation.png
#  extracting: training_set/057_HC.png
#   inflating: training_set/057_HC_Annotation.png
#  extracting: training_set/058_HC.png
#   inflating: training_set/058_HC_Annotation.png
#  extracting: training_set/059_HC.png
#   inflating: training_set/059_HC_Annotation.png
#  extracting: training_set/060_HC.png
#   inflating: training_set/060_HC_Annotation.png
#  extracting: training_set/061_2HC.png
#   inflating: training_set/061_2HC_Annotation.png
#  extracting: training_set/061_HC.png
#   inflating: training_set/061_HC_Annotation.png
#  extracting: training_set/062_HC.png
#   inflating: training_set/062_HC_Annotation.png
#  extracting: training_set/063_2HC.png
#   inflating: training_set/063_2HC_Annotation.png
#  extracting: training_set/063_3HC.png
#   inflating: training_set/063_3HC_Annotation.png
#  extracting: training_set/063_HC.png
#   inflating: training_set/063_HC_Annotation.png
#  extracting: training_set/064_2HC.png
#   inflating: training_set/064_2HC_Annotation.png
#  extracting: training_set/064_HC.png
#   inflating: training_set/064_HC_Annotation.png
#  extracting: training_set/065_HC.png
#   inflating: training_set/065_HC_Annotation.png
#  extracting: training_set/066_2HC.png
#   inflating: training_set/066_2HC_Annotation.png
#  extracting: training_set/066_HC.png
#   inflating: training_set/066_HC_Annotation.png
#  extracting: training_set/067_HC.png
#   inflating: training_set/067_HC_Annotation.png
#  extracting: training_set/068_2HC.png
#   inflating: training_set/068_2HC_Annotation.png
#  extracting: training_set/068_HC.png
#   inflating: training_set/068_HC_Annotation.png
#  extracting: training_set/069_HC.png
#   inflating: training_set/069_HC_Annotation.png
#  extracting: training_set/070_HC.png
#   inflating: training_set/070_HC_Annotation.png
#  extracting: training_set/071_HC.png
#   inflating: training_set/071_HC_Annotation.png
#  extracting: training_set/072_HC.png
#   inflating: training_set/072_HC_Annotation.png
#  extracting: training_set/073_HC.png
#   inflating: training_set/073_HC_Annotation.png
#  extracting: training_set/074_HC.png
#   inflating: training_set/074_HC_Annotation.png
#  extracting: training_set/075_HC.png
#   inflating: training_set/075_HC_Annotation.png
#  extracting: training_set/076_HC.png
#   inflating: training_set/076_HC_Annotation.png
#  extracting: training_set/077_HC.png
#   inflating: training_set/077_HC_Annotation.png
#  extracting: training_set/078_HC.png
#   inflating: training_set/078_HC_Annotation.png
#  extracting: training_set/079_HC.png
#   inflating: training_set/079_HC_Annotation.png
#  extracting: training_set/080_HC.png
#   inflating: training_set/080_HC_Annotation.png
#  extracting: training_set/081_HC.png
#   inflating: training_set/081_HC_Annotation.png
#  extracting: training_set/082_2HC.png
#   inflating: training_set/082_2HC_Annotation.png
#  extracting: training_set/082_HC.png
#   inflating: training_set/082_HC_Annotation.png
#  extracting: training_set/083_2HC.png
#   inflating: training_set/083_2HC_Annotation.png
#  extracting: training_set/083_HC.png
#   inflating: training_set/083_HC_Annotation.png
#  extracting: training_set/084_HC.png
#   inflating: training_set/084_HC_Annotation.png
#  extracting: training_set/085_HC.png
#   inflating: training_set/085_HC_Annotation.png
#  extracting: training_set/086_HC.png
#   inflating: training_set/086_HC_Annotation.png
#  extracting: training_set/087_HC.png
#   inflating: training_set/087_HC_Annotation.png
#  extracting: training_set/088_2HC.png
#   inflating: training_set/088_2HC_Annotation.png
#  extracting: training_set/088_HC.png
#   inflating: training_set/088_HC_Annotation.png
#  extracting: training_set/089_HC.png
#   inflating: training_set/089_HC_Annotation.png
#  extracting: training_set/090_HC.png
#   inflating: training_set/090_HC_Annotation.png
#  extracting: training_set/091_HC.png
#   inflating: training_set/091_HC_Annotation.png
#  extracting: training_set/092_HC.png
#   inflating: training_set/092_HC_Annotation.png
#  extracting: training_set/093_2HC.png
#   inflating: training_set/093_2HC_Annotation.png
#  extracting: training_set/093_HC.png
#   inflating: training_set/093_HC_Annotation.png
#  extracting: training_set/094_HC.png
#   inflating: training_set/094_HC_Annotation.png
#  extracting: training_set/095_HC.png
#   inflating: training_set/095_HC_Annotation.png
#  extracting: training_set/096_HC.png
#   inflating: training_set/096_HC_Annotation.png
#  extracting: training_set/097_HC.png
#   inflating: training_set/097_HC_Annotation.png
#  extracting: training_set/098_HC.png
#   inflating: training_set/098_HC_Annotation.png
#  extracting: training_set/099_HC.png
#   inflating: training_set/099_HC_Annotation.png
#  extracting: training_set/100_2HC.png
#   inflating: training_set/100_2HC_Annotation.png
#  extracting: training_set/100_HC.png
#   inflating: training_set/100_HC_Annotation.png
#  extracting: training_set/101_HC.png
#   inflating: training_set/101_HC_Annotation.png
#  extracting: training_set/102_2HC.png
#   inflating: training_set/102_2HC_Annotation.png
#  extracting: training_set/102_HC.png
#   inflating: training_set/102_HC_Annotation.png
#  extracting: training_set/103_HC.png
#   inflating: training_set/103_HC_Annotation.png
#  extracting: training_set/104_HC.png
#   inflating: training_set/104_HC_Annotation.png
#  extracting: training_set/105_HC.png
#   inflating: training_set/105_HC_Annotation.png
#  extracting: training_set/106_HC.png
#   inflating: training_set/106_HC_Annotation.png
#  extracting: training_set/107_2HC.png
#   inflating: training_set/107_2HC_Annotation.png
#  extracting: training_set/107_HC.png
#   inflating: training_set/107_HC_Annotation.png
#  extracting: training_set/108_2HC.png
#   inflating: training_set/108_2HC_Annotation.png
#  extracting: training_set/108_3HC.png
#   inflating: training_set/108_3HC_Annotation.png
#   inflating: training_set/108_HC.png
#   inflating: training_set/108_HC_Annotation.png
#  extracting: training_set/109_HC.png
#   inflating: training_set/109_HC_Annotation.png
#   inflating: training_set/110_HC.png
#   inflating: training_set/110_HC_Annotation.png
#  extracting: training_set/111_HC.png
#   inflating: training_set/111_HC_Annotation.png
#  extracting: training_set/112_HC.png
#   inflating: training_set/112_HC_Annotation.png
#  extracting: training_set/113_HC.png
#   inflating: training_set/113_HC_Annotation.png
#  extracting: training_set/114_HC.png
#   inflating: training_set/114_HC_Annotation.png
#  extracting: training_set/115_HC.png
#   inflating: training_set/115_HC_Annotation.png
#  extracting: training_set/116_HC.png
#   inflating: training_set/116_HC_Annotation.png
#  extracting: training_set/117_HC.png
#   inflating: training_set/117_HC_Annotation.png
#  extracting: training_set/118_HC.png
#   inflating: training_set/118_HC_Annotation.png
#  extracting: training_set/119_HC.png
#   inflating: training_set/119_HC_Annotation.png
#  extracting: training_set/120_HC.png
#   inflating: training_set/120_HC_Annotation.png
#  extracting: training_set/121_2HC.png
#   inflating: training_set/121_2HC_Annotation.png
#  extracting: training_set/121_HC.png
#   inflating: training_set/121_HC_Annotation.png
#  extracting: training_set/122_HC.png
#   inflating: training_set/122_HC_Annotation.png
#  extracting: training_set/123_HC.png
#   inflating: training_set/123_HC_Annotation.png
#  extracting: training_set/124_2HC.png
#   inflating: training_set/124_2HC_Annotation.png
#  extracting: training_set/124_HC.png
#   inflating: training_set/124_HC_Annotation.png
#  extracting: training_set/125_2HC.png
#   inflating: training_set/125_2HC_Annotation.png
#  extracting: training_set/125_3HC.png
#   inflating: training_set/125_3HC_Annotation.png
#  extracting: training_set/125_HC.png
#   inflating: training_set/125_HC_Annotation.png
#  extracting: training_set/126_2HC.png
#   inflating: training_set/126_2HC_Annotation.png
#  extracting: training_set/126_3HC.png
#   inflating: training_set/126_3HC_Annotation.png
#  extracting: training_set/126_HC.png
#   inflating: training_set/126_HC_Annotation.png
#  extracting: training_set/127_HC.png
#   inflating: training_set/127_HC_Annotation.png
#  extracting: training_set/128_HC.png
#   inflating: training_set/128_HC_Annotation.png
#  extracting: training_set/129_HC.png
#   inflating: training_set/129_HC_Annotation.png
#  extracting: training_set/130_HC.png
#   inflating: training_set/130_HC_Annotation.png
#  extracting: training_set/131_HC.png
#   inflating: training_set/131_HC_Annotation.png
#  extracting: training_set/132_HC.png
#   inflating: training_set/132_HC_Annotation.png
#  extracting: training_set/133_2HC.png
#   inflating: training_set/133_2HC_Annotation.png
#  extracting: training_set/133_3HC.png
#   inflating: training_set/133_3HC_Annotation.png
#  extracting: training_set/133_4HC.png
#   inflating: training_set/133_4HC_Annotation.png
#  extracting: training_set/133_HC.png
#   inflating: training_set/133_HC_Annotation.png
#  extracting: training_set/134_HC.png
#   inflating: training_set/134_HC_Annotation.png
#  extracting: training_set/135_HC.png
#   inflating: training_set/135_HC_Annotation.png
#  extracting: training_set/136_2HC.png
#   inflating: training_set/136_2HC_Annotation.png
#  extracting: training_set/136_HC.png
#   inflating: training_set/136_HC_Annotation.png
#  extracting: training_set/137_HC.png
#   inflating: training_set/137_HC_Annotation.png
#  extracting: training_set/138_2HC.png
#   inflating: training_set/138_2HC_Annotation.png
#  extracting: training_set/138_HC.png
#   inflating: training_set/138_HC_Annotation.png
#  extracting: training_set/139_HC.png
#   inflating: training_set/139_HC_Annotation.png
#  extracting: training_set/140_HC.png
#   inflating: training_set/140_HC_Annotation.png
#  extracting: training_set/141_2HC.png
#   inflating: training_set/141_2HC_Annotation.png
#  extracting: training_set/141_HC.png
#   inflating: training_set/141_HC_Annotation.png
#  extracting: training_set/142_HC.png
#   inflating: training_set/142_HC_Annotation.png
#  extracting: training_set/143_2HC.png
#   inflating: training_set/143_2HC_Annotation.png
#  extracting: training_set/143_HC.png
#   inflating: training_set/143_HC_Annotation.png
#  extracting: training_set/144_2HC.png
#   inflating: training_set/144_2HC_Annotation.png
#  extracting: training_set/144_HC.png
#   inflating: training_set/144_HC_Annotation.png
#  extracting: training_set/145_HC.png
#   inflating: training_set/145_HC_Annotation.png
#  extracting: training_set/146_2HC.png
#   inflating: training_set/146_2HC_Annotation.png
#  extracting: training_set/146_HC.png
#   inflating: training_set/146_HC_Annotation.png
#  extracting: training_set/147_HC.png
#   inflating: training_set/147_HC_Annotation.png
#  extracting: training_set/148_HC.png
#   inflating: training_set/148_HC_Annotation.png
#  extracting: training_set/149_HC.png
#   inflating: training_set/149_HC_Annotation.png
#  extracting: training_set/150_HC.png
#   inflating: training_set/150_HC_Annotation.png
#  extracting: training_set/151_HC.png
#   inflating: training_set/151_HC_Annotation.png
#  extracting: training_set/152_HC.png
#   inflating: training_set/152_HC_Annotation.png
#  extracting: training_set/153_HC.png
#   inflating: training_set/153_HC_Annotation.png
#  extracting: training_set/154_HC.png
#   inflating: training_set/154_HC_Annotation.png
#  extracting: training_set/155_HC.png
#   inflating: training_set/155_HC_Annotation.png
#  extracting: training_set/156_2HC.png
#   inflating: training_set/156_2HC_Annotation.png
#  extracting: training_set/156_HC.png
#   inflating: training_set/156_HC_Annotation.png
#  extracting: training_set/157_HC.png
#   inflating: training_set/157_HC_Annotation.png
#  extracting: training_set/158_HC.png
#   inflating: training_set/158_HC_Annotation.png
#  extracting: training_set/159_HC.png
#   inflating: training_set/159_HC_Annotation.png
#  extracting: training_set/160_HC.png
#   inflating: training_set/160_HC_Annotation.png
#  extracting: training_set/161_HC.png
#   inflating: training_set/161_HC_Annotation.png
#  extracting: training_set/162_HC.png
#   inflating: training_set/162_HC_Annotation.png
#  extracting: training_set/163_HC.png
#   inflating: training_set/163_HC_Annotation.png
#  extracting: training_set/164_2HC.png
#   inflating: training_set/164_2HC_Annotation.png
#  extracting: training_set/164_HC.png
#   inflating: training_set/164_HC_Annotation.png
#  extracting: training_set/165_HC.png
#   inflating: training_set/165_HC_Annotation.png
#   inflating: training_set/166_HC.png
#   inflating: training_set/166_HC_Annotation.png
#  extracting: training_set/167_HC.png
#   inflating: training_set/167_HC_Annotation.png
#  extracting: training_set/168_HC.png
#   inflating: training_set/168_HC_Annotation.png
#  extracting: training_set/169_HC.png
#   inflating: training_set/169_HC_Annotation.png
#  extracting: training_set/170_HC.png
#   inflating: training_set/170_HC_Annotation.png
#  extracting: training_set/171_HC.png
#   inflating: training_set/171_HC_Annotation.png
#  extracting: training_set/172_HC.png
#   inflating: training_set/172_HC_Annotation.png
#  extracting: training_set/173_HC.png
#   inflating: training_set/173_HC_Annotation.png
#  extracting: training_set/174_HC.png
#   inflating: training_set/174_HC_Annotation.png
#  extracting: training_set/175_HC.png
#   inflating: training_set/175_HC_Annotation.png
#  extracting: training_set/176_HC.png
#   inflating: training_set/176_HC_Annotation.png
#  extracting: training_set/177_HC.png
#   inflating: training_set/177_HC_Annotation.png
#  extracting: training_set/178_2HC.png
#   inflating: training_set/178_2HC_Annotation.png
#  extracting: training_set/178_HC.png
#   inflating: training_set/178_HC_Annotation.png
#  extracting: training_set/179_HC.png
#   inflating: training_set/179_HC_Annotation.png
#  extracting: training_set/180_HC.png
#   inflating: training_set/180_HC_Annotation.png
#  extracting: training_set/181_HC.png
#   inflating: training_set/181_HC_Annotation.png
#  extracting: training_set/182_HC.png
#   inflating: training_set/182_HC_Annotation.png
#  extracting: training_set/183_HC.png
#   inflating: training_set/183_HC_Annotation.png
#  extracting: training_set/184_HC.png
#   inflating: training_set/184_HC_Annotation.png
#  extracting: training_set/185_HC.png
#   inflating: training_set/185_HC_Annotation.png
#  extracting: training_set/186_HC.png
#   inflating: training_set/186_HC_Annotation.png
#  extracting: training_set/187_HC.png
#   inflating: training_set/187_HC_Annotation.png
#  extracting: training_set/188_HC.png
#   inflating: training_set/188_HC_Annotation.png
#  extracting: training_set/189_HC.png
#   inflating: training_set/189_HC_Annotation.png
#  extracting: training_set/190_HC.png
#   inflating: training_set/190_HC_Annotation.png
#  extracting: training_set/191_HC.png
#   inflating: training_set/191_HC_Annotation.png
#  extracting: training_set/192_2HC.png
#   inflating: training_set/192_2HC_Annotation.png
#  extracting: training_set/192_HC.png
#   inflating: training_set/192_HC_Annotation.png
#  extracting: training_set/193_2HC.png
#   inflating: training_set/193_2HC_Annotation.png
#  extracting: training_set/193_HC.png
#   inflating: training_set/193_HC_Annotation.png
#  extracting: training_set/194_HC.png
#   inflating: training_set/194_HC_Annotation.png
#  extracting: training_set/195_2HC.png
#   inflating: training_set/195_2HC_Annotation.png
#  extracting: training_set/195_HC.png
#   inflating: training_set/195_HC_Annotation.png
#  extracting: training_set/196_HC.png
#   inflating: training_set/196_HC_Annotation.png
#  extracting: training_set/197_HC.png
#   inflating: training_set/197_HC_Annotation.png
#  extracting: training_set/198_2HC.png
#   inflating: training_set/198_2HC_Annotation.png
#  extracting: training_set/198_HC.png
#   inflating: training_set/198_HC_Annotation.png
#  extracting: training_set/199_HC.png
#   inflating: training_set/199_HC_Annotation.png
#   inflating: training_set/200_HC.png
#   inflating: training_set/200_HC_Annotation.png
#  extracting: training_set/201_HC.png
#   inflating: training_set/201_HC_Annotation.png
#  extracting: training_set/202_HC.png
#   inflating: training_set/202_HC_Annotation.png
#  extracting: training_set/203_2HC.png
#   inflating: training_set/203_2HC_Annotation.png
#  extracting: training_set/203_3HC.png
#   inflating: training_set/203_3HC_Annotation.png
#  extracting: training_set/203_4HC.png
#   inflating: training_set/203_4HC_Annotation.png
#  extracting: training_set/203_HC.png
#   inflating: training_set/203_HC_Annotation.png
#  extracting: training_set/204_HC.png
#   inflating: training_set/204_HC_Annotation.png
#  extracting: training_set/205_HC.png
#   inflating: training_set/205_HC_Annotation.png
#  extracting: training_set/206_HC.png
#   inflating: training_set/206_HC_Annotation.png
#  extracting: training_set/207_HC.png
#   inflating: training_set/207_HC_Annotation.png
#  extracting: training_set/208_HC.png
#   inflating: training_set/208_HC_Annotation.png
#  extracting: training_set/209_HC.png
#   inflating: training_set/209_HC_Annotation.png
#  extracting: training_set/210_2HC.png
#   inflating: training_set/210_2HC_Annotation.png
#  extracting: training_set/210_HC.png
#   inflating: training_set/210_HC_Annotation.png
#  extracting: training_set/211_HC.png
#   inflating: training_set/211_HC_Annotation.png
#  extracting: training_set/212_HC.png
#   inflating: training_set/212_HC_Annotation.png
#  extracting: training_set/213_2HC.png
#   inflating: training_set/213_2HC_Annotation.png
#  extracting: training_set/213_HC.png
#   inflating: training_set/213_HC_Annotation.png
#  extracting: training_set/214_HC.png
#   inflating: training_set/214_HC_Annotation.png
#   inflating: training_set/215_HC.png
#   inflating: training_set/215_HC_Annotation.png
#   inflating: training_set/216_HC.png
#   inflating: training_set/216_HC_Annotation.png
#  extracting: training_set/217_HC.png
#   inflating: training_set/217_HC_Annotation.png
#  extracting: training_set/218_HC.png
#   inflating: training_set/218_HC_Annotation.png
#  extracting: training_set/219_HC.png
#   inflating: training_set/219_HC_Annotation.png
#  extracting: training_set/220_2HC.png
#   inflating: training_set/220_2HC_Annotation.png
#  extracting: training_set/220_HC.png
#   inflating: training_set/220_HC_Annotation.png
#  extracting: training_set/221_HC.png
#   inflating: training_set/221_HC_Annotation.png
#  extracting: training_set/222_HC.png
#   inflating: training_set/222_HC_Annotation.png
#  extracting: training_set/223_2HC.png
#   inflating: training_set/223_2HC_Annotation.png
#  extracting: training_set/223_HC.png
#   inflating: training_set/223_HC_Annotation.png
#  extracting: training_set/224_HC.png
#   inflating: training_set/224_HC_Annotation.png
#  extracting: training_set/225_2HC.png
#   inflating: training_set/225_2HC_Annotation.png
#  extracting: training_set/225_HC.png
#   inflating: training_set/225_HC_Annotation.png
#  extracting: training_set/226_HC.png
#   inflating: training_set/226_HC_Annotation.png
#  extracting: training_set/227_2HC.png
#   inflating: training_set/227_2HC_Annotation.png
#  extracting: training_set/227_HC.png
#   inflating: training_set/227_HC_Annotation.png
#  extracting: training_set/228_HC.png
#   inflating: training_set/228_HC_Annotation.png
#  extracting: training_set/229_2HC.png
#   inflating: training_set/229_2HC_Annotation.png
#  extracting: training_set/229_HC.png
#   inflating: training_set/229_HC_Annotation.png
#  extracting: training_set/230_2HC.png
#   inflating: training_set/230_2HC_Annotation.png
#  extracting: training_set/230_HC.png
#   inflating: training_set/230_HC_Annotation.png
#  extracting: training_set/231_HC.png
#   inflating: training_set/231_HC_Annotation.png
#  extracting: training_set/232_HC.png
#   inflating: training_set/232_HC_Annotation.png
#  extracting: training_set/233_HC.png
#   inflating: training_set/233_HC_Annotation.png
#   inflating: training_set/234_HC.png
#   inflating: training_set/234_HC_Annotation.png
#  extracting: training_set/235_2HC.png
#   inflating: training_set/235_2HC_Annotation.png
#  extracting: training_set/235_HC.png
#   inflating: training_set/235_HC_Annotation.png
#  extracting: training_set/236_HC.png
#   inflating: training_set/236_HC_Annotation.png
#  extracting: training_set/237_2HC.png
#   inflating: training_set/237_2HC_Annotation.png
#  extracting: training_set/237_3HC.png
#   inflating: training_set/237_3HC_Annotation.png
#  extracting: training_set/237_HC.png
#   inflating: training_set/237_HC_Annotation.png
#  extracting: training_set/238_HC.png
#   inflating: training_set/238_HC_Annotation.png
#  extracting: training_set/239_HC.png
#   inflating: training_set/239_HC_Annotation.png
#  extracting: training_set/240_HC.png
#   inflating: training_set/240_HC_Annotation.png
#  extracting: training_set/241_HC.png
#   inflating: training_set/241_HC_Annotation.png
#  extracting: training_set/242_HC.png
#   inflating: training_set/242_HC_Annotation.png
#  extracting: training_set/243_2HC.png
#   inflating: training_set/243_2HC_Annotation.png
#   inflating: training_set/243_3HC.png
#   inflating: training_set/243_3HC_Annotation.png
#   inflating: training_set/243_HC.png
#   inflating: training_set/243_HC_Annotation.png
#  extracting: training_set/244_HC.png
#   inflating: training_set/244_HC_Annotation.png
#  extracting: training_set/245_2HC.png
#   inflating: training_set/245_2HC_Annotation.png
#  extracting: training_set/245_3HC.png
#   inflating: training_set/245_3HC_Annotation.png
#  extracting: training_set/245_HC.png
#   inflating: training_set/245_HC_Annotation.png
#  extracting: training_set/246_HC.png
#   inflating: training_set/246_HC_Annotation.png
#  extracting: training_set/247_HC.png
#   inflating: training_set/247_HC_Annotation.png
#  extracting: training_set/248_HC.png
#   inflating: training_set/248_HC_Annotation.png
#  extracting: training_set/249_HC.png
#   inflating: training_set/249_HC_Annotation.png
#  extracting: training_set/250_HC.png
#   inflating: training_set/250_HC_Annotation.png
#  extracting: training_set/251_HC.png
#   inflating: training_set/251_HC_Annotation.png
#  extracting: training_set/252_HC.png
#   inflating: training_set/252_HC_Annotation.png
#  extracting: training_set/253_HC.png
#   inflating: training_set/253_HC_Annotation.png
#  extracting: training_set/254_HC.png
#   inflating: training_set/254_HC_Annotation.png
#  extracting: training_set/255_HC.png
#   inflating: training_set/255_HC_Annotation.png
#  extracting: training_set/256_HC.png
#   inflating: training_set/256_HC_Annotation.png
#  extracting: training_set/257_HC.png
#   inflating: training_set/257_HC_Annotation.png
#  extracting: training_set/258_HC.png
#   inflating: training_set/258_HC_Annotation.png
#  extracting: training_set/259_HC.png
#   inflating: training_set/259_HC_Annotation.png
#  extracting: training_set/260_2HC.png
#   inflating: training_set/260_2HC_Annotation.png
#  extracting: training_set/260_HC.png
#   inflating: training_set/260_HC_Annotation.png
#  extracting: training_set/261_HC.png
#   inflating: training_set/261_HC_Annotation.png
#  extracting: training_set/262_HC.png
#   inflating: training_set/262_HC_Annotation.png
#  extracting: training_set/263_HC.png
#   inflating: training_set/263_HC_Annotation.png
#  extracting: training_set/264_HC.png
#   inflating: training_set/264_HC_Annotation.png
#  extracting: training_set/265_HC.png
#   inflating: training_set/265_HC_Annotation.png
#  extracting: training_set/266_HC.png
#   inflating: training_set/266_HC_Annotation.png
#  extracting: training_set/267_HC.png
#   inflating: training_set/267_HC_Annotation.png
#  extracting: training_set/268_HC.png
#   inflating: training_set/268_HC_Annotation.png
#  extracting: training_set/269_HC.png
#   inflating: training_set/269_HC_Annotation.png
#   inflating: training_set/270_HC.png
#   inflating: training_set/270_HC_Annotation.png
#  extracting: training_set/271_2HC.png
#   inflating: training_set/271_2HC_Annotation.png
#  extracting: training_set/271_HC.png
#   inflating: training_set/271_HC_Annotation.png
#  extracting: training_set/272_HC.png
#   inflating: training_set/272_HC_Annotation.png
#  extracting: training_set/273_HC.png
#   inflating: training_set/273_HC_Annotation.png
#  extracting: training_set/274_HC.png
#   inflating: training_set/274_HC_Annotation.png
#  extracting: training_set/275_HC.png
#   inflating: training_set/275_HC_Annotation.png
#  extracting: training_set/276_2HC.png
#   inflating: training_set/276_2HC_Annotation.png
#  extracting: training_set/276_HC.png
#   inflating: training_set/276_HC_Annotation.png
#  extracting: training_set/277_HC.png
#   inflating: training_set/277_HC_Annotation.png
#  extracting: training_set/278_2HC.png
#   inflating: training_set/278_2HC_Annotation.png
#  extracting: training_set/278_HC.png
#   inflating: training_set/278_HC_Annotation.png
#  extracting: training_set/279_HC.png
#   inflating: training_set/279_HC_Annotation.png
#  extracting: training_set/280_HC.png
#   inflating: training_set/280_HC_Annotation.png
#  extracting: training_set/281_HC.png
#   inflating: training_set/281_HC_Annotation.png
#  extracting: training_set/282_HC.png
#   inflating: training_set/282_HC_Annotation.png
#  extracting: training_set/283_HC.png
#   inflating: training_set/283_HC_Annotation.png
#  extracting: training_set/284_HC.png
#   inflating: training_set/284_HC_Annotation.png
#  extracting: training_set/285_HC.png
#   inflating: training_set/285_HC_Annotation.png
#  extracting: training_set/286_HC.png
#   inflating: training_set/286_HC_Annotation.png
#  extracting: training_set/287_HC.png
#   inflating: training_set/287_HC_Annotation.png
#  extracting: training_set/288_HC.png
#   inflating: training_set/288_HC_Annotation.png
#  extracting: training_set/289_HC.png
#   inflating: training_set/289_HC_Annotation.png
#  extracting: training_set/290_HC.png
#   inflating: training_set/290_HC_Annotation.png
#  extracting: training_set/291_2HC.png
#   inflating: training_set/291_2HC_Annotation.png
#  extracting: training_set/291_HC.png
#   inflating: training_set/291_HC_Annotation.png
#  extracting: training_set/292_HC.png
#   inflating: training_set/292_HC_Annotation.png
#  extracting: training_set/293_HC.png
#   inflating: training_set/293_HC_Annotation.png
#  extracting: training_set/294_2HC.png
#   inflating: training_set/294_2HC_Annotation.png
#  extracting: training_set/294_HC.png
#   inflating: training_set/294_HC_Annotation.png
#  extracting: training_set/295_HC.png
#   inflating: training_set/295_HC_Annotation.png
#  extracting: training_set/296_HC.png
#   inflating: training_set/296_HC_Annotation.png
#  extracting: training_set/297_HC.png
#   inflating: training_set/297_HC_Annotation.png
#  extracting: training_set/298_HC.png
#   inflating: training_set/298_HC_Annotation.png
#  extracting: training_set/299_2HC.png
#   inflating: training_set/299_2HC_Annotation.png
#  extracting: training_set/299_HC.png
#   inflating: training_set/299_HC_Annotation.png
#  extracting: training_set/300_2HC.png
#   inflating: training_set/300_2HC_Annotation.png
#  extracting: training_set/300_HC.png
#   inflating: training_set/300_HC_Annotation.png
#  extracting: training_set/301_HC.png
#   inflating: training_set/301_HC_Annotation.png
#  extracting: training_set/302_HC.png
#   inflating: training_set/302_HC_Annotation.png
#  extracting: training_set/303_HC.png
#   inflating: training_set/303_HC_Annotation.png
#  extracting: training_set/304_HC.png
#   inflating: training_set/304_HC_Annotation.png
#  extracting: training_set/305_HC.png
#   inflating: training_set/305_HC_Annotation.png
#  extracting: training_set/306_HC.png
#   inflating: training_set/306_HC_Annotation.png
#  extracting: training_set/307_HC.png
#   inflating: training_set/307_HC_Annotation.png
#  extracting: training_set/308_HC.png
#   inflating: training_set/308_HC_Annotation.png
#  extracting: training_set/309_HC.png
#   inflating: training_set/309_HC_Annotation.png
#  extracting: training_set/310_HC.png
#   inflating: training_set/310_HC_Annotation.png
#  extracting: training_set/311_HC.png
#   inflating: training_set/311_HC_Annotation.png
#  extracting: training_set/312_2HC.png
#   inflating: training_set/312_2HC_Annotation.png
#  extracting: training_set/312_HC.png
#   inflating: training_set/312_HC_Annotation.png
#  extracting: training_set/313_HC.png
#   inflating: training_set/313_HC_Annotation.png
#  extracting: training_set/314_HC.png
#   inflating: training_set/314_HC_Annotation.png
#  extracting: training_set/315_2HC.png
#   inflating: training_set/315_2HC_Annotation.png
#  extracting: training_set/315_HC.png
#   inflating: training_set/315_HC_Annotation.png
#  extracting: training_set/316_HC.png
#   inflating: training_set/316_HC_Annotation.png
#  extracting: training_set/317_HC.png
#   inflating: training_set/317_HC_Annotation.png
#  extracting: training_set/318_HC.png
#   inflating: training_set/318_HC_Annotation.png
#  extracting: training_set/319_HC.png
#   inflating: training_set/319_HC_Annotation.png
#  extracting: training_set/320_HC.png
#   inflating: training_set/320_HC_Annotation.png
#  extracting: training_set/321_HC.png
#   inflating: training_set/321_HC_Annotation.png
#  extracting: training_set/322_HC.png
#   inflating: training_set/322_HC_Annotation.png
#  extracting: training_set/323_2HC.png
#   inflating: training_set/323_2HC_Annotation.png
#  extracting: training_set/323_HC.png
#   inflating: training_set/323_HC_Annotation.png
#  extracting: training_set/324_HC.png
#   inflating: training_set/324_HC_Annotation.png
#  extracting: training_set/325_HC.png
#   inflating: training_set/325_HC_Annotation.png
#  extracting: training_set/326_HC.png
#   inflating: training_set/326_HC_Annotation.png
#  extracting: training_set/327_2HC.png
#   inflating: training_set/327_2HC_Annotation.png
#  extracting: training_set/327_HC.png
#   inflating: training_set/327_HC_Annotation.png
#  extracting: training_set/328_HC.png
#   inflating: training_set/328_HC_Annotation.png
#  extracting: training_set/329_HC.png
#   inflating: training_set/329_HC_Annotation.png
#  extracting: training_set/330_HC.png
#   inflating: training_set/330_HC_Annotation.png
#  extracting: training_set/331_HC.png
#   inflating: training_set/331_HC_Annotation.png
#  extracting: training_set/332_HC.png
#   inflating: training_set/332_HC_Annotation.png
#  extracting: training_set/333_HC.png
#   inflating: training_set/333_HC_Annotation.png
#  extracting: training_set/334_HC.png
#   inflating: training_set/334_HC_Annotation.png
#  extracting: training_set/335_HC.png
#   inflating: training_set/335_HC_Annotation.png
#  extracting: training_set/336_HC.png
#   inflating: training_set/336_HC_Annotation.png
#  extracting: training_set/337_HC.png
#   inflating: training_set/337_HC_Annotation.png
#  extracting: training_set/338_HC.png
#   inflating: training_set/338_HC_Annotation.png
#  extracting: training_set/339_HC.png
#   inflating: training_set/339_HC_Annotation.png
#  extracting: training_set/340_2HC.png
#   inflating: training_set/340_2HC_Annotation.png
#  extracting: training_set/340_HC.png
#   inflating: training_set/340_HC_Annotation.png
#  extracting: training_set/341_HC.png
#   inflating: training_set/341_HC_Annotation.png
#  extracting: training_set/342_HC.png
#   inflating: training_set/342_HC_Annotation.png
#  extracting: training_set/343_HC.png
#   inflating: training_set/343_HC_Annotation.png
#  extracting: training_set/344_HC.png
#   inflating: training_set/344_HC_Annotation.png
#  extracting: training_set/345_2HC.png
#   inflating: training_set/345_2HC_Annotation.png
#  extracting: training_set/345_HC.png
#   inflating: training_set/345_HC_Annotation.png
#  extracting: training_set/346_HC.png
#   inflating: training_set/346_HC_Annotation.png
#  extracting: training_set/347_HC.png
#   inflating: training_set/347_HC_Annotation.png
#  extracting: training_set/348_HC.png
#   inflating: training_set/348_HC_Annotation.png
#  extracting: training_set/349_HC.png
#   inflating: training_set/349_HC_Annotation.png
#  extracting: training_set/350_HC.png
#   inflating: training_set/350_HC_Annotation.png
#  extracting: training_set/351_HC.png
#   inflating: training_set/351_HC_Annotation.png
#  extracting: training_set/352_2HC.png
#   inflating: training_set/352_2HC_Annotation.png
#  extracting: training_set/352_HC.png
#   inflating: training_set/352_HC_Annotation.png
#  extracting: training_set/353_HC.png
#   inflating: training_set/353_HC_Annotation.png
#  extracting: training_set/354_HC.png
#   inflating: training_set/354_HC_Annotation.png
#  extracting: training_set/355_HC.png
#   inflating: training_set/355_HC_Annotation.png
#  extracting: training_set/356_HC.png
#   inflating: training_set/356_HC_Annotation.png
#  extracting: training_set/357_HC.png
#   inflating: training_set/357_HC_Annotation.png
#  extracting: training_set/358_HC.png
#   inflating: training_set/358_HC_Annotation.png
#  extracting: training_set/359_2HC.png
#   inflating: training_set/359_2HC_Annotation.png
#  extracting: training_set/359_HC.png
#   inflating: training_set/359_HC_Annotation.png
#  extracting: training_set/360_2HC.png
#   inflating: training_set/360_2HC_Annotation.png
#  extracting: training_set/360_HC.png
#   inflating: training_set/360_HC_Annotation.png
#  extracting: training_set/361_2HC.png
#   inflating: training_set/361_2HC_Annotation.png
#  extracting: training_set/361_HC.png
#   inflating: training_set/361_HC_Annotation.png
#  extracting: training_set/362_HC.png
#   inflating: training_set/362_HC_Annotation.png
#  extracting: training_set/363_HC.png
#   inflating: training_set/363_HC_Annotation.png
#  extracting: training_set/364_2HC.png
#   inflating: training_set/364_2HC_Annotation.png
#  extracting: training_set/364_HC.png
#   inflating: training_set/364_HC_Annotation.png
#  extracting: training_set/365_HC.png
#   inflating: training_set/365_HC_Annotation.png
#  extracting: training_set/366_HC.png
#   inflating: training_set/366_HC_Annotation.png
#  extracting: training_set/367_HC.png
#   inflating: training_set/367_HC_Annotation.png
#  extracting: training_set/368_HC.png
#   inflating: training_set/368_HC_Annotation.png
#  extracting: training_set/369_HC.png
#   inflating: training_set/369_HC_Annotation.png
#  extracting: training_set/370_HC.png
#   inflating: training_set/370_HC_Annotation.png
#  extracting: training_set/371_HC.png
#   inflating: training_set/371_HC_Annotation.png
#  extracting: training_set/372_HC.png
#   inflating: training_set/372_HC_Annotation.png
#  extracting: training_set/373_2HC.png
#   inflating: training_set/373_2HC_Annotation.png
#  extracting: training_set/373_HC.png
#   inflating: training_set/373_HC_Annotation.png
#  extracting: training_set/374_HC.png
#   inflating: training_set/374_HC_Annotation.png
#  extracting: training_set/375_HC.png
#   inflating: training_set/375_HC_Annotation.png
#  extracting: training_set/376_2HC.png
#   inflating: training_set/376_2HC_Annotation.png
#  extracting: training_set/376_HC.png
#   inflating: training_set/376_HC_Annotation.png
#  extracting: training_set/377_HC.png
#   inflating: training_set/377_HC_Annotation.png
#  extracting: training_set/378_HC.png
#   inflating: training_set/378_HC_Annotation.png
#  extracting: training_set/379_HC.png
#   inflating: training_set/379_HC_Annotation.png
#  extracting: training_set/380_HC.png
#   inflating: training_set/380_HC_Annotation.png
#  extracting: training_set/381_HC.png
#   inflating: training_set/381_HC_Annotation.png
#  extracting: training_set/382_2HC.png
#   inflating: training_set/382_2HC_Annotation.png
#  extracting: training_set/382_HC.png
#   inflating: training_set/382_HC_Annotation.png
#  extracting: training_set/383_HC.png
#   inflating: training_set/383_HC_Annotation.png
#  extracting: training_set/384_2HC.png
#   inflating: training_set/384_2HC_Annotation.png
#  extracting: training_set/384_HC.png
#   inflating: training_set/384_HC_Annotation.png
#  extracting: training_set/385_HC.png
#   inflating: training_set/385_HC_Annotation.png
#  extracting: training_set/386_HC.png
#   inflating: training_set/386_HC_Annotation.png
#  extracting: training_set/387_HC.png
#   inflating: training_set/387_HC_Annotation.png
#   inflating: training_set/388_HC.png
#   inflating: training_set/388_HC_Annotation.png
#  extracting: training_set/389_HC.png
#   inflating: training_set/389_HC_Annotation.png
#  extracting: training_set/390_HC.png
#   inflating: training_set/390_HC_Annotation.png
#  extracting: training_set/391_HC.png
#   inflating: training_set/391_HC_Annotation.png
#  extracting: training_set/392_2HC.png
#   inflating: training_set/392_2HC_Annotation.png
#  extracting: training_set/392_3HC.png
#   inflating: training_set/392_3HC_Annotation.png
#  extracting: training_set/392_HC.png
#   inflating: training_set/392_HC_Annotation.png
#  extracting: training_set/393_HC.png
#   inflating: training_set/393_HC_Annotation.png
#  extracting: training_set/394_2HC.png
#   inflating: training_set/394_2HC_Annotation.png
#  extracting: training_set/394_HC.png
#   inflating: training_set/394_HC_Annotation.png
#  extracting: training_set/395_HC.png
#   inflating: training_set/395_HC_Annotation.png
#  extracting: training_set/396_HC.png
#   inflating: training_set/396_HC_Annotation.png
#  extracting: training_set/397_HC.png
#   inflating: training_set/397_HC_Annotation.png
#  extracting: training_set/398_HC.png
#   inflating: training_set/398_HC_Annotation.png
#  extracting: training_set/399_2HC.png
#   inflating: training_set/399_2HC_Annotation.png
#  extracting: training_set/399_HC.png
#   inflating: training_set/399_HC_Annotation.png
#  extracting: training_set/400_HC.png
#   inflating: training_set/400_HC_Annotation.png
#  extracting: training_set/401_HC.png
#   inflating: training_set/401_HC_Annotation.png
#  extracting: training_set/402_HC.png
#   inflating: training_set/402_HC_Annotation.png
#  extracting: training_set/403_2HC.png
#   inflating: training_set/403_2HC_Annotation.png
#  extracting: training_set/403_HC.png
#   inflating: training_set/403_HC_Annotation.png
#  extracting: training_set/404_2HC.png
#   inflating: training_set/404_2HC_Annotation.png
#   inflating: training_set/404_HC.png
#   inflating: training_set/404_HC_Annotation.png
#  extracting: training_set/405_HC.png
#   inflating: training_set/405_HC_Annotation.png
#  extracting: training_set/406_HC.png
#   inflating: training_set/406_HC_Annotation.png
#  extracting: training_set/407_HC.png
#   inflating: training_set/407_HC_Annotation.png
#  extracting: training_set/408_HC.png
#   inflating: training_set/408_HC_Annotation.png
#  extracting: training_set/409_HC.png
#   inflating: training_set/409_HC_Annotation.png
#  extracting: training_set/410_2HC.png
#   inflating: training_set/410_2HC_Annotation.png
#  extracting: training_set/410_HC.png
#   inflating: training_set/410_HC_Annotation.png
#  extracting: training_set/411_HC.png
#   inflating: training_set/411_HC_Annotation.png
#  extracting: training_set/412_HC.png
#   inflating: training_set/412_HC_Annotation.png
#  extracting: training_set/413_HC.png
#   inflating: training_set/413_HC_Annotation.png
#  extracting: training_set/414_HC.png
#   inflating: training_set/414_HC_Annotation.png
#  extracting: training_set/415_HC.png
#   inflating: training_set/415_HC_Annotation.png
#  extracting: training_set/416_HC.png
#   inflating: training_set/416_HC_Annotation.png
#  extracting: training_set/417_HC.png
#   inflating: training_set/417_HC_Annotation.png
#  extracting: training_set/418_HC.png
#   inflating: training_set/418_HC_Annotation.png
#  extracting: training_set/419_HC.png
#   inflating: training_set/419_HC_Annotation.png
#  extracting: training_set/420_HC.png
#   inflating: training_set/420_HC_Annotation.png
#  extracting: training_set/421_HC.png
#   inflating: training_set/421_HC_Annotation.png
#  extracting: training_set/422_HC.png
#   inflating: training_set/422_HC_Annotation.png
#  extracting: training_set/423_HC.png
#   inflating: training_set/423_HC_Annotation.png
#  extracting: training_set/424_HC.png
#   inflating: training_set/424_HC_Annotation.png
#  extracting: training_set/425_2HC.png
#   inflating: training_set/425_2HC_Annotation.png
#  extracting: training_set/425_HC.png
#   inflating: training_set/425_HC_Annotation.png
#  extracting: training_set/426_2HC.png
#   inflating: training_set/426_2HC_Annotation.png
#  extracting: training_set/426_3HC.png
#   inflating: training_set/426_3HC_Annotation.png
#  extracting: training_set/426_4HC.png
#   inflating: training_set/426_4HC_Annotation.png
#  extracting: training_set/426_HC.png
#   inflating: training_set/426_HC_Annotation.png
#  extracting: training_set/427_HC.png
#   inflating: training_set/427_HC_Annotation.png
#  extracting: training_set/428_HC.png
#   inflating: training_set/428_HC_Annotation.png
#  extracting: training_set/429_HC.png
#   inflating: training_set/429_HC_Annotation.png
#  extracting: training_set/430_HC.png
#   inflating: training_set/430_HC_Annotation.png
#  extracting: training_set/431_2HC.png
#   inflating: training_set/431_2HC_Annotation.png
#  extracting: training_set/431_HC.png
#   inflating: training_set/431_HC_Annotation.png
#  extracting: training_set/432_HC.png
#   inflating: training_set/432_HC_Annotation.png
#  extracting: training_set/433_HC.png
#   inflating: training_set/433_HC_Annotation.png
#  extracting: training_set/434_2HC.png
#   inflating: training_set/434_2HC_Annotation.png
#  extracting: training_set/434_HC.png
# ...
#   inflating: training_set/667_HC_Annotation.png
#   inflating: training_set/668_HC.png
#   inflating: training_set/668_HC_Annotation.png
#  extracting: training_set/669_HC.png
#   inflating: training_set/669_HC_Annotation.png
#  extracting: training_set/670_HC.png
#   inflating: training_set/670_HC_Annotation.png
#  extracting: training_set/671_2HC.png
#   inflating: training_set/671_2HC_Annotation.png
#  extracting: training_set/671_3HC.png
#   inflating: training_set/671_3HC_Annotation.png
#  extracting: training_set/671_HC.png
#   inflating: training_set/671_HC_Annotation.png
#  extracting: training_set/672_HC.png
#   inflating: training_set/672_HC_Annotation.png
#   inflating: training_set/673_2HC.png
#   inflating: training_set/673_2HC_Annotation.png
#  extracting: training_set/673_HC.png
#   inflating: training_set/673_HC_Annotation.png
#  extracting: training_set/674_HC.png
#   inflating: training_set/674_HC_Annotation.png
#  extracting: training_set/675_2HC.png
#   inflating: training_set/675_2HC_Annotation.png
#  extracting: training_set/675_HC.png
#   inflating: training_set/675_HC_Annotation.png
#  extracting: training_set/676_HC.png
#   inflating: training_set/676_HC_Annotation.png
#  extracting: training_set/677_2HC.png
#   inflating: training_set/677_2HC_Annotation.png
#  extracting: training_set/677_HC.png
#   inflating: training_set/677_HC_Annotation.png
#  extracting: training_set/678_HC.png
#   inflating: training_set/678_HC_Annotation.png
#  extracting: training_set/679_HC.png
#   inflating: training_set/679_HC_Annotation.png
#   inflating: training_set/680_HC.png
#   inflating: training_set/680_HC_Annotation.png
#  extracting: training_set/681_HC.png
#   inflating: training_set/681_HC_Annotation.png
#  extracting: training_set/682_HC.png
#   inflating: training_set/682_HC_Annotation.png
#  extracting: training_set/683_HC.png
#   inflating: training_set/683_HC_Annotation.png
#  extracting: training_set/684_HC.png
#   inflating: training_set/684_HC_Annotation.png
#  extracting: training_set/685_HC.png
#   inflating: training_set/685_HC_Annotation.png
#  extracting: training_set/686_2HC.png
#   inflating: training_set/686_2HC_Annotation.png
#   inflating: training_set/686_HC.png
#   inflating: training_set/686_HC_Annotation.png
#  extracting: training_set/687_HC.png
#   inflating: training_set/687_HC_Annotation.png
#   inflating: training_set/688_HC.png
#   inflating: training_set/688_HC_Annotation.png
#  extracting: training_set/689_HC.png
#   inflating: training_set/689_HC_Annotation.png
#  extracting: training_set/690_2HC.png
#   inflating: training_set/690_2HC_Annotation.png
#  extracting: training_set/690_HC.png
#   inflating: training_set/690_HC_Annotation.png
#  extracting: training_set/691_HC.png
#   inflating: training_set/691_HC_Annotation.png
#  extracting: training_set/692_2HC.png
#   inflating: training_set/692_2HC_Annotation.png
#  extracting: training_set/692_HC.png
#   inflating: training_set/692_HC_Annotation.png
#  extracting: training_set/693_HC.png
#   inflating: training_set/693_HC_Annotation.png
#  extracting: training_set/694_HC.png
#   inflating: training_set/694_HC_Annotation.png
#  extracting: training_set/695_HC.png
#   inflating: training_set/695_HC_Annotation.png
#  extracting: training_set/696_HC.png
#   inflating: training_set/696_HC_Annotation.png
#   inflating: training_set/697_HC.png
#   inflating: training_set/697_HC_Annotation.png
#   inflating: training_set/698_HC.png
#   inflating: training_set/698_HC_Annotation.png
#  extracting: training_set/699_HC.png
#   inflating: training_set/699_HC_Annotation.png
#  extracting: training_set/700_HC.png
#   inflating: training_set/700_HC_Annotation.png
#   inflating: training_set/701_HC.png
#   inflating: training_set/701_HC_Annotation.png
#  extracting: training_set/702_HC.png
#   inflating: training_set/702_HC_Annotation.png
#  extracting: training_set/703_HC.png
#   inflating: training_set/703_HC_Annotation.png
#  extracting: training_set/704_2HC.png
#   inflating: training_set/704_2HC_Annotation.png
#  extracting: training_set/704_HC.png
#   inflating: training_set/704_HC_Annotation.png
#  extracting: training_set/705_HC.png
#   inflating: training_set/705_HC_Annotation.png
#  extracting: training_set/706_HC.png
#   inflating: training_set/706_HC_Annotation.png
#  extracting: training_set/707_HC.png
#   inflating: training_set/707_HC_Annotation.png
#   inflating: training_set/708_2HC.png
#   inflating: training_set/708_2HC_Annotation.png
#   inflating: training_set/708_3HC.png
#   inflating: training_set/708_3HC_Annotation.png
#   inflating: training_set/708_HC.png
#   inflating: training_set/708_HC_Annotation.png
#  extracting: training_set/709_2HC.png
#   inflating: training_set/709_2HC_Annotation.png
#  extracting: training_set/709_HC.png
#   inflating: training_set/709_HC_Annotation.png
#  extracting: training_set/710_HC.png
#   inflating: training_set/710_HC_Annotation.png
#  extracting: training_set/711_HC.png
#   inflating: training_set/711_HC_Annotation.png
#  extracting: training_set/712_2HC.png
#   inflating: training_set/712_2HC_Annotation.png
#  extracting: training_set/712_HC.png
#   inflating: training_set/712_HC_Annotation.png
#  extracting: training_set/713_HC.png
#   inflating: training_set/713_HC_Annotation.png
#  extracting: training_set/714_HC.png
#   inflating: training_set/714_HC_Annotation.png
#   inflating: training_set/715_HC.png
#   inflating: training_set/715_HC_Annotation.png
#  extracting: training_set/716_HC.png
#   inflating: training_set/716_HC_Annotation.png
#  extracting: training_set/717_2HC.png
#   inflating: training_set/717_2HC_Annotation.png
#  extracting: training_set/717_HC.png
#   inflating: training_set/717_HC_Annotation.png
#  extracting: training_set/718_2HC.png
#   inflating: training_set/718_2HC_Annotation.png
#  extracting: training_set/718_HC.png
#   inflating: training_set/718_HC_Annotation.png
#  extracting: training_set/719_HC.png
#   inflating: training_set/719_HC_Annotation.png
#  extracting: training_set/720_2HC.png
#   inflating: training_set/720_2HC_Annotation.png
#  extracting: training_set/720_HC.png
#   inflating: training_set/720_HC_Annotation.png
#  extracting: training_set/721_HC.png
#   inflating: training_set/721_HC_Annotation.png
#   inflating: training_set/722_HC.png
#   inflating: training_set/722_HC_Annotation.png
#  extracting: training_set/723_HC.png
#   inflating: training_set/723_HC_Annotation.png
#  extracting: training_set/724_HC.png
#   inflating: training_set/724_HC_Annotation.png
#  extracting: training_set/725_2HC.png
#   inflating: training_set/725_2HC_Annotation.png
#  extracting: training_set/725_HC.png
#   inflating: training_set/725_HC_Annotation.png
#  extracting: training_set/726_HC.png
#   inflating: training_set/726_HC_Annotation.png
#  extracting: training_set/727_HC.png
#   inflating: training_set/727_HC_Annotation.png
#  extracting: training_set/728_HC.png
#   inflating: training_set/728_HC_Annotation.png
#  extracting: training_set/729_HC.png
#   inflating: training_set/729_HC_Annotation.png
#  extracting: training_set/730_2HC.png
#   inflating: training_set/730_2HC_Annotation.png
#  extracting: training_set/730_HC.png
#   inflating: training_set/730_HC_Annotation.png
#  extracting: training_set/731_2HC.png
#   inflating: training_set/731_2HC_Annotation.png
#   inflating: training_set/731_3HC.png
#   inflating: training_set/731_3HC_Annotation.png
#  extracting: training_set/731_HC.png
#   inflating: training_set/731_HC_Annotation.png
#  extracting: training_set/732_HC.png
#   inflating: training_set/732_HC_Annotation.png
#   inflating: training_set/733_HC.png
#   inflating: training_set/733_HC_Annotation.png
#   inflating: training_set/734_HC.png
#   inflating: training_set/734_HC_Annotation.png
#  extracting: training_set/735_HC.png
#   inflating: training_set/735_HC_Annotation.png
#  extracting: training_set/736_2HC.png
#   inflating: training_set/736_2HC_Annotation.png
#  extracting: training_set/736_HC.png
#   inflating: training_set/736_HC_Annotation.png
#  extracting: training_set/737_HC.png
#   inflating: training_set/737_HC_Annotation.png
#  extracting: training_set/738_HC.png
#   inflating: training_set/738_HC_Annotation.png
#  extracting: training_set/739_HC.png
#   inflating: training_set/739_HC_Annotation.png
#  extracting: training_set/740_HC.png
#   inflating: training_set/740_HC_Annotation.png
#  extracting: training_set/741_HC.png
#   inflating: training_set/741_HC_Annotation.png
#  extracting: training_set/742_HC.png
#   inflating: training_set/742_HC_Annotation.png
#  extracting: training_set/743_HC.png
#   inflating: training_set/743_HC_Annotation.png
#  extracting: training_set/744_HC.png
#   inflating: training_set/744_HC_Annotation.png
#  extracting: training_set/745_HC.png
#   inflating: training_set/745_HC_Annotation.png
#  extracting: training_set/746_2HC.png
#   inflating: training_set/746_2HC_Annotation.png
#  extracting: training_set/746_3HC.png
#   inflating: training_set/746_3HC_Annotation.png
#  extracting: training_set/746_4HC.png
#   inflating: training_set/746_4HC_Annotation.png
#  extracting: training_set/746_HC.png
#   inflating: training_set/746_HC_Annotation.png
#  extracting: training_set/747_HC.png
#   inflating: training_set/747_HC_Annotation.png
#  extracting: training_set/748_HC.png
#   inflating: training_set/748_HC_Annotation.png
#  extracting: training_set/749_HC.png
#   inflating: training_set/749_HC_Annotation.png
#  extracting: training_set/750_HC.png
#   inflating: training_set/750_HC_Annotation.png
#   inflating: training_set/751_2HC.png
#   inflating: training_set/751_2HC_Annotation.png
#  extracting: training_set/751_HC.png
#   inflating: training_set/751_HC_Annotation.png
#   inflating: training_set/752_HC.png
#   inflating: training_set/752_HC_Annotation.png
#  extracting: training_set/753_HC.png
#   inflating: training_set/753_HC_Annotation.png
#   inflating: training_set/754_HC.png
#   inflating: training_set/754_HC_Annotation.png
#  extracting: training_set/755_HC.png
#   inflating: training_set/755_HC_Annotation.png
#  extracting: training_set/756_2HC.png
#   inflating: training_set/756_2HC_Annotation.png
#  extracting: training_set/756_HC.png
#   inflating: training_set/756_HC_Annotation.png
#  extracting: training_set/757_HC.png
#   inflating: training_set/757_HC_Annotation.png
#  extracting: training_set/758_HC.png
#   inflating: training_set/758_HC_Annotation.png
#  extracting: training_set/759_HC.png
#   inflating: training_set/759_HC_Annotation.png
#   inflating: training_set/760_HC.png
#   inflating: training_set/760_HC_Annotation.png
#  extracting: training_set/761_HC.png
#   inflating: training_set/761_HC_Annotation.png
#  extracting: training_set/762_HC.png
#   inflating: training_set/762_HC_Annotation.png
#   inflating: training_set/763_HC.png
#   inflating: training_set/763_HC_Annotation.png
#  extracting: training_set/764_2HC.png
#   inflating: training_set/764_2HC_Annotation.png
#  extracting: training_set/764_HC.png
#   inflating: training_set/764_HC_Annotation.png
#  extracting: training_set/765_HC.png
#   inflating: training_set/765_HC_Annotation.png
#  extracting: training_set/766_HC.png
#   inflating: training_set/766_HC_Annotation.png
#  extracting: training_set/767_HC.png
#   inflating: training_set/767_HC_Annotation.png
#  extracting: training_set/768_2HC.png
#   inflating: training_set/768_2HC_Annotation.png
#  extracting: training_set/768_HC.png
#   inflating: training_set/768_HC_Annotation.png
#  extracting: training_set/769_HC.png
#   inflating: training_set/769_HC_Annotation.png
#  extracting: training_set/770_HC.png
#   inflating: training_set/770_HC_Annotation.png
#   inflating: training_set/771_HC.png
#   inflating: training_set/771_HC_Annotation.png
#  extracting: training_set/772_HC.png
#   inflating: training_set/772_HC_Annotation.png
#  extracting: training_set/773_2HC.png
#   inflating: training_set/773_2HC_Annotation.png
#  extracting: training_set/773_3HC.png
#   inflating: training_set/773_3HC_Annotation.png
#  extracting: training_set/773_HC.png
#   inflating: training_set/773_HC_Annotation.png
#  extracting: training_set/774_HC.png
#   inflating: training_set/774_HC_Annotation.png
#  extracting: training_set/775_HC.png
#   inflating: training_set/775_HC_Annotation.png
#   inflating: training_set/776_HC.png
#   inflating: training_set/776_HC_Annotation.png
#  extracting: training_set/777_HC.png
#   inflating: training_set/777_HC_Annotation.png
#  extracting: training_set/778_HC.png
#   inflating: training_set/778_HC_Annotation.png
#   inflating: training_set/779_2HC.png
#   inflating: training_set/779_2HC_Annotation.png
#   inflating: training_set/779_HC.png
#   inflating: training_set/779_HC_Annotation.png
#  extracting: training_set/780_2HC.png
#   inflating: training_set/780_2HC_Annotation.png
#  extracting: training_set/780_HC.png
#   inflating: training_set/780_HC_Annotation.png
#  extracting: training_set/781_HC.png
#   inflating: training_set/781_HC_Annotation.png
#  extracting: training_set/782_HC.png
#   inflating: training_set/782_HC_Annotation.png
#   inflating: training_set/783_2HC.png
#   inflating: training_set/783_2HC_Annotation.png
#   inflating: training_set/783_3HC.png
#   inflating: training_set/783_3HC_Annotation.png
#  extracting: training_set/783_4HC.png
#   inflating: training_set/783_4HC_Annotation.png
#  extracting: training_set/783_HC.png
#   inflating: training_set/783_HC_Annotation.png
#  extracting: training_set/784_HC.png
#   inflating: training_set/784_HC_Annotation.png
#  extracting: training_set/785_2HC.png
#   inflating: training_set/785_2HC_Annotation.png
#  extracting: training_set/785_HC.png
#   inflating: training_set/785_HC_Annotation.png
#  extracting: training_set/786_HC.png
#   inflating: training_set/786_HC_Annotation.png
#  extracting: training_set/787_HC.png
#   inflating: training_set/787_HC_Annotation.png
#  extracting: training_set/788_2HC.png
#   inflating: training_set/788_2HC_Annotation.png
#  extracting: training_set/788_HC.png
#   inflating: training_set/788_HC_Annotation.png
#  extracting: training_set/789_HC.png
#   inflating: training_set/789_HC_Annotation.png
#  extracting: training_set/790_HC.png
#   inflating: training_set/790_HC_Annotation.png
#  extracting: training_set/791_HC.png
#   inflating: training_set/791_HC_Annotation.png
#  extracting: training_set/792_HC.png
#   inflating: training_set/792_HC_Annotation.png
#  extracting: training_set/793_2HC.png
#   inflating: training_set/793_2HC_Annotation.png
#  extracting: training_set/793_HC.png
#   inflating: training_set/793_HC_Annotation.png
#  extracting: training_set/794_HC.png
#   inflating: training_set/794_HC_Annotation.png
#  extracting: training_set/795_2HC.png
#   inflating: training_set/795_2HC_Annotation.png
#  extracting: training_set/795_HC.png
#   inflating: training_set/795_HC_Annotation.png
#  extracting: training_set/796_2HC.png
#   inflating: training_set/796_2HC_Annotation.png
#  extracting: training_set/796_HC.png
#   inflating: training_set/796_HC_Annotation.png
#  extracting: training_set/797_HC.png
#   inflating: training_set/797_HC_Annotation.png
#  extracting: training_set/798_HC.png
#   inflating: training_set/798_HC_Annotation.png
#  extracting: training_set/799_HC.png
#   inflating: training_set/799_HC_Annotation.png
#   inflating: training_set/800_HC.png
#   inflating: training_set/800_HC_Annotation.png
#  extracting: training_set/801_HC.png
#   inflating: training_set/801_HC_Annotation.png
#  extracting: training_set/802_HC.png
#   inflating: training_set/802_HC_Annotation.png
#  extracting: training_set/803_HC.png
#   inflating: training_set/803_HC_Annotation.png
#   inflating: training_set/804_HC.png
#   inflating: training_set/804_HC_Annotation.png
#  extracting: training_set/805_HC.png
#   inflating: training_set/805_HC_Annotation.png

# %%
import cv2
import os
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # **Mask Generation**
# Done only once and replaced that  annotation with masks permanently
# Did not changed the annotation file name though

# %% [markdown]
# ## **Warning!!!**
# Do not run below cells as task is already completed

# %%
train_pixel_file = pd.read_csv('training_set_pixel_size_and_HC.csv')
train_pixel_file.head()
# This Dataframe will be used to extract image names hence by doing image_name + '_Annotation' we will get annotation names
# Out:
#      filename  pixel size(mm)  head circumference (mm)
# 0  000_HC.png        0.069136                    44.30
# 1  001_HC.png        0.089659                    56.81
# 2  002_HC.png        0.062033                    68.75
# 3  003_HC.png        0.091291                    69.00
# 4  004_HC.png        0.061240                    59.81

# %%
# This function takes annotation and spits out corresponding mask
def masking(image):
    imgray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(imgray, 127, 255, 0)
    contours,useless = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    ellipse = cv2.fitEllipse(contours[0])
    return cv2.ellipse(image, ellipse, (255,255,255), -1)

# %%
fig = plt.figure(figsize = (30,9))
img_file_path = os.path.join('training_set', train_pixel_file.iloc[8, 0])
mask_file_path = os.path.join('training_set', train_pixel_file.iloc[8, 0].replace('.png','_Annotation.png'))
ax = fig.add_subplot(2,2,3) 
img = cv2.imread(file_path)
mask = cv2.imread(mask_file_path)
plt.imshow(img)
plt.imshow(mask)

# %%
img = cv2.GaussianBlur(img,(31,31),1,1,cv2.BORDER_REPLICATE)
plt.imshow(img)

# %%
# to check if our masking function is working correctly
fig = plt.figure(figsize = (30,7))
for index in range(7):
  file_path = os.path.join('training_set', train_pixel_file.iloc[index, 0].replace('.png','_Annotation.png'))
  print(file_path)
  ax = fig.add_subplot(2, 7, index+1)             ## annoted plot
  plt.imshow(cv2.imread(file_path))
    
  ax = fig.add_subplot(2, 7, index+8)
  plt.imshow(masking(cv2.imread(file_path)))        ## mask plot
# Out:
# training_set/000_HC_Annotation.png
# training_set/001_HC_Annotation.png
# training_set/002_HC_Annotation.png
# training_set/003_HC_Annotation.png
# training_set/004_HC_Annotation.png
# training_set/005_HC_Annotation.png
# training_set/006_HC_Annotation.png

# %%
# Here we loop through training set and  take annotations one by one and replace them with corresponding masks
fig = plt.figure(figsize = (30,7))
for index in range(len(train_pixel_file)):
    file_path = os.path.join('training_set', train_pixel_file.iloc[index, 0].replace('.png','_Annotation.png'))
    image = cv2.imread(file_path)
    mask = masking(image)
    cv2.imwrite(file_path, mask)

# %% [markdown]
# ## **Warning!!!**
# **Done with mask generation. Don't run above cells ever again**

# %% [markdown]
# ### **Do all the imports in below cell**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from skimage import io, color
from PIL import Image
import cv2

import os
import random

import torch
from torch.utils.data  import Dataset, DataLoader
from torchvision import transforms
import torchvision.transforms.functional as TF
import torch.nn as nn
import torch.nn.functional as F
import torchvision

# %%
validation_set_size = 0.20            # fraction of dataset used for validation which will be splited randomly

# %%
# our dataset class
class HC18(Dataset):
  #""" train and validation dataset class"""
    def __init__(self, root_dir, train = True, transformX = None, transformY = None):
        self.pixel_file = pd.read_csv(os.path.join(root_dir, 'training_set_pixel_size_and_HC.csv'))
        self.root_dir = root_dir
        self.transformX = transformX
        self.transformY = transformY
        self.train = train
        
        # lets split the dataset in train and validation
        self.train_data, self.validation_data = train_test_split(self.pixel_file, test_size = validation_set_size, random_state = 5)
        
    def __len__(self):
        
        if self.train:
          length = len(self.train_data)
        else:
          length = len(self.validation_data)
        return length
    
    def __getitem__(self, index):
      
        if self.train:
          imx_name = os.path.join(self.root_dir, 'training_set', self.train_data.iloc[index, 0])
          imy_name = os.path.join(self.root_dir, 'training_set',self.train_data.iloc[index, 0].replace('.png','_Annotation.png'))

        else:
          imx_name = os.path.join(self.root_dir, 'training_set', self.validation_data.iloc[index, 0])
          imy_name = os.path.join(self.root_dir, 'training_set',self.validation_data.iloc[index, 0].replace('.png','_Annotation.png'))
        
        
        imx = Image.open(imx_name)
        imy = Image.open(imy_name).convert('L')
        
        # Apply Gaussian Blur on images
        
        
        ## tried some data augmentation techniques
        if self.train:
          # Random horizontal flipping
          if random.random() > 0.5:
              imx = TF.hflip(imx)
              imy = TF.hflip(imy)

          # Random vertical flipping
          if random.random() > 0.5:
              imx = TF.vflip(imx)
              imy = TF.vflip(imy)


          # Random rotation
          if random.random() > 0.8:
            angle = random.choice([-30, -90, -60, -45 -15, 0, 15, 30, 45, 60, 90])
            imx = TF.rotate(imx, angle)
            imy = TF.rotate(imy, angle)
        
        
        
        
        
        
        if self.transformX :
            imx = self.transformX(imx)
            imy = self.transformY(imy)
        
        sample = {'image': imx, 'annotation': imy}
        return sample

# %%
# our datasets
tx_X = transforms.Compose([ transforms.Resize((572, 572)),
                              transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,))
                              ])
tx_Y = transforms.Compose([ transforms.Resize((572, 572)),
                              transforms.ToTensor(),  ################ no need to normalize the maskk
                             # transforms.Normalize((0.5,), (0.5,))
                              ])
train_data = HC18('', train = True, transformX = tx_X, transformY = tx_Y)
validation_data = HC18('', train = False, transformX = tx_X, transformY = tx_Y )

# %%
# our dataloaders
train_loader = DataLoader(dataset = train_data, batch_size = 2, shuffle = True, num_workers = 2 )
validation_loader = DataLoader(dataset = validation_data, batch_size = 2, shuffle = True, num_workers = 2)

# %%
# this function will return numpy array from the transformed tensors which were
# obtained from our train_loader. Just to plot them and see if they are intact :) ha ha
def im_converterX(tensor):
    image = tensor.cpu().clone().detach().numpy() # make copy of tensor and converting it to numpy as we will need original later
    image = image.transpose(1,2,0) # swapping axes making (1, 28, 28) image to a (28, 28, 1)
 # print(image.shape)
    image = image * np.array((0.5, 0.5, 0.5)) + np.array((0.5, 0.5, 0.5)) # unnormalizing the image # this also outputs (28, 28, 3) which seems important for plt.imshow
    image = image.clip(0, 1) # to make sure final values are in range 0 to 1 as .ToTensor outputed
    return image

# %%
# this function will return numpy array from the transformed tensors which were
# obtained from our train_loader. Just to plot them and see if they are intact :) ha ha
def im_converterY(tensor):
    image = tensor.cpu().clone().detach().numpy() # make copy of tensor and converting it to numpy as we will need original later
    image = image.transpose(1,2,0) # swapping axes making (1, 28, 28) image to a (28, 28, 1)
 # print(image.shape)
    image = image * np.array((1, 1, 1)) # unnormalizing the image  not needed# this also outputs (28, 28, 3) which seems important for plt.imshow
    image = image.clip(0, 1) # to make sure final values are in range 0 to 1 as .ToTensor outputed
    return image

# %%
## Here we loop through our train_loader and see the images
## Looks good
fig = plt.figure(figsize = (15,6))
for ith_batch, sample_batched in enumerate(train_loader):
    print(ith_batch, sample_batched['image'].size(), sample_batched['annotation'].size())
    
    for index in range(2):
        ax = fig.add_subplot(2, 2 , index + 1)  # subplot index starts from 1
        plt.imshow(im_converterX(sample_batched['image'][index]))
        ax = fig.add_subplot(2, 2, index + 3)
        plt.imshow(im_converterY(sample_batched['annotation'][index]))
    break
# Out:
# 0 torch.Size([2, 1, 572, 572]) torch.Size([2, 1, 572, 572])

# %%
class double_conv(nn.Module):
    '''(conv => BN => ReLU) * 2'''

    def __init__(self, in_ch, out_ch):
        super(double_conv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            #nn.Dropout2d(0.7),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            #nn.Dropout2d(0.77),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x = self.conv(x)
        return x


class inconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(inconv, self).__init__()
        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x):
        x = self.conv(x)
        return x


class down(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(down, self).__init__()
        self.mpconv = nn.Sequential(
            nn.MaxPool2d(2),
            double_conv(in_ch, out_ch)
        )

    def forward(self, x):
        x = self.mpconv(x)
        return x


class up(nn.Module):
    def __init__(self, in_ch, out_ch, bilinear=True):
        super(up, self).__init__()

        if bilinear: #upsampling will not be learnable
            self.up = nn.Upsample(
                scale_factor=2, mode='bilinear', align_corners=True)
        else:  # it will be learnable here
            self.up = nn.ConvTranspose2d(in_ch // 2, in_ch // 2, 2, stride=2)
        
        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x1, x2):
        x1 = self.up(x1)

        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, (diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2))

        x = torch.cat([x2, x1], dim=1)
        x = self.conv(x)
        return x


class outconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(outconv, self).__init__()
        self.conv = nn.Conv2d(in_ch, out_ch, 1)

    def forward(self, x):
        x = self.conv(x)
        return x

# %%
class UNet(nn.Module):
    def __init__(self, n_channels, n_classes):
        super(UNet, self).__init__()
        self.inc = inconv(n_channels, 64)
        self.down1 = down(64, 128)
        self.down2 = down(128, 256)
        self.down3 = down(256, 512)
        self.down4 = down(512, 512)
        self.up1 = up(1024, 256, bilinear = False) # upsampling weights are made learnable
        self.up2 = up(512, 128, bilinear = False)
        self.up3 = up(256, 64, bilinear = False)
        self.up4 = up(128, 64, bilinear = False)
        self.outc = outconv(64, n_classes)
        self.dropout = torch.nn.Dropout2d(0.1)

    def forward(self, x):
        x = x.float()
        x1 = self.inc(x)
        x1 = self.dropout(x1)
        x2 = self.down1(x1)
        x2 = self.dropout(x2)
       # x2 = self.dropout(x2)
        x3 = self.down2(x2)
        x3 = self.dropout(x3)
        x4 = self.down3(x3)
        x4 = self.dropout(x4)
        x5 = self.down4(x4)
        x5 = self.dropout(x5)
       
        x = self.up1(x5, x4)
#         print(x.shape)
        x = self.up2(x, x3)
#         print(x.shape)
        x = self.dropout(x)
        x = self.up3(x, x2)
#         print(x.shape)
        #x = self.dropout(x) #
        x = self.up4(x, x1)
#         print(x.shape)
        x = self.outc(x)
#         print(x.shape)
        return torch.sigmoid(x)
      
      
      
      
      
      
model = UNet(1, 1)
model.to('cuda')
print("Model Loaded to GPU")
# Out:
# Model Loaded to GPU

# %%
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0077)

# %%
# calculates similarity index between predicted and actual segmentation
def dice_index(y_pred, y_actual):
    smooth = 0.000001
    size_of_batch = y_pred.size(0)
    
    p1 = y_pred.view(size_of_batch, -1)
    p2 = y_actual.view(size_of_batch, -1)
    
    intersection = (p1 * p2).sum()
    
    dice =  ((2.0 * intersection )+ smooth) / (p1.sum() + p2.sum() + smooth)
    #dice.requires_grad = True
    
    return dice

# %%
# calculate dice loss which will be later used in loss function calculation
def dice_loss(y_predict, y_train): ## to add in bce looss
  
  dice_loss = 1 -(dice_index(y_predict, y_train))
  
  return dice_loss

# %%
epochs = 250


train_running_loss_history = []
validation_running_loss_history =[]

for e in range(epochs):
  train_running_loss = 0.0
  validation_running_loss = 0.0
  
  model.train()
  
  for ith_batch, sample_batched in enumerate(train_loader):
    X_train = sample_batched['image'].to('cuda')
    y_train = sample_batched['annotation'].to('cuda')
    
    #X_train.requires_grad = True
    #y_train.requires_grad = True

    #print(ith_batch) #, X_train.size(), y_train.size())

    optimizer.zero_grad()
    y_pred = model(X_train)
   # out = (y_pred + 0.5).int().float()
    
    loss = 0.30 * dice_loss(y_pred, y_train) +  0.70 * criterion(y_pred, y_train)
    #loss = criterion(y_pred, y_train)
    loss.backward()
    optimizer.step()
    
    if ith_batch % 50 == 0:
      print('Epoch: ', e + 1, 'Batch: ', ith_batch, 'Current Loss: ', loss.item())
      
    train_running_loss += loss.item()
    
    
    
    
  else:
    print('else')
    with torch.no_grad():
      
      model.eval()
      
      for ith_batch, sample_batched in enumerate(validation_loader):
          X_val = sample_batched['image'].to('cuda')
          y_val = sample_batched['annotation'].to('cuda')
          
          
          
          y_out = model(X_val)
          out_val = (y_out + 0.5).int().float()
          
          val_loss = 0.3 * dice_loss(out_val, y_val)  + 0.7 * criterion(y_out, y_val)
          
          #val_loss = criterion(y_out, y_val)
          
          validation_running_loss += val_loss.item()
      print("================================================================================")
      print("Epoch {} completed".format(e + 1))
      
      train_epoch_loss = train_running_loss / len(train_loader)
      validation_epoch_loss = validation_running_loss / len(validation_loader)
      
      print("Average train loss is {}: ".format(train_epoch_loss))
      print("Average validation loss is {}".format(validation_epoch_loss))
      print("================================================================================")
      train_running_loss_history.append(train_epoch_loss)
      validation_running_loss_history.append(validation_epoch_loss)
  
  torch.cuda.empty_cache()
      #print(y_pred.shape)

    #y_pred = y_pred.to('cpu')
    #X_train = X_train.to('cpu')

    #del y_train
    #torch.cuda.empty_cache()
    #if ith_batch ==100:
    #break
  #for index in range(2):
  #         ax = gig.add_subplot(2, 2 , index + 1)  # subplot index starts from 1
   #         plt.imshow(im_converter(X_train[index]))
    #        ax = gig.add_subplot(2, 2, index + 3)
     #       plt.imshow(im_converter(y_pred[index]))
# Out:
# Epoch:  1 Batch:  0 Current Loss:  0.7081149220466614
# Epoch:  1 Batch:  50 Current Loss:  0.48298758268356323
# Epoch:  1 Batch:  100 Current Loss:  0.5061333179473877
# Epoch:  1 Batch:  150 Current Loss:  0.5857142806053162
# Epoch:  1 Batch:  200 Current Loss:  0.29979074001312256
# Epoch:  1 Batch:  250 Current Loss:  0.3135214149951935
# Epoch:  1 Batch:  300 Current Loss:  0.47544795274734497
# Epoch:  1 Batch:  350 Current Loss:  0.3760516345500946
# else
# ================================================================================
# Epoch 1 completed
# Average train loss is 0.407696340829134:
# Average validation loss is 0.7796363870799542
# ================================================================================
# Epoch:  2 Batch:  0 Current Loss:  0.2073071300983429
# Epoch:  2 Batch:  50 Current Loss:  0.4693138897418976
# Epoch:  2 Batch:  100 Current Loss:  0.35307934880256653
# Epoch:  2 Batch:  150 Current Loss:  0.21861214935779572
# Epoch:  2 Batch:  200 Current Loss:  0.31332433223724365
# Epoch:  2 Batch:  250 Current Loss:  0.17090274393558502
# Epoch:  2 Batch:  300 Current Loss:  0.25499892234802246
# Epoch:  2 Batch:  350 Current Loss:  0.246657133102417
# else
# ================================================================================
# Epoch 2 completed
# Average train loss is 0.28449331419542434:
# Average validation loss is 0.322889005318284
# ================================================================================
# Epoch:  3 Batch:  0 Current Loss:  0.34015774726867676
# Epoch:  3 Batch:  50 Current Loss:  0.24949122965335846
# Epoch:  3 Batch:  100 Current Loss:  0.15484124422073364
# Epoch:  3 Batch:  150 Current Loss:  0.3619900941848755
# Epoch:  3 Batch:  200 Current Loss:  0.23624113202095032
# Epoch:  3 Batch:  250 Current Loss:  0.19200687110424042
# Epoch:  3 Batch:  300 Current Loss:  0.151415154337883
# Epoch:  3 Batch:  350 Current Loss:  0.16069456934928894
# else
# ================================================================================
# Epoch 3 completed
# Average train loss is 0.22994589051231742:
# Average validation loss is 0.1715761550143361
# ================================================================================
# Epoch:  4 Batch:  0 Current Loss:  0.14529575407505035
# Epoch:  4 Batch:  50 Current Loss:  0.14210546016693115
# Epoch:  4 Batch:  100 Current Loss:  0.15796831250190735
# Epoch:  4 Batch:  150 Current Loss:  0.1432618796825409
# Epoch:  4 Batch:  200 Current Loss:  0.17244872450828552
# Epoch:  4 Batch:  250 Current Loss:  0.21166718006134033
# Epoch:  4 Batch:  300 Current Loss:  0.14610569179058075
# Epoch:  4 Batch:  350 Current Loss:  0.07906702160835266
# else
# ================================================================================
# Epoch 4 completed
# Average train loss is 0.180327001651749:
# Average validation loss is 0.12462806809693575
# ================================================================================
# Epoch:  5 Batch:  0 Current Loss:  0.25523751974105835
# Epoch:  5 Batch:  50 Current Loss:  0.23307420313358307
# Epoch:  5 Batch:  100 Current Loss:  0.3563304841518402
# Epoch:  5 Batch:  150 Current Loss:  0.20308047533035278
# Epoch:  5 Batch:  200 Current Loss:  0.1869274079799652
# Epoch:  5 Batch:  250 Current Loss:  0.2786255478858948
# Epoch:  5 Batch:  300 Current Loss:  0.24544742703437805
# Epoch:  5 Batch:  350 Current Loss:  0.11200236529111862
# else
# ================================================================================
# Epoch 5 completed
# Average train loss is 0.15798679457046091:
# Average validation loss is 0.10879280250519514
# ================================================================================
# Epoch:  6 Batch:  0 Current Loss:  0.11962805688381195
# Epoch:  6 Batch:  50 Current Loss:  0.11203508824110031
# Epoch:  6 Batch:  100 Current Loss:  0.14915619790554047
# Epoch:  6 Batch:  150 Current Loss:  0.12532348930835724
# Epoch:  6 Batch:  200 Current Loss:  0.16367995738983154
# Epoch:  6 Batch:  250 Current Loss:  0.15757587552070618
# Epoch:  6 Batch:  300 Current Loss:  0.1066935658454895
# Epoch:  6 Batch:  350 Current Loss:  0.1561371088027954
# else
# ================================================================================
# Epoch 6 completed
# Average train loss is 0.1413595779053867:
# Average validation loss is 0.11645266780629754
# ================================================================================
# Epoch:  7 Batch:  0 Current Loss:  0.10640992224216461
# Epoch:  7 Batch:  50 Current Loss:  0.08925949037075043
# Epoch:  7 Batch:  100 Current Loss:  0.12971509993076324
# Epoch:  7 Batch:  150 Current Loss:  0.06607989966869354
# Epoch:  7 Batch:  200 Current Loss:  0.11574321985244751
# Epoch:  7 Batch:  250 Current Loss:  0.09244067221879959
# Epoch:  7 Batch:  300 Current Loss:  0.08481880277395248
# Epoch:  7 Batch:  350 Current Loss:  0.11191117018461227
# else
# ================================================================================
# Epoch 7 completed
# Average train loss is 0.12674118670634926:
# Average validation loss is 0.1437746845930815
# ================================================================================
# Epoch:  8 Batch:  0 Current Loss:  0.0692816898226738
# Epoch:  8 Batch:  50 Current Loss:  0.09151691198348999
# Epoch:  8 Batch:  100 Current Loss:  0.17594866454601288
# Epoch:  8 Batch:  150 Current Loss:  0.039677731692790985
# Epoch:  8 Batch:  200 Current Loss:  0.4912335276603699
# Epoch:  8 Batch:  250 Current Loss:  0.08668781071901321
# Epoch:  8 Batch:  300 Current Loss:  0.1514846831560135
# Epoch:  8 Batch:  350 Current Loss:  0.13675335049629211
# else
# ================================================================================
# Epoch 8 completed
# Average train loss is 0.11740593788214028:
# Average validation loss is 0.11956980928778649
# ================================================================================
# Epoch:  9 Batch:  0 Current Loss:  0.11679986119270325
# Epoch:  9 Batch:  50 Current Loss:  0.18142127990722656
# Epoch:  9 Batch:  100 Current Loss:  0.1578715294599533
# Epoch:  9 Batch:  150 Current Loss:  0.2259030044078827
# Epoch:  9 Batch:  200 Current Loss:  0.1196151077747345
# Epoch:  9 Batch:  250 Current Loss:  0.05628160387277603
# Epoch:  9 Batch:  300 Current Loss:  0.05755075812339783
# Epoch:  9 Batch:  350 Current Loss:  0.1413346827030182
# else
# ================================================================================
# Epoch 9 completed
# Average train loss is 0.108998510427773:
# Average validation loss is 0.1479687187820673
# ================================================================================
# Epoch:  10 Batch:  0 Current Loss:  0.04053784906864166
# Epoch:  10 Batch:  50 Current Loss:  0.06915411353111267
# Epoch:  10 Batch:  100 Current Loss:  0.06462718546390533
# Epoch:  10 Batch:  150 Current Loss:  0.04855123907327652
# Epoch:  10 Batch:  200 Current Loss:  0.09197460114955902
# Epoch:  10 Batch:  250 Current Loss:  0.1259935200214386
# Epoch:  10 Batch:  300 Current Loss:  0.08476287126541138
# Epoch:  10 Batch:  350 Current Loss:  0.13818314671516418
# else
# ================================================================================
# Epoch 10 completed
# Average train loss is 0.10197474509011954:
# Average validation loss is 0.09289557255804538
# ================================================================================
# Epoch:  11 Batch:  0 Current Loss:  0.07921867817640305
# Epoch:  11 Batch:  50 Current Loss:  0.11815145611763
# Epoch:  11 Batch:  100 Current Loss:  0.15269771218299866
# Epoch:  11 Batch:  150 Current Loss:  0.052785951644182205
# Epoch:  11 Batch:  200 Current Loss:  0.19179236888885498
# Epoch:  11 Batch:  250 Current Loss:  0.05229474604129791
# Epoch:  11 Batch:  300 Current Loss:  0.038722336292266846
# Epoch:  11 Batch:  350 Current Loss:  0.11276818066835403
# else
# ================================================================================
# Epoch 11 completed
# Average train loss is 0.10139156000223011:
# Average validation loss is 0.11790734868496656
# ================================================================================
# Epoch:  12 Batch:  0 Current Loss:  0.07574382424354553
# Epoch:  12 Batch:  50 Current Loss:  0.07975418865680695
# Epoch:  12 Batch:  100 Current Loss:  0.19136260449886322
# Epoch:  12 Batch:  150 Current Loss:  0.07093699276447296
# Epoch:  12 Batch:  200 Current Loss:  0.039634183049201965
# Epoch:  12 Batch:  250 Current Loss:  0.056130509823560715
# Epoch:  12 Batch:  300 Current Loss:  0.0804368332028389
# Epoch:  12 Batch:  350 Current Loss:  0.06455613672733307
# else
# ================================================================================
# Epoch 12 completed
# Average train loss is 0.0934157323744148:
# Average validation loss is 0.08778692116960883
# ================================================================================
# Epoch:  13 Batch:  0 Current Loss:  0.05370040982961655
# Epoch:  13 Batch:  50 Current Loss:  0.11296351999044418
# Epoch:  13 Batch:  100 Current Loss:  0.17074663937091827
# Epoch:  13 Batch:  150 Current Loss:  0.06231992319226265
# Epoch:  13 Batch:  200 Current Loss:  0.090725839138031
# Epoch:  13 Batch:  250 Current Loss:  0.20213653147220612
# Epoch:  13 Batch:  300 Current Loss:  0.05209621042013168
# Epoch:  13 Batch:  350 Current Loss:  0.06755983084440231
# else
# ================================================================================
# Epoch 13 completed
# Average train loss is 0.092302414663136:
# Average validation loss is 0.07932977493852376
# ================================================================================
# Epoch:  14 Batch:  0 Current Loss:  0.18441972136497498
# Epoch:  14 Batch:  50 Current Loss:  0.0778982937335968
# Epoch:  14 Batch:  100 Current Loss:  0.04543423280119896
# Epoch:  14 Batch:  150 Current Loss:  0.13688606023788452
# Epoch:  14 Batch:  200 Current Loss:  0.03860929608345032
# Epoch:  14 Batch:  250 Current Loss:  0.06607653945684433
# Epoch:  14 Batch:  300 Current Loss:  0.13243016600608826
# Epoch:  14 Batch:  350 Current Loss:  0.06134657561779022
# else
# ================================================================================
# Epoch 14 completed
# Average train loss is 0.08916113225277514:
# Average validation loss is 0.12707719027996064
# ================================================================================
# Epoch:  15 Batch:  0 Current Loss:  0.07103664427995682
# Epoch:  15 Batch:  50 Current Loss:  0.04923667758703232
# Epoch:  15 Batch:  100 Current Loss:  0.07285143435001373
# Epoch:  15 Batch:  150 Current Loss:  0.0820215493440628
# Epoch:  15 Batch:  200 Current Loss:  0.06295734643936157
# Epoch:  15 Batch:  250 Current Loss:  0.08186212182044983
# Epoch:  15 Batch:  300 Current Loss:  0.05831126123666763
# Epoch:  15 Batch:  350 Current Loss:  0.061746854335069656
# else
# ================================================================================
# Epoch 15 completed
# Average train loss is 0.08645068242680282:
# Average validation loss is 0.10462251642718912
# ================================================================================
# Epoch:  16 Batch:  0 Current Loss:  0.11015266180038452
# Epoch:  16 Batch:  50 Current Loss:  0.06753578037023544
# Epoch:  16 Batch:  100 Current Loss:  0.0884464755654335
# Epoch:  16 Batch:  150 Current Loss:  0.04514661803841591
# Epoch:  16 Batch:  200 Current Loss:  0.05859807878732681
# Epoch:  16 Batch:  250 Current Loss:  0.06489682197570801
# Epoch:  16 Batch:  300 Current Loss:  0.0452142171561718
# Epoch:  16 Batch:  350 Current Loss:  0.06692788004875183
# else
# ================================================================================
# Epoch 16 completed
# Average train loss is 0.0848406682210043:
# Average validation loss is 0.07379110483452678
# ================================================================================
# Epoch:  17 Batch:  0 Current Loss:  0.1204647496342659
# Epoch:  17 Batch:  50 Current Loss:  0.1097312644124031
# Epoch:  17 Batch:  100 Current Loss:  0.05489426851272583
# Epoch:  17 Batch:  150 Current Loss:  0.1964869201183319
# Epoch:  17 Batch:  200 Current Loss:  0.08772767335176468
# Epoch:  17 Batch:  250 Current Loss:  0.05148620903491974
# Epoch:  17 Batch:  300 Current Loss:  0.21043334901332855
# Epoch:  17 Batch:  350 Current Loss:  0.09485866129398346
# else
# ================================================================================
# Epoch 17 completed
# Average train loss is 0.08156739146914332:
# Average validation loss is 0.10411594437435269
# ================================================================================
# Epoch:  18 Batch:  0 Current Loss:  0.05189765617251396
# Epoch:  18 Batch:  50 Current Loss:  0.06519568711519241
# Epoch:  18 Batch:  100 Current Loss:  0.053769104182720184
# Epoch:  18 Batch:  150 Current Loss:  0.21752531826496124
# Epoch:  18 Batch:  200 Current Loss:  0.05185296759009361
# Epoch:  18 Batch:  250 Current Loss:  0.06302651762962341
# Epoch:  18 Batch:  300 Current Loss:  0.21077600121498108
# Epoch:  18 Batch:  350 Current Loss:  0.07095668464899063
# else
# ================================================================================
# Epoch 18 completed
# Average train loss is 0.08134594555944204:
# Average validation loss is 0.07245322220027446
# ================================================================================
# Epoch:  19 Batch:  0 Current Loss:  0.06685920059680939
# Epoch:  19 Batch:  50 Current Loss:  0.05381745100021362
# Epoch:  19 Batch:  100 Current Loss:  0.05732792243361473
# Epoch:  19 Batch:  150 Current Loss:  0.09780348092317581
# Epoch:  19 Batch:  200 Current Loss:  0.03508426249027252
# Epoch:  19 Batch:  250 Current Loss:  0.03336583450436592
# Epoch:  19 Batch:  300 Current Loss:  0.050385817885398865
# Epoch:  19 Batch:  350 Current Loss:  0.07778475433588028
# else
# ================================================================================
# Epoch 19 completed
# Average train loss is 0.07735201059374958:
# Average validation loss is 0.09066206768155098
# ================================================================================
# Epoch:  20 Batch:  0 Current Loss:  0.08047261089086533
# Epoch:  20 Batch:  50 Current Loss:  0.043255724012851715
# Epoch:  20 Batch:  100 Current Loss:  0.14244043827056885
# Epoch:  20 Batch:  150 Current Loss:  0.08298125118017197
# Epoch:  20 Batch:  200 Current Loss:  0.08276694267988205
# Epoch:  20 Batch:  250 Current Loss:  0.052510447800159454
# Epoch:  20 Batch:  300 Current Loss:  0.0944204181432724
# Epoch:  20 Batch:  350 Current Loss:  0.029533233493566513
# else
# ================================================================================
# Epoch 20 completed
# Average train loss is 0.07904696672223509:
# Average validation loss is 0.06860116025432944
# ================================================================================
# Epoch:  21 Batch:  0 Current Loss:  0.06667888164520264
# Epoch:  21 Batch:  50 Current Loss:  0.04356604442000389
# Epoch:  21 Batch:  100 Current Loss:  0.05673309415578842
# Epoch:  21 Batch:  150 Current Loss:  0.05361267179250717
# Epoch:  21 Batch:  200 Current Loss:  0.02843138575553894
# Epoch:  21 Batch:  250 Current Loss:  0.036663610488176346
# Epoch:  21 Batch:  300 Current Loss:  0.1132759302854538
# Epoch:  21 Batch:  350 Current Loss:  0.04395833984017372
# else
# ================================================================================
# Epoch 21 completed
# Average train loss is 0.07544564431067556:
# Average validation loss is 0.06968582550063729
# ================================================================================
# Epoch:  22 Batch:  0 Current Loss:  0.05539928749203682
# Epoch:  22 Batch:  50 Current Loss:  0.06070205941796303
# Epoch:  22 Batch:  100 Current Loss:  0.06508374959230423
# Epoch:  22 Batch:  150 Current Loss:  0.06895334273576736
# Epoch:  22 Batch:  200 Current Loss:  0.05104329437017441
# Epoch:  22 Batch:  250 Current Loss:  0.08699429780244827
# Epoch:  22 Batch:  300 Current Loss:  0.042931683361530304
# Epoch:  22 Batch:  350 Current Loss:  0.20624171197414398
# else
# ================================================================================
# Epoch 22 completed
# Average train loss is 0.07706512606237084:
# Average validation loss is 0.09472929071635008
# ================================================================================
# Epoch:  23 Batch:  0 Current Loss:  0.06637236475944519
# Epoch:  23 Batch:  50 Current Loss:  0.024906286969780922
# Epoch:  23 Batch:  100 Current Loss:  0.05052824690937996
# Epoch:  23 Batch:  150 Current Loss:  0.0729607343673706
# Epoch:  23 Batch:  200 Current Loss:  0.10114921629428864
# Epoch:  23 Batch:  250 Current Loss:  0.04416525363922119
# Epoch:  23 Batch:  300 Current Loss:  0.10745672136545181
# Epoch:  23 Batch:  350 Current Loss:  0.12612853944301605
# else
# ================================================================================
# Epoch 23 completed
# Average train loss is 0.07246288396418095:
# Average validation loss is 0.07678646847605705
# ================================================================================
# Epoch:  24 Batch:  0 Current Loss:  0.05698009580373764
# Epoch:  24 Batch:  50 Current Loss:  0.06279806047677994
# Epoch:  24 Batch:  100 Current Loss:  0.08037271350622177
# Epoch:  24 Batch:  150 Current Loss:  0.058845989406108856
# Epoch:  24 Batch:  200 Current Loss:  0.10055007040500641
# Epoch:  24 Batch:  250 Current Loss:  0.12989279627799988
# Epoch:  24 Batch:  300 Current Loss:  0.05502717196941376
# Epoch:  24 Batch:  350 Current Loss:  0.04938066005706787
# else
# ================================================================================
# Epoch 24 completed
# Average train loss is 0.07220106985885649:
# Average validation loss is 0.06600976081565023
# ================================================================================
# Epoch:  25 Batch:  0 Current Loss:  0.08107384294271469
# Epoch:  25 Batch:  50 Current Loss:  0.0505109578371048
# Epoch:  25 Batch:  100 Current Loss:  0.06645496934652328
# Epoch:  25 Batch:  150 Current Loss:  0.0995258018374443
# Epoch:  25 Batch:  200 Current Loss:  0.059799060225486755
# Epoch:  25 Batch:  250 Current Loss:  0.0705336481332779
# Epoch:  25 Batch:  300 Current Loss:  0.05938556417822838
# Epoch:  25 Batch:  350 Current Loss:  0.10143810510635376
# else
# ================================================================================
# Epoch 25 completed
# Average train loss is 0.07198452471755445:
# Average validation loss is 0.07565116692334413
# ================================================================================
# Epoch:  26 Batch:  0 Current Loss:  0.06085405871272087
# Epoch:  26 Batch:  50 Current Loss:  0.06222551688551903
# Epoch:  26 Batch:  100 Current Loss:  0.07989276945590973
# Epoch:  26 Batch:  150 Current Loss:  0.04628344997763634
# Epoch:  26 Batch:  200 Current Loss:  0.057183265686035156
# Epoch:  26 Batch:  250 Current Loss:  0.061463721096515656
# Epoch:  26 Batch:  300 Current Loss:  0.032941535115242004
# Epoch:  26 Batch:  350 Current Loss:  0.058250632137060165
# else
# ================================================================================
# Epoch 26 completed
# Average train loss is 0.06924259455874562:
# Average validation loss is 0.06743558427318931
# ================================================================================
# Epoch:  27 Batch:  0 Current Loss:  0.031343281269073486
# Epoch:  27 Batch:  50 Current Loss:  0.13534407317638397
# Epoch:  27 Batch:  100 Current Loss:  0.032712142914533615
# Epoch:  27 Batch:  150 Current Loss:  0.08374439924955368
# Epoch:  27 Batch:  200 Current Loss:  0.028953243046998978
# Epoch:  27 Batch:  250 Current Loss:  0.05168146267533302
# Epoch:  27 Batch:  300 Current Loss:  0.04460719972848892
# Epoch:  27 Batch:  350 Current Loss:  0.03748545050621033
# else
# ================================================================================
# Epoch 27 completed
# Average train loss is 0.06599604765884579:
# Average validation loss is 0.07427097139880061
# ================================================================================
# Epoch:  28 Batch:  0 Current Loss:  0.0421280674636364
# Epoch:  28 Batch:  50 Current Loss:  0.09874079376459122
# Epoch:  28 Batch:  100 Current Loss:  0.05131717026233673
# Epoch:  28 Batch:  150 Current Loss:  0.08767964690923691
# Epoch:  28 Batch:  200 Current Loss:  0.1794448345899582
# Epoch:  28 Batch:  250 Current Loss:  0.033887144178152084
# Epoch:  28 Batch:  300 Current Loss:  0.0795958861708641
# Epoch:  28 Batch:  350 Current Loss:  0.23640364408493042
# else
# ================================================================================
# Epoch 28 completed
# Average train loss is 0.06664590710774064:
# Average validation loss is 0.07766631834208965
# ================================================================================
# Epoch:  29 Batch:  0 Current Loss:  0.0521920844912529
# Epoch:  29 Batch:  50 Current Loss:  0.14322932064533234
# Epoch:  29 Batch:  100 Current Loss:  0.03153113275766373
# Epoch:  29 Batch:  150 Current Loss:  0.05811396986246109
# Epoch:  29 Batch:  200 Current Loss:  0.054712578654289246
# Epoch:  29 Batch:  250 Current Loss:  0.0404166653752327
# Epoch:  29 Batch:  300 Current Loss:  0.054130665957927704
# Epoch:  29 Batch:  350 Current Loss:  0.03733143210411072
# else
# ================================================================================
# Epoch 29 completed
# Average train loss is 0.06696564940735698:
# Average validation loss is 0.07901514217257499
# ================================================================================
# Epoch:  30 Batch:  0 Current Loss:  0.029577167704701424
# Epoch:  30 Batch:  50 Current Loss:  0.08931687474250793
# Epoch:  30 Batch:  100 Current Loss:  0.07136016339063644
# Epoch:  30 Batch:  150 Current Loss:  0.05376338213682175
# Epoch:  30 Batch:  200 Current Loss:  0.05567338690161705
# Epoch:  30 Batch:  250 Current Loss:  0.044468969106674194
# Epoch:  30 Batch:  300 Current Loss:  0.08732840418815613
# Epoch:  30 Batch:  350 Current Loss:  0.036180444061756134
# else
# ================================================================================
# Epoch 30 completed
# Average train loss is 0.0662467990629375:
# Average validation loss is 0.06005543977022171
# ================================================================================
# Epoch:  31 Batch:  0 Current Loss:  0.06403318047523499
# Epoch:  31 Batch:  50 Current Loss:  0.08815762400627136
# Epoch:  31 Batch:  100 Current Loss:  0.039029743522405624
# Epoch:  31 Batch:  150 Current Loss:  0.04409046471118927
# Epoch:  31 Batch:  200 Current Loss:  0.10952289402484894
# Epoch:  31 Batch:  250 Current Loss:  0.0538032092154026
# Epoch:  31 Batch:  300 Current Loss:  0.03511902689933777
# Epoch:  31 Batch:  350 Current Loss:  0.15093348920345306
# else
# ================================================================================
# Epoch 31 completed
# Average train loss is 0.06403777244500816:
# Average validation loss is 0.1100297381542623
# ================================================================================
# Epoch:  32 Batch:  0 Current Loss:  0.03888334333896637
# Epoch:  32 Batch:  50 Current Loss:  0.036945734173059464
# Epoch:  32 Batch:  100 Current Loss:  0.027557842433452606
# Epoch:  32 Batch:  150 Current Loss:  0.044288355857133865
# Epoch:  32 Batch:  200 Current Loss:  0.12275733798742294
# Epoch:  32 Batch:  250 Current Loss:  0.043876733630895615
# Epoch:  32 Batch:  300 Current Loss:  0.04177136346697807
# Epoch:  32 Batch:  350 Current Loss:  0.035629432648420334
# else
# ================================================================================
# Epoch 32 completed
# Average train loss is 0.06276029695756734:
# Average validation loss is 0.07041250769048929
# ================================================================================
# Epoch:  33 Batch:  0 Current Loss:  0.048965293914079666
# Epoch:  33 Batch:  50 Current Loss:  0.04139658808708191
# Epoch:  33 Batch:  100 Current Loss:  0.09831957519054413
# Epoch:  33 Batch:  150 Current Loss:  0.05508609116077423
# Epoch:  33 Batch:  200 Current Loss:  0.11281253397464752
# Epoch:  33 Batch:  250 Current Loss:  0.03542167693376541
# Epoch:  33 Batch:  300 Current Loss:  0.045860517770051956
# Epoch:  33 Batch:  350 Current Loss:  0.06041378527879715
# else
# ================================================================================
# Epoch 33 completed
# Average train loss is 0.06489092011004687:
# Average validation loss is 0.07565241513773799
# ================================================================================
# Epoch:  34 Batch:  0 Current Loss:  0.047900110483169556
# Epoch:  34 Batch:  50 Current Loss:  0.08475794643163681
# Epoch:  34 Batch:  100 Current Loss:  0.04038316756486893
# Epoch:  34 Batch:  150 Current Loss:  0.1148490458726883
# Epoch:  34 Batch:  200 Current Loss:  0.032448168843984604
# Epoch:  34 Batch:  250 Current Loss:  0.05332548916339874
# Epoch:  34 Batch:  300 Current Loss:  0.02748088538646698
# Epoch:  34 Batch:  350 Current Loss:  0.05629824101924896
# else
# ================================================================================
# Epoch 34 completed
# Average train loss is 0.062199327903799714:
# Average validation loss is 0.061764199435710904
# ================================================================================
# Epoch:  35 Batch:  0 Current Loss:  0.0669301301240921
# Epoch:  35 Batch:  50 Current Loss:  0.06292976438999176
# Epoch:  35 Batch:  100 Current Loss:  0.1024135872721672
# Epoch:  35 Batch:  150 Current Loss:  0.03449089080095291
# Epoch:  35 Batch:  200 Current Loss:  0.047349024564027786
# Epoch:  35 Batch:  250 Current Loss:  0.09247006475925446
# Epoch:  35 Batch:  300 Current Loss:  0.07019911706447601
# Epoch:  35 Batch:  350 Current Loss:  0.032931238412857056
# else
# ================================================================================
# Epoch 35 completed
# Average train loss is 0.062260108636692166:
# Average validation loss is 0.06810031419619918
# ================================================================================
# Epoch:  36 Batch:  0 Current Loss:  0.028133410960435867
# Epoch:  36 Batch:  50 Current Loss:  0.32204562425613403
# Epoch:  36 Batch:  100 Current Loss:  0.0937010794878006
# Epoch:  36 Batch:  150 Current Loss:  0.04167123883962631
# Epoch:  36 Batch:  200 Current Loss:  0.0341656394302845
# Epoch:  36 Batch:  250 Current Loss:  0.03826158493757248
# Epoch:  36 Batch:  300 Current Loss:  0.04521175101399422
# Epoch:  36 Batch:  350 Current Loss:  0.11323598027229309
# else
# ================================================================================
# Epoch 36 completed
# Average train loss is 0.06057614137418568:
# Average validation loss is 0.06587079878896475
# ================================================================================
# Epoch:  37 Batch:  0 Current Loss:  0.06943827122449875
# Epoch:  37 Batch:  50 Current Loss:  0.04092114418745041
# Epoch:  37 Batch:  100 Current Loss:  0.03475353866815567
# Epoch:  37 Batch:  150 Current Loss:  0.0500752329826355
# Epoch:  37 Batch:  200 Current Loss:  0.08447744697332382
# Epoch:  37 Batch:  250 Current Loss:  0.04664887487888336
# Epoch:  37 Batch:  300 Current Loss:  0.051822271198034286
# Epoch:  37 Batch:  350 Current Loss:  0.036060649901628494
# else
# ================================================================================
# Epoch 37 completed
# Average train loss is 0.060251777586527167:
# Average validation loss is 0.11348065715283155
# ================================================================================
# Epoch:  38 Batch:  0 Current Loss:  0.08545838296413422
# Epoch:  38 Batch:  50 Current Loss:  0.08250822126865387
# Epoch:  38 Batch:  100 Current Loss:  0.03306029736995697
# Epoch:  38 Batch:  150 Current Loss:  0.03849359601736069
# Epoch:  38 Batch:  200 Current Loss:  0.09550507366657257
# Epoch:  38 Batch:  250 Current Loss:  0.11209084093570709
# Epoch:  38 Batch:  300 Current Loss:  0.26357585191726685
# Epoch:  38 Batch:  350 Current Loss:  0.03506571799516678
# else
# ================================================================================
# Epoch 38 completed
# Average train loss is 0.06059013632126153:
# Average validation loss is 0.06517761604860425
# ================================================================================
# Epoch:  39 Batch:  0 Current Loss:  0.044604163616895676
# Epoch:  39 Batch:  50 Current Loss:  0.06612948328256607
# Epoch:  39 Batch:  100 Current Loss:  0.21689599752426147
# Epoch:  39 Batch:  150 Current Loss:  0.06831522285938263
# Epoch:  39 Batch:  200 Current Loss:  0.05668525770306587
# Epoch:  39 Batch:  250 Current Loss:  0.06336760520935059
# Epoch:  39 Batch:  300 Current Loss:  0.027010658755898476
# Epoch:  39 Batch:  350 Current Loss:  0.050617024302482605
# else
# ================================================================================
# Epoch 39 completed
# Average train loss is 0.05877334177028388:
# Average validation loss is 0.06202528787776828
# ================================================================================
# Epoch:  40 Batch:  0 Current Loss:  0.07934698462486267
# Epoch:  40 Batch:  50 Current Loss:  0.038472652435302734
# Epoch:  40 Batch:  100 Current Loss:  0.06505727022886276
# Epoch:  40 Batch:  150 Current Loss:  0.02775171957910061
# Epoch:  40 Batch:  200 Current Loss:  0.04578249156475067
# Epoch:  40 Batch:  250 Current Loss:  0.0464506670832634
# Epoch:  40 Batch:  300 Current Loss:  0.0819864422082901
# Epoch:  40 Batch:  350 Current Loss:  0.06800959259271622
# else
# ================================================================================
# Epoch 40 completed
# Average train loss is 0.05864050315227359:
# Average validation loss is 0.06891148531809449
# ================================================================================
# Epoch:  41 Batch:  0 Current Loss:  0.06749500334262848
# Epoch:  41 Batch:  50 Current Loss:  0.0547376349568367
# Epoch:  41 Batch:  100 Current Loss:  0.03867095336318016
# Epoch:  41 Batch:  150 Current Loss:  0.11097897589206696
# Epoch:  41 Batch:  200 Current Loss:  0.07633089274168015
# Epoch:  41 Batch:  250 Current Loss:  0.039679501205682755
# Epoch:  41 Batch:  300 Current Loss:  0.03906942158937454
# Epoch:  41 Batch:  350 Current Loss:  0.08581547439098358
# else
# ================================================================================
# Epoch 41 completed
# Average train loss is 0.05912506085354835:
# Average validation loss is 0.26174416648223997
# ================================================================================
# Epoch:  42 Batch:  0 Current Loss:  0.05021696910262108
# Epoch:  42 Batch:  50 Current Loss:  0.06956016272306442
# Epoch:  42 Batch:  100 Current Loss:  0.05496867001056671
# Epoch:  42 Batch:  150 Current Loss:  0.029592035338282585
# Epoch:  42 Batch:  200 Current Loss:  0.0366118922829628
# Epoch:  42 Batch:  250 Current Loss:  0.049398940056562424
# Epoch:  42 Batch:  300 Current Loss:  0.05209255591034889
# Epoch:  42 Batch:  350 Current Loss:  0.03910905495285988
# else
# ================================================================================
# Epoch 42 completed
# Average train loss is 0.05756455617491156:
# Average validation loss is 0.05784909581765532
# ================================================================================
# Epoch:  43 Batch:  0 Current Loss:  0.023791544139385223
# Epoch:  43 Batch:  50 Current Loss:  0.06906656920909882
# Epoch:  43 Batch:  100 Current Loss:  0.12551935017108917
# Epoch:  43 Batch:  150 Current Loss:  0.03128699213266373
# Epoch:  43 Batch:  200 Current Loss:  0.02363547682762146
# Epoch:  43 Batch:  250 Current Loss:  0.053442977368831635
# Epoch:  43 Batch:  300 Current Loss:  0.025235194712877274
# Epoch:  43 Batch:  350 Current Loss:  0.03844928741455078
# else
# ================================================================================
# Epoch 43 completed
# Average train loss is 0.05626087942160666:
# Average validation loss is 0.05819047996774316
# ================================================================================
# Epoch:  44 Batch:  0 Current Loss:  0.056070052087306976
# Epoch:  44 Batch:  50 Current Loss:  0.030409542843699455
# Epoch:  44 Batch:  100 Current Loss:  0.031519852578639984
# Epoch:  44 Batch:  150 Current Loss:  0.03199077397584915
# Epoch:  44 Batch:  200 Current Loss:  0.09044499695301056
# Epoch:  44 Batch:  250 Current Loss:  0.09887303411960602
# Epoch:  44 Batch:  300 Current Loss:  0.07770469039678574
# Epoch:  44 Batch:  350 Current Loss:  0.03690502047538757
# else
# ================================================================================
# Epoch 44 completed
# Average train loss is 0.059082238269038495:
# Average validation loss is 0.05958969762548804
# ================================================================================
# Epoch:  45 Batch:  0 Current Loss:  0.033559009432792664
# Epoch:  45 Batch:  50 Current Loss:  0.042213812470436096
# Epoch:  45 Batch:  100 Current Loss:  0.09013396501541138
# Epoch:  45 Batch:  150 Current Loss:  0.05922398716211319
# Epoch:  45 Batch:  200 Current Loss:  0.03074565716087818
# Epoch:  45 Batch:  250 Current Loss:  0.036964286118745804
# Epoch:  45 Batch:  300 Current Loss:  0.034840285778045654
# Epoch:  45 Batch:  350 Current Loss:  0.050162285566329956
# else
# ================================================================================
# Epoch 45 completed
# Average train loss is 0.056176379099488256:
# Average validation loss is 0.056432001516222956
# ================================================================================
# Epoch:  46 Batch:  0 Current Loss:  0.038184136152267456
# Epoch:  46 Batch:  50 Current Loss:  0.0417049303650856
# Epoch:  46 Batch:  100 Current Loss:  0.04594682157039642
# Epoch:  46 Batch:  150 Current Loss:  0.0317392535507679
# Epoch:  46 Batch:  200 Current Loss:  0.03240959718823433
# Epoch:  46 Batch:  250 Current Loss:  0.054481878876686096
# Epoch:  46 Batch:  300 Current Loss:  0.0441376268863678
# Epoch:  46 Batch:  350 Current Loss:  0.0555044449865818
# else
# ================================================================================
# Epoch 46 completed
# Average train loss is 0.054054584382101895:
# Average validation loss is 0.06242533637210727
# ================================================================================
# Epoch:  47 Batch:  0 Current Loss:  0.02499016560614109
# Epoch:  47 Batch:  50 Current Loss:  0.14327235519886017
# Epoch:  47 Batch:  100 Current Loss:  0.035831768065690994
# Epoch:  47 Batch:  150 Current Loss:  0.024903111159801483
# Epoch:  47 Batch:  200 Current Loss:  0.029712289571762085
# Epoch:  47 Batch:  250 Current Loss:  0.09439026564359665
# Epoch:  47 Batch:  300 Current Loss:  0.027975594624876976
# Epoch:  47 Batch:  350 Current Loss:  0.046322647482156754
# else
# ================================================================================
# Epoch 47 completed
# Average train loss is 0.05466154906898737:
# Average validation loss is 0.05565573243424296
# ================================================================================
# Epoch:  48 Batch:  0 Current Loss:  0.13354426622390747
# Epoch:  48 Batch:  50 Current Loss:  0.040870923548936844
# Epoch:  48 Batch:  100 Current Loss:  0.07742113620042801
# Epoch:  48 Batch:  150 Current Loss:  0.045617543160915375
# Epoch:  48 Batch:  200 Current Loss:  0.04628170654177666
# Epoch:  48 Batch:  250 Current Loss:  0.04034710302948952
# Epoch:  48 Batch:  300 Current Loss:  0.025041043758392334
# Epoch:  48 Batch:  350 Current Loss:  0.02559041604399681
# else
# ================================================================================
# Epoch 48 completed
# Average train loss is 0.053037901353091:
# Average validation loss is 0.061405734103173015
# ================================================================================
# Epoch:  49 Batch:  0 Current Loss:  0.04645482823252678
# Epoch:  49 Batch:  50 Current Loss:  0.08181431889533997
# Epoch:  49 Batch:  100 Current Loss:  0.027915306389331818
# Epoch:  49 Batch:  150 Current Loss:  0.039147257804870605
# Epoch:  49 Batch:  200 Current Loss:  0.061719559133052826
# Epoch:  49 Batch:  250 Current Loss:  0.0890887901186943
# Epoch:  49 Batch:  300 Current Loss:  0.031099895015358925
# Epoch:  49 Batch:  350 Current Loss:  0.023181095719337463
# else
# ================================================================================
# Epoch 49 completed
# Average train loss is 0.05286414703819901:
# Average validation loss is 0.0634935494326055
# ================================================================================
# Epoch:  50 Batch:  0 Current Loss:  0.025761175900697708
# Epoch:  50 Batch:  50 Current Loss:  0.029254471883177757
# Epoch:  50 Batch:  100 Current Loss:  0.031376004219055176
# Epoch:  50 Batch:  150 Current Loss:  0.05487263202667236
# Epoch:  50 Batch:  200 Current Loss:  0.0488465391099453
# Epoch:  50 Batch:  250 Current Loss:  0.03516002744436264
# Epoch:  50 Batch:  300 Current Loss:  0.025065526366233826
# Epoch:  50 Batch:  350 Current Loss:  0.030575137585401535
# else
# ================================================================================
# Epoch 50 completed
# Average train loss is 0.052192770671099425:
# Average validation loss is 0.0838751739822328
# ================================================================================
# Epoch:  51 Batch:  0 Current Loss:  0.04476897045969963
# Epoch:  51 Batch:  50 Current Loss:  0.03906720131635666
# Epoch:  51 Batch:  100 Current Loss:  0.037044987082481384
# Epoch:  51 Batch:  150 Current Loss:  0.10575484484434128
# Epoch:  51 Batch:  200 Current Loss:  0.04268494248390198
# Epoch:  51 Batch:  250 Current Loss:  0.03085407242178917
# Epoch:  51 Batch:  300 Current Loss:  0.06720571964979172
# Epoch:  51 Batch:  350 Current Loss:  0.027463022619485855
# else
# ================================================================================
# Epoch 51 completed
# Average train loss is 0.0512630228837952:
# Average validation loss is 0.05862123854458332
# ================================================================================
# Epoch:  52 Batch:  0 Current Loss:  0.03189375624060631
# Epoch:  52 Batch:  50 Current Loss:  0.046619292348623276
# Epoch:  52 Batch:  100 Current Loss:  0.01866840571165085
# Epoch:  52 Batch:  150 Current Loss:  0.028229791671037674
# Epoch:  52 Batch:  200 Current Loss:  0.07925008237361908
# Epoch:  52 Batch:  250 Current Loss:  0.07468715310096741
# Epoch:  52 Batch:  300 Current Loss:  0.041861698031425476
# Epoch:  52 Batch:  350 Current Loss:  0.04539869353175163
# else
# ================================================================================
# Epoch 52 completed
# Average train loss is 0.05333928177133203:
# Average validation loss is 0.059461684897542
# ================================================================================
# Epoch:  53 Batch:  0 Current Loss:  0.039237119257450104
# Epoch:  53 Batch:  50 Current Loss:  0.03933960571885109
# Epoch:  53 Batch:  100 Current Loss:  0.03379468247294426
# Epoch:  53 Batch:  150 Current Loss:  0.06516116857528687
# Epoch:  53 Batch:  200 Current Loss:  0.0881267637014389
# Epoch:  53 Batch:  250 Current Loss:  0.10634752362966537
# Epoch:  53 Batch:  300 Current Loss:  0.04512088745832443
# Epoch:  53 Batch:  350 Current Loss:  0.022194858640432358
# else
# ================================================================================
# Epoch 53 completed
# Average train loss is 0.052899048957042394:
# Average validation loss is 0.05427616866305471
# ================================================================================
# Epoch:  54 Batch:  0 Current Loss:  0.05630822852253914
# Epoch:  54 Batch:  50 Current Loss:  0.05080054700374603
# Epoch:  54 Batch:  100 Current Loss:  0.02962605096399784
# Epoch:  54 Batch:  150 Current Loss:  0.1258237659931183
# Epoch:  54 Batch:  200 Current Loss:  0.031294625252485275
# Epoch:  54 Batch:  250 Current Loss:  0.05524732172489166
# Epoch:  54 Batch:  300 Current Loss:  0.07390999048948288
# Epoch:  54 Batch:  350 Current Loss:  0.06462505459785461
# else
# ================================================================================
# Epoch 54 completed
# Average train loss is 0.05208702610339969:
# Average validation loss is 0.05940237684175372
# ================================================================================
# Epoch:  55 Batch:  0 Current Loss:  0.056334998458623886
# Epoch:  55 Batch:  50 Current Loss:  0.028520748019218445
# Epoch:  55 Batch:  100 Current Loss:  0.0746532455086708
# Epoch:  55 Batch:  150 Current Loss:  0.03360937908291817
# Epoch:  55 Batch:  200 Current Loss:  0.0509207658469677
# Epoch:  55 Batch:  250 Current Loss:  0.034458011388778687
# Epoch:  55 Batch:  300 Current Loss:  0.03308764845132828
# Epoch:  55 Batch:  350 Current Loss:  0.033892493695020676
# else
# ================================================================================
# Epoch 55 completed
# Average train loss is 0.05101261060219258:
# Average validation loss is 0.05150823637843132
# ================================================================================
# Epoch:  56 Batch:  0 Current Loss:  0.035231441259384155
# Epoch:  56 Batch:  50 Current Loss:  0.06898472458124161
# Epoch:  56 Batch:  100 Current Loss:  0.060183800756931305
# Epoch:  56 Batch:  150 Current Loss:  0.03924482315778732
# Epoch:  56 Batch:  200 Current Loss:  0.1014760434627533
# Epoch:  56 Batch:  250 Current Loss:  0.02756359428167343
# Epoch:  56 Batch:  300 Current Loss:  0.04056473821401596
# Epoch:  56 Batch:  350 Current Loss:  0.04043824225664139
# else
# ================================================================================
# Epoch 56 completed
# Average train loss is 0.05031651800964028:
# Average validation loss is 0.062352803144603966
# ================================================================================
# Epoch:  57 Batch:  0 Current Loss:  0.02947080321609974
# Epoch:  57 Batch:  50 Current Loss:  0.03653495013713837
# Epoch:  57 Batch:  100 Current Loss:  0.026667743921279907
# Epoch:  57 Batch:  150 Current Loss:  0.04181591421365738
# Epoch:  57 Batch:  200 Current Loss:  0.09208720922470093
# Epoch:  57 Batch:  250 Current Loss:  0.040969010442495346
# Epoch:  57 Batch:  300 Current Loss:  0.031456850469112396
# Epoch:  57 Batch:  350 Current Loss:  0.05708865448832512
# else
# ================================================================================
# Epoch 57 completed
# Average train loss is 0.050957590891048316:
# Average validation loss is 0.05335685670375824
# ================================================================================
# Epoch:  58 Batch:  0 Current Loss:  0.02723098173737526
# Epoch:  58 Batch:  50 Current Loss:  0.07251741737127304
# Epoch:  58 Batch:  100 Current Loss:  0.0847289115190506
# Epoch:  58 Batch:  150 Current Loss:  0.045578815042972565
# Epoch:  58 Batch:  200 Current Loss:  0.07474216818809509
# Epoch:  58 Batch:  250 Current Loss:  0.04064597934484482
# Epoch:  58 Batch:  300 Current Loss:  0.055181585252285004
# Epoch:  58 Batch:  350 Current Loss:  0.07002575695514679
# else
# ================================================================================
# Epoch 58 completed
# Average train loss is 0.04885318554472178:
# Average validation loss is 0.05502838677726686
# ================================================================================
# Epoch:  59 Batch:  0 Current Loss:  0.04583396762609482
# Epoch:  59 Batch:  50 Current Loss:  0.04443828761577606
# Epoch:  59 Batch:  100 Current Loss:  0.057642996311187744
# Epoch:  59 Batch:  150 Current Loss:  0.05151024088263512
# Epoch:  59 Batch:  200 Current Loss:  0.03353556990623474
# Epoch:  59 Batch:  250 Current Loss:  0.08825745433568954
# Epoch:  59 Batch:  300 Current Loss:  0.03791557997465134
# Epoch:  59 Batch:  350 Current Loss:  0.032678812742233276
# else
# ================================================================================
# Epoch 59 completed
# Average train loss is 0.047020791205577554:
# Average validation loss is 0.05566722679883242
# ================================================================================
# Epoch:  60 Batch:  0 Current Loss:  0.04297550022602081
# Epoch:  60 Batch:  50 Current Loss:  0.06171918660402298
# Epoch:  60 Batch:  100 Current Loss:  0.03346332907676697
# Epoch:  60 Batch:  150 Current Loss:  0.07358202338218689
# Epoch:  60 Batch:  200 Current Loss:  0.029841378331184387
# Epoch:  60 Batch:  250 Current Loss:  0.058811791241168976
# Epoch:  60 Batch:  300 Current Loss:  0.042040929198265076
# Epoch:  60 Batch:  350 Current Loss:  0.07043038308620453
# else
# ================================================================================
# Epoch 60 completed
# Average train loss is 0.04987621312495321:
# Average validation loss is 0.057176637649536136
# ================================================================================
# Epoch:  61 Batch:  0 Current Loss:  0.03592842444777489
# Epoch:  61 Batch:  50 Current Loss:  0.037603847682476044
# Epoch:  61 Batch:  100 Current Loss:  0.023038651794195175
# Epoch:  61 Batch:  150 Current Loss:  0.0915226861834526
# Epoch:  61 Batch:  200 Current Loss:  0.058431144803762436
# Epoch:  61 Batch:  250 Current Loss:  0.03321099653840065
# Epoch:  61 Batch:  300 Current Loss:  0.04181409999728203
# Epoch:  61 Batch:  350 Current Loss:  0.035613130778074265
# else
# ================================================================================
# Epoch 61 completed
# Average train loss is 0.05175983463879675:
# Average validation loss is 0.055390647631138566
# ================================================================================
# Epoch:  62 Batch:  0 Current Loss:  0.046683419495821
# Epoch:  62 Batch:  50 Current Loss:  0.04699009284377098
# Epoch:  62 Batch:  100 Current Loss:  0.0658084973692894
# Epoch:  62 Batch:  150 Current Loss:  0.09388066083192825
# Epoch:  62 Batch:  200 Current Loss:  0.05060698091983795
# Epoch:  62 Batch:  250 Current Loss:  0.06115375831723213
# Epoch:  62 Batch:  300 Current Loss:  0.0455901101231575
# Epoch:  62 Batch:  350 Current Loss:  0.047815486788749695
# else
# ================================================================================
# Epoch 62 completed
# Average train loss is 0.05018122853944078:
# Average validation loss is 0.05616469915956259
# ================================================================================
# Epoch:  63 Batch:  0 Current Loss:  0.05241994932293892
# Epoch:  63 Batch:  50 Current Loss:  0.02065499685704708
# Epoch:  63 Batch:  100 Current Loss:  0.0941346138715744
# Epoch:  63 Batch:  150 Current Loss:  0.020749254152178764
# Epoch:  63 Batch:  200 Current Loss:  0.026526952162384987
# Epoch:  63 Batch:  250 Current Loss:  0.03242829069495201
# Epoch:  63 Batch:  300 Current Loss:  0.03602179139852524
# Epoch:  63 Batch:  350 Current Loss:  0.02440151572227478
# else
# ================================================================================
# Epoch 63 completed
# Average train loss is 0.04772314886562526:
# Average validation loss is 0.06486247420310974
# ================================================================================
# Epoch:  64 Batch:  0 Current Loss:  0.07032707333564758
# Epoch:  64 Batch:  50 Current Loss:  0.025311581790447235
# Epoch:  64 Batch:  100 Current Loss:  0.04954289272427559
# Epoch:  64 Batch:  150 Current Loss:  0.029121097177267075
# Epoch:  64 Batch:  200 Current Loss:  0.07128622382879257
# Epoch:  64 Batch:  250 Current Loss:  0.06709584593772888
# Epoch:  64 Batch:  300 Current Loss:  0.050788771361112595
# Epoch:  64 Batch:  350 Current Loss:  0.04851185902953148
# else
# ================================================================================
# Epoch 64 completed
# Average train loss is 0.050406404617242516:
# Average validation loss is 0.05787588914856315
# ================================================================================
# Epoch:  65 Batch:  0 Current Loss:  0.028622733429074287
# Epoch:  65 Batch:  50 Current Loss:  0.02732931077480316
# Epoch:  65 Batch:  100 Current Loss:  0.028069717809557915
# Epoch:  65 Batch:  150 Current Loss:  0.03178040683269501
# Epoch:  65 Batch:  200 Current Loss:  0.0420970618724823
# Epoch:  65 Batch:  250 Current Loss:  0.03188595175743103
# Epoch:  65 Batch:  300 Current Loss:  0.04850509762763977
# Epoch:  65 Batch:  350 Current Loss:  0.049711622297763824
# else
# ================================================================================
# Epoch 65 completed
# Average train loss is 0.050721546020358804:
# Average validation loss is 0.05014990519732237
# ================================================================================
# Epoch:  66 Batch:  0 Current Loss:  0.1222720667719841
# ...
# Epoch 229 completed
# Average train loss is 0.027763644666410982:
# Average validation loss is 0.05025715637952089
# ================================================================================
# Epoch:  230 Batch:  0 Current Loss:  0.03374936059117317
# Epoch:  230 Batch:  50 Current Loss:  0.024970492348074913
# Epoch:  230 Batch:  100 Current Loss:  0.013598769903182983
# Epoch:  230 Batch:  150 Current Loss:  0.02148512750864029
# Epoch:  230 Batch:  200 Current Loss:  0.030429046601057053
# Epoch:  230 Batch:  250 Current Loss:  0.0184423066675663
# Epoch:  230 Batch:  300 Current Loss:  0.029021436348557472
# Epoch:  230 Batch:  350 Current Loss:  0.024244552478194237
# else
# ================================================================================
# Epoch 230 completed
# Average train loss is 0.030111340053845196:
# Average validation loss is 0.05659642491489649
# ================================================================================
# Epoch:  231 Batch:  0 Current Loss:  0.02526351436972618
# Epoch:  231 Batch:  50 Current Loss:  0.03422006592154503
# Epoch:  231 Batch:  100 Current Loss:  0.04894710332155228
# Epoch:  231 Batch:  150 Current Loss:  0.031057946383953094
# Epoch:  231 Batch:  200 Current Loss:  0.04884738102555275
# Epoch:  231 Batch:  250 Current Loss:  0.019629059359431267
# Epoch:  231 Batch:  300 Current Loss:  0.025871464982628822
# Epoch:  231 Batch:  350 Current Loss:  0.03957834094762802
# else
# ================================================================================
# Epoch 231 completed
# Average train loss is 0.028343789796344936:
# Average validation loss is 0.054090746026486156
# ================================================================================
# Epoch:  232 Batch:  0 Current Loss:  0.01958523690700531
# Epoch:  232 Batch:  50 Current Loss:  0.0323774628341198
# Epoch:  232 Batch:  100 Current Loss:  0.03246990591287613
# Epoch:  232 Batch:  150 Current Loss:  0.02698323130607605
# Epoch:  232 Batch:  200 Current Loss:  0.028229152783751488
# Epoch:  232 Batch:  250 Current Loss:  0.025120779871940613
# Epoch:  232 Batch:  300 Current Loss:  0.018443703651428223
# Epoch:  232 Batch:  350 Current Loss:  0.03702259808778763
# else
# ================================================================================
# Epoch 232 completed
# Average train loss is 0.029019504450261593:
# Average validation loss is 0.05854643726721406
# ================================================================================
# Epoch:  233 Batch:  0 Current Loss:  0.019732123240828514
# Epoch:  233 Batch:  50 Current Loss:  0.01636023260653019
# Epoch:  233 Batch:  100 Current Loss:  0.022053638473153114
# Epoch:  233 Batch:  150 Current Loss:  0.026665769517421722
# Epoch:  233 Batch:  200 Current Loss:  0.023916350677609444
# Epoch:  233 Batch:  250 Current Loss:  0.02567679062485695
# Epoch:  233 Batch:  300 Current Loss:  0.030402302742004395
# Epoch:  233 Batch:  350 Current Loss:  0.02882390096783638
# else
# ================================================================================
# Epoch 233 completed
# Average train loss is 0.026269222635310143:
# Average validation loss is 0.054596108216792345
# ================================================================================
# Epoch:  234 Batch:  0 Current Loss:  0.02417883463203907
# Epoch:  234 Batch:  50 Current Loss:  0.023660071194171906
# Epoch:  234 Batch:  100 Current Loss:  0.016318660229444504
# Epoch:  234 Batch:  150 Current Loss:  0.03248484060168266
# Epoch:  234 Batch:  200 Current Loss:  0.025791551917791367
# Epoch:  234 Batch:  250 Current Loss:  0.04057629778981209
# Epoch:  234 Batch:  300 Current Loss:  0.01644398272037506
# Epoch:  234 Batch:  350 Current Loss:  0.045776840299367905
# else
# ================================================================================
# Epoch 234 completed
# Average train loss is 0.027152929895091802:
# Average validation loss is 0.0550523971952498
# ================================================================================
# Epoch:  235 Batch:  0 Current Loss:  0.039296653121709824
# Epoch:  235 Batch:  50 Current Loss:  0.017000602558255196
# Epoch:  235 Batch:  100 Current Loss:  0.029225096106529236
# Epoch:  235 Batch:  150 Current Loss:  0.032722242176532745
# Epoch:  235 Batch:  200 Current Loss:  0.020194195210933685
# Epoch:  235 Batch:  250 Current Loss:  0.02880753017961979
# Epoch:  235 Batch:  300 Current Loss:  0.027956563979387283
# Epoch:  235 Batch:  350 Current Loss:  0.01877700909972191
# else
# ================================================================================
# Epoch 235 completed
# Average train loss is 0.028213062288705258:
# Average validation loss is 0.055326733384281394
# ================================================================================
# Epoch:  236 Batch:  0 Current Loss:  0.02002982422709465
# Epoch:  236 Batch:  50 Current Loss:  0.060335803776979446
# Epoch:  236 Batch:  100 Current Loss:  0.030158113688230515
# Epoch:  236 Batch:  150 Current Loss:  0.021550409495830536
# Epoch:  236 Batch:  200 Current Loss:  0.023217815905809402
# Epoch:  236 Batch:  250 Current Loss:  0.020066041499376297
# Epoch:  236 Batch:  300 Current Loss:  0.04083729907870293
# Epoch:  236 Batch:  350 Current Loss:  0.018093187361955643
# else
# ================================================================================
# Epoch 236 completed
# Average train loss is 0.028058939392212778:
# Average validation loss is 0.06822990251705051
# ================================================================================
# Epoch:  237 Batch:  0 Current Loss:  0.011932626366615295
# Epoch:  237 Batch:  50 Current Loss:  0.03028223291039467
# Epoch:  237 Batch:  100 Current Loss:  0.01657462865114212
# Epoch:  237 Batch:  150 Current Loss:  0.027627617120742798
# Epoch:  237 Batch:  200 Current Loss:  0.03006584756076336
# Epoch:  237 Batch:  250 Current Loss:  0.019046319648623466
# Epoch:  237 Batch:  300 Current Loss:  0.07120347023010254
# Epoch:  237 Batch:  350 Current Loss:  0.029732655733823776
# else
# ================================================================================
# Epoch 237 completed
# Average train loss is 0.027076349947601556:
# Average validation loss is 0.05711619907990098
# ================================================================================
# Epoch:  238 Batch:  0 Current Loss:  0.05481811612844467
# Epoch:  238 Batch:  50 Current Loss:  0.020253920927643776
# Epoch:  238 Batch:  100 Current Loss:  0.023853644728660583
# Epoch:  238 Batch:  150 Current Loss:  0.03307964652776718
# Epoch:  238 Batch:  200 Current Loss:  0.02678936906158924
# Epoch:  238 Batch:  250 Current Loss:  0.02317545749247074
# Epoch:  238 Batch:  300 Current Loss:  0.030438009649515152
# Epoch:  238 Batch:  350 Current Loss:  0.020404398441314697
# else
# ================================================================================
# Epoch 238 completed
# Average train loss is 0.02743241275427863:
# Average validation loss is 0.0558706353418529
# ================================================================================
# Epoch:  239 Batch:  0 Current Loss:  0.021970383822917938
# Epoch:  239 Batch:  50 Current Loss:  0.021868642419576645
# Epoch:  239 Batch:  100 Current Loss:  0.03259796276688576
# Epoch:  239 Batch:  150 Current Loss:  0.025210170075297356
# Epoch:  239 Batch:  200 Current Loss:  0.020822247490286827
# Epoch:  239 Batch:  250 Current Loss:  0.024663787335157394
# Epoch:  239 Batch:  300 Current Loss:  0.038593590259552
# Epoch:  239 Batch:  350 Current Loss:  0.03356853127479553
# else
# ================================================================================
# Epoch 239 completed
# Average train loss is 0.029328112048096953:
# Average validation loss is 0.05167667118832469
# ================================================================================
# Epoch:  240 Batch:  0 Current Loss:  0.022038601338863373
# Epoch:  240 Batch:  50 Current Loss:  0.025371940806508064
# Epoch:  240 Batch:  100 Current Loss:  0.025307970121502876
# Epoch:  240 Batch:  150 Current Loss:  0.023026451468467712
# Epoch:  240 Batch:  200 Current Loss:  0.026413507759571075
# Epoch:  240 Batch:  250 Current Loss:  0.03228939324617386
# Epoch:  240 Batch:  300 Current Loss:  0.0200343020260334
# Epoch:  240 Batch:  350 Current Loss:  0.032118093222379684
# else
# ================================================================================
# Epoch 240 completed
# Average train loss is 0.028884666336234658:
# Average validation loss is 0.053464293237775566
# ================================================================================
# Epoch:  241 Batch:  0 Current Loss:  0.025038549676537514
# Epoch:  241 Batch:  50 Current Loss:  0.035853516310453415
# Epoch:  241 Batch:  100 Current Loss:  0.027965951710939407
# Epoch:  241 Batch:  150 Current Loss:  0.022746602073311806
# Epoch:  241 Batch:  200 Current Loss:  0.016843633726239204
# Epoch:  241 Batch:  250 Current Loss:  0.038349442183971405
# Epoch:  241 Batch:  300 Current Loss:  0.02422194741666317
# Epoch:  241 Batch:  350 Current Loss:  0.03397655114531517
# else
# ================================================================================
# Epoch 241 completed
# Average train loss is 0.027447828992735596:
# Average validation loss is 0.05870680703781545
# ================================================================================
# Epoch:  242 Batch:  0 Current Loss:  0.047803960740566254
# Epoch:  242 Batch:  50 Current Loss:  0.024534394964575768
# Epoch:  242 Batch:  100 Current Loss:  0.030494900420308113
# Epoch:  242 Batch:  150 Current Loss:  0.01776164397597313
# Epoch:  242 Batch:  200 Current Loss:  0.023129001259803772
# Epoch:  242 Batch:  250 Current Loss:  0.05246145650744438
# Epoch:  242 Batch:  300 Current Loss:  0.013922015205025673
# Epoch:  242 Batch:  350 Current Loss:  0.035069163888692856
# else
# ================================================================================
# Epoch 242 completed
# Average train loss is 0.028049965905956924:
# Average validation loss is 0.04914250748232007
# ================================================================================
# Epoch:  243 Batch:  0 Current Loss:  0.017781250178813934
# Epoch:  243 Batch:  50 Current Loss:  0.01671285182237625
# Epoch:  243 Batch:  100 Current Loss:  0.01652025803923607
# Epoch:  243 Batch:  150 Current Loss:  0.02877506986260414
# Epoch:  243 Batch:  200 Current Loss:  0.023410698398947716
# Epoch:  243 Batch:  250 Current Loss:  0.02974151261150837
# Epoch:  243 Batch:  300 Current Loss:  0.021506568416953087
# Epoch:  243 Batch:  350 Current Loss:  0.02497990056872368
# else
# ================================================================================
# Epoch 243 completed
# Average train loss is 0.026071307591628283:
# Average validation loss is 0.05644446471706033
# ================================================================================
# Epoch:  244 Batch:  0 Current Loss:  0.019987953826785088
# Epoch:  244 Batch:  50 Current Loss:  0.029292915016412735
# Epoch:  244 Batch:  100 Current Loss:  0.01956648752093315
# Epoch:  244 Batch:  150 Current Loss:  0.020654134452342987
# Epoch:  244 Batch:  200 Current Loss:  0.015600874088704586
# Epoch:  244 Batch:  250 Current Loss:  0.019817331805825233
# Epoch:  244 Batch:  300 Current Loss:  0.02361305244266987
# Epoch:  244 Batch:  350 Current Loss:  0.021181190386414528
# else
# ================================================================================
# Epoch 244 completed
# Average train loss is 0.027185060682240872:
# Average validation loss is 0.0583008124679327
# ================================================================================
# Epoch:  245 Batch:  0 Current Loss:  0.026285449042916298
# Epoch:  245 Batch:  50 Current Loss:  0.019901877269148827
# Epoch:  245 Batch:  100 Current Loss:  0.018814269453287125
# Epoch:  245 Batch:  150 Current Loss:  0.02113407850265503
# Epoch:  245 Batch:  200 Current Loss:  0.017835618928074837
# Epoch:  245 Batch:  250 Current Loss:  0.03224754333496094
# Epoch:  245 Batch:  300 Current Loss:  0.01633506640791893
# Epoch:  245 Batch:  350 Current Loss:  0.020044049248099327
# else
# ================================================================================
# Epoch 245 completed
# Average train loss is 0.025223415931686758:
# Average validation loss is 0.058202048735693096
# ================================================================================
# Epoch:  246 Batch:  0 Current Loss:  0.019763652235269547
# Epoch:  246 Batch:  50 Current Loss:  0.01942897029221058
# Epoch:  246 Batch:  100 Current Loss:  0.017979154363274574
# Epoch:  246 Batch:  150 Current Loss:  0.02756319008767605
# Epoch:  246 Batch:  200 Current Loss:  0.01722128316760063
# Epoch:  246 Batch:  250 Current Loss:  0.019445253536105156
# Epoch:  246 Batch:  300 Current Loss:  0.05314682796597481
# Epoch:  246 Batch:  350 Current Loss:  0.025727298110723495
# else
# ================================================================================
# Epoch 246 completed
# Average train loss is 0.02836353512480855:
# Average validation loss is 0.052143528014421466
# ================================================================================
# Epoch:  247 Batch:  0 Current Loss:  0.02242187224328518
# Epoch:  247 Batch:  50 Current Loss:  0.02207672782242298
# Epoch:  247 Batch:  100 Current Loss:  0.02255922555923462
# Epoch:  247 Batch:  150 Current Loss:  0.028704706579446793
# Epoch:  247 Batch:  200 Current Loss:  0.02873431332409382
# Epoch:  247 Batch:  250 Current Loss:  0.05078945681452751
# Epoch:  247 Batch:  300 Current Loss:  0.02061501145362854
# Epoch:  247 Batch:  350 Current Loss:  0.030293870717287064
# else
# ================================================================================
# Epoch 247 completed
# Average train loss is 0.02643027327954769:
# Average validation loss is 0.05117498451843858
# ================================================================================
# Epoch:  248 Batch:  0 Current Loss:  0.024342499673366547
# Epoch:  248 Batch:  50 Current Loss:  0.015199026092886925
# Epoch:  248 Batch:  100 Current Loss:  0.030213503167033195
# Epoch:  248 Batch:  150 Current Loss:  0.023750608786940575
# Epoch:  248 Batch:  200 Current Loss:  0.01765638031065464
# Epoch:  248 Batch:  250 Current Loss:  0.03716079145669937
# Epoch:  248 Batch:  300 Current Loss:  0.0470837727189064
# Epoch:  248 Batch:  350 Current Loss:  0.020812293514609337
# else
# ================================================================================
# Epoch 248 completed
# Average train loss is 0.02684122322127223:
# Average validation loss is 0.05189640492200851
# ================================================================================
# Epoch:  249 Batch:  0 Current Loss:  0.028339099138975143
# Epoch:  249 Batch:  50 Current Loss:  0.023591089993715286
# Epoch:  249 Batch:  100 Current Loss:  0.021383117884397507
# Epoch:  249 Batch:  150 Current Loss:  0.04770297184586525
# Epoch:  249 Batch:  200 Current Loss:  0.020565632730722427
# Epoch:  249 Batch:  250 Current Loss:  0.019647032022476196
# Epoch:  249 Batch:  300 Current Loss:  0.020868610590696335
# Epoch:  249 Batch:  350 Current Loss:  0.028086261823773384
# else
# ================================================================================
# Epoch 249 completed
# Average train loss is 0.025922913756221532:
# Average validation loss is 0.05522818174213171
# ================================================================================
# Epoch:  250 Batch:  0 Current Loss:  0.02048681117594242
# Epoch:  250 Batch:  50 Current Loss:  0.019221270456910133
# Epoch:  250 Batch:  100 Current Loss:  0.020351476967334747
# Epoch:  250 Batch:  150 Current Loss:  0.026911724358797073
# Epoch:  250 Batch:  200 Current Loss:  0.02362918294966221
# Epoch:  250 Batch:  250 Current Loss:  0.02485623024404049
# Epoch:  250 Batch:  300 Current Loss:  0.016040310263633728
# Epoch:  250 Batch:  350 Current Loss:  0.027509767562150955
# else
# ================================================================================
# Epoch 250 completed
# Average train loss is 0.02620762642007321:
# Average validation loss is 0.053251310251653194
# ================================================================================

# %%
torch.save(model,"Models/UNET-more-dropouts-250.pt")

# %%
plt.plot(train_running_loss_history, label = 'Train Loss')
plt.plot(validation_running_loss_history, label = 'Validation Loss')
plt.legend()

# %%
model.eval()
X_train.size()
# Out:
# torch.Size([1, 1, 572, 572])

# %%
out = (y_pred + 0.5).int().float()

# %%
print(dice_index(y_train, out))
print(dice_loss(y_train, out))
# Out:
# tensor(0.9864, device='cuda:0')
# tensor(0.0136, device='cuda:0')

# %%
# pig = plt.figure(figsize = (15, 6))

# a = pig.add_subplot(2, 3, 1)
# plt.imshow(im_converterX(X_train[0]))

# a = pig.add_subplot(2, 3, 2)
# plt.imshow(im_converterY(y_train[0]))

# a = pig.add_subplot(2, 3, 3)
# plt.imshow(im_converterY(out[0]))


# a = pig.add_subplot(2, 3, 4)
# plt.imshow(im_converterX(X_train[1]))

# a = pig.add_subplot(2, 3, 5)
# plt.imshow(im_converterY(y_train[1]))

# a = pig.add_subplot(2, 3, 6)
# plt.imshow(im_converterY(out[1]))

# %%
gg = dice_index(out, y_train)
print(gg)
print(dice_loss(out, y_train))
# Out:
# tensor(0.9864, device='cuda:0')
# tensor(0.0136, device='cuda:0')

# %%
class HC18_test(Dataset):
    def __init__(self, root_dir, transformX = None):
        self.pixel_file = pd.read_csv(os.path.join(root_dir, 'test_set_pixel_size.csv'))
        self.root_dir = root_dir
        self.transformX = transformX
        
    def __len__(self):
        return len(self.pixel_file)
    
    def __getitem__(self, index):
        imx_name = os.path.join(self.root_dir, 'test_set', self.pixel_file.iloc[index, 0])
        
        imx = Image.open(imx_name)
        
        f_name = self.pixel_file.iloc[index, 0]
        
        if self.transformX :
            imx = self.transformX(imx)
        
        sample = {'image': imx, 'f_name': f_name}
        return sample

# %%
test_data = HC18_test('', transformX = tx_X)

# %%
test_data

# %%
test_loader = DataLoader(dataset = test_data, batch_size = 2, shuffle = True)

# %%
test_loader

# %%
## Here we loop through our train_loader and see the images
## Looks good
fig = plt.figure(figsize = (15,6))
#model.to('cpu')
for ith_batch, sample_batched in enumerate(test_loader):
  
    X_test = sample_batched['image'].to('cuda')
    print(ith_batch, X_test.size())
    
    y_test = (model(X_test) + 0.5).int().float()
    
    
    
    for index in range(2):
        ax = fig.add_subplot(2, 2 , index + 1)  # subplot index starts from 1
        plt.imshow(im_converterX(X_test[index]))
        
        ax  = fig.add_subplot(2, 2, index + 3)
        plt.imshow(im_converterY(y_test[index]))
    break
# Out:
# 0 torch.Size([2, 1, 572, 572])

# %%
def avg_dice_index(dataloader):
  
    dice = 0.0
    model.eval()
    with torch.no_grad():
    
        for ith_batch, sample_batched in enumerate(dataloader):
  
            X_train = sample_batched['image'].to('cuda')
            y_train = sample_batched['annotation'].to('cuda')
            
            y_predict = (model(X_train) + 0.5).int().float()
            
            dice += dice_index(y_predict, y_train)
            
            
            
    avg_dice = dice / len(dataloader)
    return avg_dice.item()

# %%
avg_dice_index(validation_loader)    #### Dice index of validation data
# Out:
# 0.9652069807052612

# %%
avg_dice_index(train_loader)        ### Dice index of training data
# Out:
# 0.9764581918716431

# %%
test_loader = DataLoader(dataset = test_data, batch_size = 1, shuffle = True) # to write image files

# %% [markdown]
# ## **Warning!!!**
# ### Your are about to write on drive

# %%
transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((540, 800)),
        transforms.ToTensor()
        ])
    
with torch.no_grad():
      #model.eval()
      for ith_batch , sample in enumerate(test_loader):
        X_test = sample['image'].to('cuda')
        y_pred = (model(X_test) + 0.5).int().float().cpu()
#         print(335-ith_batch)
        
        file_names = sample['f_name']
        pankaj = transform(y_pred[0])
        #singh = transform(y_pred[1])
        torchvision.utils.save_image(pankaj , os.path.join('segmented', file_names[0]))
        #torchvision.utils.save_image(singh, os.path.join('/content/drive/My Drive/HC18/test_set', file_names[1].replace('.png','_Annotation.png')))
      print("Segmentation files written")
# Out:
# Segmentation files written

# %%
def fit_ellipse(im):    
    imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
    ret,thresh = cv2.threshold(imgray,127,255,0)
    contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    contour_sizes = [len(contour) for contour in contours]
    ellipse = cv2.fitEllipse(contours[np.argmax(contour_sizes)])
    return ellipse

# %%
file_names = sorted([file for _,_,files in os.walk('segmented/') for file in files])

# %%
df_pixel_size = pd.read_csv('test_set_pixel_size.csv')
submission = {'filename': [], 'center_x_mm': [], 'center_y_mm': [], 'semi_axes_a_mm': [],
             'semi_axes_b_mm': [], 'angle_rad': [], 'Index': []}

file_names = sorted([file for _,_,files in os.walk('segmented/') for file in files])

for i, file_name in enumerate(file_names):
    im = cv2.imread('segmented/'+file_name)
   # file_name = file_name.replace('_Segmented', '')
    ellipse = fit_ellipse(im)
    im_mask = cv2.ellipse(np.zeros_like(im),ellipse,(255,255,255),-1)
    image_name = file_name.split('.')[0] + '_Annotation_fit.png'
    #cv2.imwrite('/content/drive/My Drive/HC18/test_set/'+image_name, im_mask)
    
    pixel_size = df_pixel_size.loc[df_pixel_size['filename'] == file_name, 'pixel size(mm)'].iloc[0]
    submission['filename'].extend([file_name])
    submission['Index'].extend([int(file_name.split('_')[0])])
    center_x,  center_y = ellipse[0]
    submission['center_x_mm'].extend([pixel_size*center_x])
    submission['center_y_mm'].extend([pixel_size*center_y])
    semi_axes_b, semi_axes_a = ellipse[1]
    if semi_axes_b > semi_axes_a:
        semi_axes_b = semi_axes_b + semi_axes_a
        semi_axes_a = semi_axes_b - semi_axes_a
        semi_axes_b -= semi_axes_a
    submission['semi_axes_a_mm'].extend([semi_axes_a*pixel_size/2])
    submission['semi_axes_b_mm'].extend([semi_axes_b*pixel_size/2])
    angle = ellipse[2]
    if angle < 90:
        angle += 90
    else:
        angle -= 90
    submission['angle_rad'].extend([np.deg2rad(angle)])
    
submission = pd.DataFrame(submission)
submission = submission[['filename', 'center_x_mm', 'center_y_mm', 
                         'semi_axes_a_mm', 'semi_axes_b_mm', 'angle_rad', 'Index']]    
submission = submission.sort_values(['Index'])
submission = submission.drop('Index', axis=1)
submission.to_csv("UNET-more-dropouts-250.csv", index=False)
print('Required .csv file generated')
# Out:
# Required .csv file generated

# %%
q = pd.read_csv('UNET-more-dropouts-250.csv')  ## to check theck the generated csv

# %%
print('Length of csv file: ',len(q))
# Out:
# Length of csv file:  335

# %%
submission.head()
# Out:
#      filename  center_x_mm  center_y_mm  semi_axes_a_mm  semi_axes_b_mm  \
# 0  000_HC.png    94.884929    64.893586       54.127414       40.942545
# 1  001_HC.png    30.273914    21.401476       12.481284       10.527079
# 2  002_HC.png    60.776175    42.075110       38.668300       29.067211
# 3  003_HC.png    34.543247    27.323610       30.082409       23.211138
# 4  004_HC.png    81.307350    58.637528       58.560887       43.674067
#
#    angle_rad
# 0   3.097472
# 1   3.128517
# 2   0.063802
# 3   3.063866
# 4   0.044832
