# %% [markdown]
# <a href="https://colab.research.google.com/github/Pankaj1357/HC18-Grand-Challenge/blob/master/HC18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Compared with MVP:
#     Increased Learning rate to 0.0154
#     Cosine Scheduler for learning rate

# %%
import cv2
import os
import matplotlib.pyplot as plt
import pandas as pd
import time

# %% [markdown]
# # **Mask Generation**
# Done only once and replaced that  annotation with masks permanently
# Did not changed the annotation file name though

# %% [markdown]
# ## **Warning!!!**
# Do not run below cells as task is already completed

# %%
train_pixel_file = pd.read_csv('training_set_pixel_size_and_HC.csv')
train_pixel_file.head()
# This Dataframe will be used to extract image names hence by doing image_name + '_Annotation' we will get annotation names
# Out:
#      filename  pixel size(mm)  head circumference (mm)
# 0  000_HC.png        0.069136                    44.30
# 1  001_HC.png        0.089659                    56.81
# 2  002_HC.png        0.062033                    68.75
# 3  003_HC.png        0.091291                    69.00
# 4  004_HC.png        0.061240                    59.81

# %%
# This function takes annotation and spits out corresponding mask
def masking(image):
    imgray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(imgray, 127, 255, 0)
    contours,useless = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    ellipse = cv2.fitEllipse(contours[0])
    return cv2.ellipse(image, ellipse, (255,255,255), -1)

# %%
# to check if our masking function is working correctly
fig = plt.figure(figsize = (30,7))
for index in range(7):
  file_path = os.path.join('training_set', train_pixel_file.iloc[index, 0].replace('.png','_Annotation.png'))
  print(file_path)
  ax = fig.add_subplot(2, 7, index+1)             ## annoted plot
  plt.imshow(cv2.imread(file_path))
    
  ax = fig.add_subplot(2, 7, index+8)
  plt.imshow(masking(cv2.imread(file_path)))        ## mask plot
# Out:
# training_set/000_HC_Annotation.png
# training_set/001_HC_Annotation.png
# training_set/002_HC_Annotation.png
# training_set/003_HC_Annotation.png
# training_set/004_HC_Annotation.png
# training_set/005_HC_Annotation.png
# training_set/006_HC_Annotation.png

# %%
# Here we loop through training set and  take annotations one by one and replace them with corresponding masks
fig = plt.figure(figsize = (30,7))
for index in range(len(train_pixel_file)):
    file_path = os.path.join('training_set', train_pixel_file.iloc[index, 0].replace('.png','_Annotation.png'))
    image = cv2.imread(file_path)
    mask = masking(image)
    cv2.imwrite(file_path, mask)

# %% [markdown]
# ## **Warning!!!**
# **Done with mask generation. Don't run above cells ever again**

# %% [markdown]
# ### **Do all the imports in below cell**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from skimage import io, color
from PIL import Image
import cv2

import os
import random

import torch
from torch.utils.data  import Dataset, DataLoader
from torchvision import transforms
import torchvision.transforms.functional as TF
import torch.nn as nn
import torch.nn.functional as F
import torchvision

# %%
validation_set_size = 0.20            # fraction of dataset used for validation which will be splited randomly

# %%
# our dataset class
class HC18(Dataset):
  #""" train and validation dataset class"""
    def __init__(self, root_dir, train = True, transformX = None, transformY = None):
        self.pixel_file = pd.read_csv(os.path.join(root_dir, 'training_set_pixel_size_and_HC.csv'))
        self.root_dir = root_dir
        self.transformX = transformX
        self.transformY = transformY
        self.train = train
        
        # lets split the dataset in train and validation
        self.train_data, self.validation_data = train_test_split(self.pixel_file, test_size = validation_set_size, random_state = 5)
        
    def __len__(self):
        
        if self.train:
          length = len(self.train_data)
        else:
          length = len(self.validation_data)
        return length
    
    def __getitem__(self, index):
      
        if self.train:
          imx_name = os.path.join(self.root_dir, 'training_set', self.train_data.iloc[index, 0])
          imy_name = os.path.join(self.root_dir, 'training_set',self.train_data.iloc[index, 0].replace('.png','_Annotation.png'))

        else:
          imx_name = os.path.join(self.root_dir, 'training_set', self.validation_data.iloc[index, 0])
          imy_name = os.path.join(self.root_dir, 'training_set',self.validation_data.iloc[index, 0].replace('.png','_Annotation.png'))
        
        
        imx = Image.open(imx_name)
        imy = Image.open(imy_name).convert('L')
        
        ## tried some data augmentation techniques
        if self.train:
          # Random horizontal flipping
          if random.random() > 0.5:
              imx = TF.hflip(imx)
              imy = TF.hflip(imy)

          # Random vertical flipping
          if random.random() > 0.5:
              imx = TF.vflip(imx)
              imy = TF.vflip(imy)


          # Random rotation
          if random.random() > 0.8:
            angle = random.choice([-30, -90, -60, -45 -15, 0, 15, 30, 45, 60, 90])
            imx = TF.rotate(imx, angle)
            imy = TF.rotate(imy, angle)
        
        
        
        
        
        
        if self.transformX :
            imx = self.transformX(imx)
            imy = self.transformY(imy)
        
        sample = {'image': imx, 'annotation': imy}
        return sample

# %%
# our datasets
tx_X = transforms.Compose([ transforms.Resize((572, 572)),
                              transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,))
                              ])
tx_Y = transforms.Compose([ transforms.Resize((572, 572)),
                              transforms.ToTensor(),  ################ no need to normalize the maskk
                             # transforms.Normalize((0.5,), (0.5,))
                              ])
train_data = HC18('', train = True, transformX = tx_X, transformY = tx_Y)
validation_data = HC18('', train = False, transformX = tx_X, transformY = tx_Y )

# %%
# our dataloaders
train_loader = DataLoader(dataset = train_data, batch_size = 2, shuffle = True, num_workers = 2 )
validation_loader = DataLoader(dataset = validation_data, batch_size = 2, shuffle = True, num_workers = 2)

# %%
# this function will return numpy array from the transformed tensors which were
# obtained from our train_loader. Just to plot them and see if they are intact :) ha ha
def im_converterX(tensor):
    image = tensor.cpu().clone().detach().numpy() # make copy of tensor and converting it to numpy as we will need original later
    image = image.transpose(1,2,0) # swapping axes making (1, 28, 28) image to a (28, 28, 1)
 # print(image.shape)
    image = image * np.array((0.5, 0.5, 0.5)) + np.array((0.5, 0.5, 0.5)) # unnormalizing the image # this also outputs (28, 28, 3) which seems important for plt.imshow
    image = image.clip(0, 1) # to make sure final values are in range 0 to 1 as .ToTensor outputed
    return image

# %%
# this function will return numpy array from the transformed tensors which were
# obtained from our train_loader. Just to plot them and see if they are intact :) ha ha
def im_converterY(tensor):
    image = tensor.cpu().clone().detach().numpy() # make copy of tensor and converting it to numpy as we will need original later
    image = image.transpose(1,2,0) # swapping axes making (1, 28, 28) image to a (28, 28, 1)
 # print(image.shape)
    image = image * np.array((1, 1, 1)) # unnormalizing the image  not needed# this also outputs (28, 28, 3) which seems important for plt.imshow
    image = image.clip(0, 1) # to make sure final values are in range 0 to 1 as .ToTensor outputed
    return image

# %%
## Here we loop through our train_loader and see the images
## Looks good
fig = plt.figure(figsize = (15,6))
for ith_batch, sample_batched in enumerate(train_loader):
    print(ith_batch, sample_batched['image'].size(), sample_batched['annotation'].size())
    
    for index in range(2):
        ax = fig.add_subplot(2, 2 , index + 1)  # subplot index starts from 1
        plt.imshow(im_converterX(sample_batched['image'][index]))
        ax = fig.add_subplot(2, 2, index + 3)
        plt.imshow(im_converterY(sample_batched['annotation'][index]))
    break
# Out:
# 0 torch.Size([2, 1, 572, 572]) torch.Size([2, 1, 572, 572])

# %%
class double_conv(nn.Module):
    '''(conv => BN => ReLU) * 2'''

    def __init__(self, in_ch, out_ch):
        super(double_conv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            #nn.Dropout2d(0.7),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            #nn.Dropout2d(0.77),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x = self.conv(x)
        return x


class inconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(inconv, self).__init__()
        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x):
        x = self.conv(x)
        return x


class down(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(down, self).__init__()
        self.mpconv = nn.Sequential(
            nn.MaxPool2d(2),
            double_conv(in_ch, out_ch)
        )

    def forward(self, x):
        x = self.mpconv(x)
        return x


class up(nn.Module):
    def __init__(self, in_ch, out_ch, bilinear=True):
        super(up, self).__init__()

        if bilinear: #upsampling will not be learnable
            self.up = nn.Upsample(
                scale_factor=2, mode='bilinear', align_corners=True)
        else:  # it will be learnable here
            self.up = nn.ConvTranspose2d(in_ch // 2, in_ch // 2, 2, stride=2)
        
        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x1, x2):
        x1 = self.up(x1)

        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, (diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2))

        x = torch.cat([x2, x1], dim=1)
        x = self.conv(x)
        return x


class outconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(outconv, self).__init__()
        self.conv = nn.Conv2d(in_ch, out_ch, 1)

    def forward(self, x):
        x = self.conv(x)
        return x
    
    
class attention_gate(nn.Module):
    def __init__(self, in_ch_g,in_ch_x,out_ch):
        super(attention_gate, self).__init__()
        self.conv = nn.Conv2d(in_ch_g,in_ch_x, 1)
        self.conv_att = nn.Conv2d(in_ch_x,in_ch_x,1)
#         self.resampler = nn.Conv2d()

#     x orignal, g new
    def forward(self,g,x):
        orig_x = x        
#         upconv then downsample x
#         print(f'g = {g.shape}')
#         print(f'x = {x.shape}')
        g = self.conv(g)
        
        g = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)(g)
        diffY = x.size()[2] - g.size()[2]
        diffX = x.size()[3] - g.size()[3]

        g = F.pad(g, (diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2))
    
        a = g + x
        a = nn.ReLU()(a)
        a = nn.Sigmoid()(a)
        a = a * orig_x
        a = self.conv_att(a)
#         a = torch.reshape(a,shape)
        return a

# %%
class UNet(nn.Module):
    def __init__(self, n_channels, n_classes):
        super(UNet, self).__init__()
        self.inc = inconv(n_channels, 16)
        self.down1 = down(16, 32)
        self.down2 = down(32, 64)
        self.down3 = down(64, 64)
#         self.down4 = down(512, 512)
        self.up1 = up(128, 32, bilinear = False) # upsampling weights are made learnable
        self.up2 = up(64, 16, bilinear = False)
        self.up3 = up(32, 8, bilinear = False)
#         self.up4 = up(32, 8, bilinear = False)
       
        self.dropout = torch.nn.Dropout2d(0.5)
        self.ag3 = attention_gate(64,64,64)
        self.ag2 = attention_gate(32,32,32)
        self.ag1 = attention_gate(16,16,16)
        self.bot_conv1 = nn.Conv2d(64,8,3)
        self.bot_conv2 = nn.Conv2d(32,8,3)
        self.bot_conv3 = nn.Conv2d(16,8,3)
        self.bot_conv4 = nn.Conv2d(8,8,3)
        self.upsample1 = nn.Upsample(scale_factor=8, mode='bilinear', align_corners=True)
        self.upsample2 = nn.Upsample(scale_factor=4, mode='bilinear', align_corners=True)
        self.upsample3 = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        self.outc = outconv(32, n_classes)
        
    def forward(self, x):
        x = x.float()
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        ag3 = self.ag3(x4,x3)
        y1 = self.up1(x4, ag3)
#         print(y1.shape)
#         print(x2.shape)
        ag2 = self.ag2(y1,x2)
        y2 = self.up2(y1,ag2)
        y2 = self.dropout(y2)
        ag1 = self.ag1(y2,x1)
        y3 = self.up3(y2,ag1)
        #x = self.dropout(x) #
#         y3 = self.outc(y3)
#         y3 = torch.sigmoid(y3)
#         print(x4.shape) 
        
        # Bottom
        
        x4 =  self.bot_conv1(x4)
        x4 =  F.pad(x4,(1,1,1,1))
        y1 =  self.bot_conv2(y1)
        y1 = F.pad(y1,(1,1,1,1))
        y2 =  self.bot_conv3(y2)
        y2 = F.pad(y2,(1,1,1,1))
        y3 =  self.bot_conv4(y3)
        y3 = F.pad(y3,(1,1,1,1))
       
        x4 = self.upsample1(x4)
        x4 = F.pad(x4,(2,2,2,2))
        y1 = self.upsample2(y1)
        y2 = self.upsample3(y2)
        
        final = torch.cat([x4,y1,y2,y3], dim=1)
        final = self.outc(final)
        return torch.sigmoid(final)
      
      
      
      
      
      
model = UNet(1, 1)
model.to('cuda')
print("Model Loaded to GPU")
# Out:
# Model Loaded to GPU

# %%
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0154)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10, eta_min=0)

# %%
# calculates similarity index between predicted and actual segmentation
def dice_index(y_pred, y_actual):
    smooth = 0.000001
    size_of_batch = y_pred.size(0)
    
    p1 = y_pred.view(size_of_batch, -1)
    p2 = y_actual.view(size_of_batch, -1)
    
    intersection = (p1 * p2).sum()
    
    dice =  ((2.0 * intersection )+ smooth) / (p1.sum() + p2.sum() + smooth)
    #dice.requires_grad = True
    
    return dice

# %%
# calculate dice loss which will be later used in loss function calculation
def dice_loss(y_predict, y_train): ## to add in bce looss
  
  dice_loss = 1 -(dice_index(y_predict, y_train))
  
  return dice_loss

# %%
epochs = 150


train_running_loss_history = []
validation_running_loss_history =[]
start_time_training = time.time()
for e in range(epochs):
  start_time_epoch = time.time()
  train_running_loss = 0.0
  validation_running_loss = 0.0
  
  model.train()
  
  for ith_batch, sample_batched in enumerate(train_loader):
    if e % 5 == 0:
      plt.plot(train_running_loss_history, label = 'Train Loss')
      plt.plot(validation_running_loss_history, label = 'Validation Loss')
      plt.legend()
    X_train = sample_batched['image'].to('cuda')
    y_train = sample_batched['annotation'].to('cuda')
    
    #X_train.requires_grad = True
    #y_train.requires_grad = True

    #print(ith_batch) #, X_train.size(), y_train.size())

    optimizer.zero_grad()
    y_pred = model(X_train)
   # out = (y_pred + 0.5).int().float()
    
    loss = 0.30 * dice_loss(y_pred, y_train) +  0.70 * criterion(y_pred, y_train)
    #loss = criterion(y_pred, y_train)
    loss.backward()
    optimizer.step()
    
#     if ith_batch % 50 == 0:
#       print('Epoch: ', e + 1, 'Batch: ', ith_batch, 'Current Loss: ', loss.item())
      
    train_running_loss += loss.item()
    
    
    
    
  else:
    with torch.no_grad():
      
      model.eval()
      
      for ith_batch, sample_batched in enumerate(validation_loader):
          X_val = sample_batched['image'].to('cuda')
          y_val = sample_batched['annotation'].to('cuda')
          
          
          
          y_out = model(X_val)
          out_val = (y_out + 0.5).int().float()
          
          val_loss = 0.3 * dice_loss(out_val, y_val)  + 0.7 * criterion(y_out, y_val)
          
          #val_loss = criterion(y_out, y_val)
          
          validation_running_loss += val_loss.item()
      print("================================================================================")
      print("Epoch {} completed".format(e + 1))
      
      train_epoch_loss = train_running_loss / len(train_loader)
      validation_epoch_loss = validation_running_loss / len(validation_loader)
      
      print("Average train loss is {}: ".format(train_epoch_loss))
      print("Average validation loss is {}".format(validation_epoch_loss))

      train_running_loss_history.append(train_epoch_loss)
      validation_running_loss_history.append(validation_epoch_loss)
                                             
      # Timer and graph
#       print("this epoch ran %s seconds" % (time.time() - start_time_epoch))
      print("total running time is %s minutes" % ((time.time() - start_time_training)/60))                                       
      print("================================================================================")                                       
      #print(y_pred.shape)

    #y_pred = y_pred.to('cpu')
    #X_train = X_train.to('cpu')

    #del y_train
    #torch.cuda.empty_cache()
    #if ith_batch ==100:
    #break
  #for index in range(2):
  #         ax = gig.add_subplot(2, 2 , index + 1)  # subplot index starts from 1
   #         plt.imshow(im_converter(X_train[index]))
    #        ax = gig.add_subplot(2, 2, index + 3)
     #       plt.imshow(im_converter(y_pred[index]))
# Out:
# ================================================================================
# Epoch 1 completed
# Average train loss is 0.4863171070814133:
# Average validation loss is 0.47779187858104705
# total running time is 2.226652769247691 minutes
# ================================================================================
# ================================================================================
# Epoch 2 completed
# Average train loss is 0.413477337397635:
# Average validation loss is 1.090313345193863
# total running time is 4.935994676748911 minutes
# ================================================================================
# ================================================================================
# Epoch 3 completed
# Average train loss is 0.3839522726088762:
# Average validation loss is 0.4409219938516617
# total running time is 7.564541316032409 minutes
# ================================================================================
# ================================================================================
# Epoch 4 completed
# Average train loss is 0.36194650154560803:
# Average validation loss is 0.39696481853723525
# total running time is 9.519027491410574 minutes
# ================================================================================
# ================================================================================
# Epoch 5 completed
# Average train loss is 0.33438717018812897:
# Average validation loss is 0.37201553612947463
# total running time is 11.502933021386465 minutes
# ================================================================================
# ================================================================================
# Epoch 6 completed
# Average train loss is 0.31450345732271673:
# Average validation loss is 0.7462189395725727
# total running time is 16.544732491175335 minutes
# ================================================================================
# ================================================================================
# Epoch 7 completed
# Average train loss is 0.29606694757938384:
# Average validation loss is 0.30833651050925254
# total running time is 18.524800213178 minutes
# ================================================================================
# ================================================================================
# Epoch 8 completed
# Average train loss is 0.2725528283044696:
# Average validation loss is 0.5029538671672344
# total running time is 20.468180561065672 minutes
# ================================================================================
# ================================================================================
# Epoch 9 completed
# Average train loss is 0.24328952135518192:
# Average validation loss is 0.5404190734028816
# total running time is 22.43013166586558 minutes
# ================================================================================
# ================================================================================
# Epoch 10 completed
# Average train loss is 0.22188086152076722:
# Average validation loss is 0.2746783400326967
# total running time is 24.39263967672984 minutes
# ================================================================================
# ================================================================================
# Epoch 11 completed
# Average train loss is 0.20059356624260544:
# Average validation loss is 0.1841626314818859
# total running time is 31.585619874795277 minutes
# ================================================================================
# ================================================================================
# Epoch 12 completed
# Average train loss is 0.1939130106382072:
# Average validation loss is 0.1808103009313345
# total running time is 33.5688639720281 minutes
# ================================================================================
# ================================================================================
# Epoch 13 completed
# Average train loss is 0.1787678892351687:
# Average validation loss is 0.2176114721596241
# total running time is 35.52220693429311 minutes
# ================================================================================
# ================================================================================
# Epoch 14 completed
# Average train loss is 0.1781089997664094:
# Average validation loss is 0.18974569976329803
# total running time is 37.502691598733264 minutes
# ================================================================================
# ================================================================================
# Epoch 15 completed
# Average train loss is 0.1700684717297554:
# Average validation loss is 0.31108467996120454
# total running time is 39.45231105486552 minutes
# ================================================================================
# ================================================================================
# Epoch 16 completed
# Average train loss is 0.16592362171970307:
# Average validation loss is 0.2224169735610485
# total running time is 48.87489456335704 minutes
# ================================================================================
# ================================================================================
# Epoch 17 completed
# Average train loss is 0.16452986204996706:
# Average validation loss is 0.5007849335670471
# total running time is 50.85476463635762 minutes
# ================================================================================
# ================================================================================
# Epoch 18 completed
# Average train loss is 0.15683024109341204:
# Average validation loss is 0.16348264262080192
# total running time is 52.811150129636125 minutes
# ================================================================================
# ================================================================================
# Epoch 19 completed
# Average train loss is 0.1525699176080525:
# Average validation loss is 0.19135125748813153
# total running time is 54.793676575024925 minutes
# ================================================================================
# ================================================================================
# Epoch 20 completed
# Average train loss is 0.1503882083296776:
# Average validation loss is 0.17779278315603733
# total running time is 56.75145438909531 minutes
# ================================================================================
# ================================================================================
# Epoch 21 completed
# Average train loss is 0.14695463414303958:
# Average validation loss is 0.1393245544284582
# total running time is 68.34908854166666 minutes
# ================================================================================
# ================================================================================
# Epoch 22 completed
# Average train loss is 0.1462213693652302:
# Average validation loss is 0.13599142648279666
# total running time is 70.32614319324493 minutes
# ================================================================================
# ================================================================================
# Epoch 23 completed
# Average train loss is 0.14363088984042405:
# Average validation loss is 0.2235564921796322
# total running time is 72.30716593662898 minutes
# ================================================================================
# ================================================================================
# Epoch 24 completed
# Average train loss is 0.1414839499630034:
# Average validation loss is 0.17972088281065227
# total running time is 74.26203989187876 minutes
# ================================================================================
# ================================================================================
# Epoch 25 completed
# Average train loss is 0.13981334005482496:
# Average validation loss is 0.22034174248576163
# total running time is 76.2427653948466 minutes
# ================================================================================
# ================================================================================
# Epoch 26 completed
# Average train loss is 0.13817439923994243:
# Average validation loss is 0.2759696331620216
# total running time is 90.14499365488687 minutes
# ================================================================================
# ================================================================================
# Epoch 27 completed
# Average train loss is 0.13486291320063173:
# Average validation loss is 0.1505714360252023
# total running time is 92.10069094101588 minutes
# ================================================================================
# ================================================================================
# Epoch 28 completed
# Average train loss is 0.13643249832093715:
# Average validation loss is 0.1664504323154688
# total running time is 94.0786850253741 minutes
# ================================================================================
# ================================================================================
# Epoch 29 completed
# Average train loss is 0.13555224531330168:
# Average validation loss is 0.13606660667806864
# total running time is 96.0476971467336 minutes
# ================================================================================
# ================================================================================
# Epoch 30 completed
# Average train loss is 0.13385391503572464:
# Average validation loss is 0.151989925801754
# total running time is 98.01174383163452 minutes
# ================================================================================
# ================================================================================
# Epoch 31 completed
# Average train loss is 0.13009389964863657:
# Average validation loss is 0.16711513012647627
# total running time is 114.20232923030854 minutes
# ================================================================================
# ================================================================================
# Epoch 32 completed
# Average train loss is 0.1279361199401319:
# Average validation loss is 0.3418010999262333
# total running time is 116.17875894308091 minutes
# ================================================================================
# ================================================================================
# Epoch 33 completed
# Average train loss is 0.1319778700079769:
# Average validation loss is 0.14076884929090738
# total running time is 118.13790416320165 minutes
# ================================================================================
# ================================================================================
# Epoch 34 completed
# Average train loss is 0.12538517070002853:
# Average validation loss is 0.1430971772223711
# total running time is 120.11245269775391 minutes
# ================================================================================
# ================================================================================
# Epoch 35 completed
# Average train loss is 0.12656560686416923:
# Average validation loss is 0.2010124573856592
# total running time is 122.09395449956259 minutes
# ================================================================================
# ================================================================================
# Epoch 36 completed
# Average train loss is 0.1286003897897899:
# Average validation loss is 0.16439160842448472
# total running time is 140.4599238673846 minutes
# ================================================================================
# ================================================================================
# Epoch 37 completed
# Average train loss is 0.12471424316987395:
# Average validation loss is 0.18360960699617862
# total running time is 142.43834672371545 minutes
# ================================================================================
# ================================================================================
# Epoch 38 completed
# Average train loss is 0.12588925304822624:
# Average validation loss is 0.16812289379537104
# total running time is 144.39342357714972 minutes
# ================================================================================
# ================================================================================
# Epoch 39 completed
# Average train loss is 0.12100885820575058:
# Average validation loss is 0.2637966355681419
# total running time is 146.372203540802 minutes
# ================================================================================
# ================================================================================
# Epoch 40 completed
# Average train loss is 0.12437002656050027:
# Average validation loss is 0.14962062072008847
# total running time is 148.32319578727086 minutes
# ================================================================================
# ================================================================================
# Epoch 41 completed
# Average train loss is 0.1219660038035363:
# Average validation loss is 0.1697955547645688
# total running time is 169.00341215928395 minutes
# ================================================================================
# ================================================================================
# Epoch 42 completed
# Average train loss is 0.12167515200562776:
# Average validation loss is 0.12173999946564436
# total running time is 170.9568742275238 minutes
# ================================================================================
# ================================================================================
# Epoch 43 completed
# Average train loss is 0.11695346909575165:
# Average validation loss is 0.13442799404263497
# total running time is 172.93706715901692 minutes
# ================================================================================
# ================================================================================
# Epoch 44 completed
# Average train loss is 0.12075975551269949:
# Average validation loss is 0.116510090790689
# total running time is 174.91770706176757 minutes
# ================================================================================
# ================================================================================
# Epoch 45 completed
# Average train loss is 0.12050065813586115:
# Average validation loss is 0.23206415437161923
# total running time is 176.87132214307786 minutes
# ================================================================================
# ================================================================================
# Epoch 46 completed
# Average train loss is 0.11699912353418768:
# Average validation loss is 0.1123602695018053
# total running time is 199.85451238950094 minutes
# ================================================================================
# ================================================================================
# Epoch 47 completed
# Average train loss is 0.11869241225533188:
# Average validation loss is 0.12400308936834335
# total running time is 201.80436716477075 minutes
# ================================================================================
# ================================================================================
# Epoch 48 completed
# Average train loss is 0.11899086490273475:
# Average validation loss is 0.11960599347949027
# total running time is 203.77997796932857 minutes
# ================================================================================
# ================================================================================
# Epoch 49 completed
# Average train loss is 0.11765674884431064:
# Average validation loss is 0.14893309019505976
# total running time is 205.7463893810908 minutes
# ================================================================================
# ================================================================================
# Epoch 50 completed
# Average train loss is 0.11568369338288903:
# Average validation loss is 0.2158015377447009
# total running time is 207.71546239852904 minutes
# ================================================================================
# ================================================================================
# Epoch 51 completed
# Average train loss is 0.11616965122520924:
# Average validation loss is 0.11756265413016082
# total running time is 232.9486911614736 minutes
# ================================================================================
# ================================================================================
# Epoch 52 completed
# Average train loss is 0.1184638577234:
# Average validation loss is 0.1721669513732195
# total running time is 234.90753439267476 minutes
# ================================================================================
# ================================================================================
# Epoch 53 completed
# Average train loss is 0.1152476305142045:
# Average validation loss is 0.1879863976687193
# total running time is 236.8830774585406 minutes
# ================================================================================
# ================================================================================
# Epoch 54 completed
# Average train loss is 0.11111516793258489:
# Average validation loss is 0.1789453136175871
# total running time is 238.8673820813497 minutes
# ================================================================================
# ================================================================================
# Epoch 55 completed
# Average train loss is 0.1160252864100039:
# Average validation loss is 0.17087162416428328
# total running time is 240.8165658593178 minutes
# ================================================================================
# ================================================================================
# Epoch 56 completed
# Average train loss is 0.11226497038267552:
# Average validation loss is 0.12106197789311408
# total running time is 268.4029171347618 minutes
# ================================================================================
# ================================================================================
# Epoch 57 completed
# Average train loss is 0.10891602678224445:
# Average validation loss is 0.33137444756925105
# total running time is 270.3808041095734 minutes
# ================================================================================
# ================================================================================
# Epoch 58 completed
# Average train loss is 0.11424083332531154:
# Average validation loss is 0.12231387179344892
# total running time is 272.33459078470867 minutes
# ================================================================================
# ================================================================================
# Epoch 59 completed
# Average train loss is 0.11123870783485472:
# Average validation loss is 0.18817885965108871
# total running time is 274.3149666508039 minutes
# ================================================================================
# ================================================================================
# Epoch 60 completed
# Average train loss is 0.11104505605995656:
# Average validation loss is 0.1843671889230609
# total running time is 276.26414738496146 minutes
# ================================================================================
# ================================================================================
# Epoch 61 completed
# Average train loss is 0.11339479031041265:
# Average validation loss is 0.11871410053223372
# total running time is 306.11346993843716 minutes
# ================================================================================
# ================================================================================
# Epoch 62 completed
# Average train loss is 0.11296738062053918:
# Average validation loss is 0.16507387194782497
# total running time is 308.096301484108 minutes
# ================================================================================
# ================================================================================
# Epoch 63 completed
# Average train loss is 0.10939539887942373:
# Average validation loss is 0.1161032947152853
# total running time is 310.0728955626488 minutes
# ================================================================================
# ================================================================================
# Epoch 64 completed
# Average train loss is 0.1088855478540063:
# Average validation loss is 0.12328427854925395
# total running time is 312.0229023218155 minutes
# ================================================================================
# ================================================================================
# Epoch 65 completed
# Average train loss is 0.10794050866737961:
# Average validation loss is 0.1274196022748947
# total running time is 314.0005537231763 minutes
# ================================================================================
# ================================================================================
# Epoch 66 completed
# Average train loss is 0.11270601746626198:
# Average validation loss is 0.13593362838029863
# total running time is 346.0897557536761 minutes
# ================================================================================
# ================================================================================
# Epoch 67 completed
# Average train loss is 0.10765337280929088:
# Average validation loss is 0.12891309900209308
# total running time is 348.0618033091227 minutes
# ================================================================================
# ================================================================================
# Epoch 68 completed
# Average train loss is 0.10853882734663785:
# Average validation loss is 0.1160014970973134
# total running time is 350.02309567928313 minutes
# ================================================================================
# ================================================================================
# Epoch 69 completed
# Average train loss is 0.10520080603659153:
# Average validation loss is 0.10461445786058902
# total running time is 352.0010299841563 minutes
# ================================================================================
# ================================================================================
# Epoch 70 completed
# Average train loss is 0.10708988918922842:
# Average validation loss is 0.12436778653413057
# total running time is 353.9474317868551 minutes
# ================================================================================
# ================================================================================
# Epoch 71 completed
# Average train loss is 0.10635716315358877:
# Average validation loss is 0.11114005040377378
# total running time is 388.28180362383523 minutes
# ================================================================================
# ================================================================================
# Epoch 72 completed
# Average train loss is 0.1071870823763311:
# Average validation loss is 0.10348633658140897
# total running time is 390.23615926504135 minutes
# ================================================================================
# ================================================================================
# Epoch 73 completed
# Average train loss is 0.10537209574133158:
# Average validation loss is 0.16526045098900796
# total running time is 392.21893341143925 minutes
# ================================================================================
# ================================================================================
# Epoch 74 completed
# Average train loss is 0.10501922387629747:
# Average validation loss is 0.10431036204099656
# total running time is 394.17098005215325 minutes
# ================================================================================
# ================================================================================
# Epoch 75 completed
# Average train loss is 0.10519886411726474:
# Average validation loss is 0.12311111949384212
# total running time is 396.1484875122706 minutes
# ================================================================================
# ================================================================================
# Epoch 76 completed
# Average train loss is 0.10765792071819305:
# Average validation loss is 0.10722999118268489
# total running time is 432.89203979174295 minutes
# ================================================================================
# ================================================================================
# Epoch 77 completed
# Average train loss is 0.10440228288993239:
# Average validation loss is 0.1437520747259259
# total running time is 434.86927833557127 minutes
# ================================================================================
# ================================================================================
# Epoch 78 completed
# Average train loss is 0.10553996484726667:
# Average validation loss is 0.12086122686043382
# total running time is 436.84373924334847 minutes
# ================================================================================
# ================================================================================
# Epoch 79 completed
# Average train loss is 0.10500624494627118:
# Average validation loss is 0.2003407221287489
# total running time is 438.8113001704216 minutes
# ================================================================================
# ================================================================================
# Epoch 80 completed
# Average train loss is 0.10572016198188067:
# Average validation loss is 0.14224598821252585
# total running time is 440.79154535531995 minutes
# ================================================================================
# ================================================================================
# Epoch 81 completed
# Average train loss is 0.1021565702278167:
# Average validation loss is 0.14297559455037118
# total running time is 479.0319280862808 minutes
# ================================================================================
# ================================================================================
# Epoch 82 completed
# Average train loss is 0.10385677761398256:
# Average validation loss is 0.10814694356173277
# total running time is 479.86547009547553 minutes
# ================================================================================
# ================================================================================
# Epoch 83 completed
# Average train loss is 0.10328642589971423:
# Average validation loss is 0.1461543816700578
# total running time is 480.7002949118614 minutes
# ================================================================================
# ================================================================================
# Epoch 84 completed
# Average train loss is 0.10033357378095388:
# Average validation loss is 0.13018214583396912
# total running time is 481.53564252058663 minutes
# ================================================================================
# ================================================================================
# Epoch 85 completed
# Average train loss is 0.09961679841391742:
# Average validation loss is 0.1035216605849564
# total running time is 482.37041438420613 minutes
# ================================================================================
# ================================================================================
# Epoch 86 completed
# Average train loss is 0.10387041813693941:
# Average validation loss is 0.13521218974143268
# total running time is 521.416992910703 minutes
# ================================================================================
# ================================================================================
# Epoch 87 completed
# Average train loss is 0.10156686836853623:
# Average validation loss is 0.14032689390704037
# total running time is 522.2513488252957 minutes
# ================================================================================
# ================================================================================
# Epoch 88 completed
# Average train loss is 0.10331054033711552:
# Average validation loss is 0.11837179232388735
# total running time is 523.085956756274 minutes
# ================================================================================
# ================================================================================
# Epoch 89 completed
# Average train loss is 0.10479340584017337:
# Average validation loss is 0.18264262281358243
# total running time is 523.9204821030299 minutes
# ================================================================================
# ================================================================================
# Epoch 90 completed
# Average train loss is 0.09794002195820212:
# Average validation loss is 0.10874821092933416
# total running time is 524.7553851604462 minutes
# ================================================================================
# ================================================================================
# Epoch 91 completed
# Average train loss is 0.09959788681007922:
# Average validation loss is 0.11644071247428656
# total running time is 565.9682693521182 minutes
# ================================================================================
# ================================================================================
# Epoch 92 completed
# Average train loss is 0.10235289698000997:
# Average validation loss is 0.1567883451655507
# total running time is 566.8026661674181 minutes
# ================================================================================
# ================================================================================
# Epoch 93 completed
# Average train loss is 0.10338037081994117:
# Average validation loss is 0.1226540870591998
# total running time is 567.6373926679294 minutes
# ================================================================================
# ================================================================================
# Epoch 94 completed
# Average train loss is 0.10285192885436117:
# Average validation loss is 0.12148490391671657
# total running time is 568.472393087546 minutes
# ================================================================================
# ================================================================================
# Epoch 95 completed
# Average train loss is 0.09835752811748534:
# Average validation loss is 0.11611219832673669
# total running time is 569.3066282947858 minutes
# ================================================================================
# ================================================================================
# Epoch 96 completed
# Average train loss is 0.1019587836228311:
# Average validation loss is 0.11302129585295916
# total running time is 612.6888640801112 minutes
# ================================================================================
# ================================================================================
# Epoch 97 completed
# Average train loss is 0.09978234187699854:
# Average validation loss is 0.1210308394767344
# total running time is 613.5232020616531 minutes
# ================================================================================
# ================================================================================
# Epoch 98 completed
# Average train loss is 0.09582445316947996:
# Average validation loss is 0.12022964131087065
# total running time is 614.3573991219203 minutes
# ================================================================================
# ================================================================================
# Epoch 99 completed
# Average train loss is 0.1007136082695797:
# Average validation loss is 0.10446810873225332
# total running time is 615.1921161929766 minutes
# ================================================================================
# ================================================================================
# Epoch 100 completed
# Average train loss is 0.10168396005406975:
# Average validation loss is 0.10140493247658014
# total running time is 616.0266307989756 minutes
# ================================================================================
# ================================================================================
# Epoch 101 completed
# Average train loss is 0.09844470775686204:
# Average validation loss is 0.11882152497768401
# total running time is 661.7526414076488 minutes
# ================================================================================
# ================================================================================
# Epoch 102 completed
# Average train loss is 0.0995231535891071:
# Average validation loss is 0.11308435305953025
# total running time is 662.5872074564298 minutes
# ================================================================================
# ================================================================================
# Epoch 103 completed
# Average train loss is 0.09733796812593937:
# Average validation loss is 0.14175436597317456
# total running time is 663.4216149687767 minutes
# ================================================================================
# ================================================================================
# Epoch 104 completed
# Average train loss is 0.09546221467666328:
# Average validation loss is 0.12626660402864218
# total running time is 664.2554309725762 minutes
# ================================================================================
# ================================================================================
# Epoch 105 completed
# Average train loss is 0.09807824703864754:
# Average validation loss is 0.1060516956821084
# total running time is 665.0903812766076 minutes
# ================================================================================
# ================================================================================
# Epoch 106 completed
# Average train loss is 0.09919384090229869:
# Average validation loss is 0.10828486116603017
# total running time is 713.1657153089841 minutes
# ================================================================================
# ================================================================================
# Epoch 107 completed
# Average train loss is 0.09511503339745105:
# Average validation loss is 0.11176647592335939
# total running time is 713.999956035614 minutes
# ================================================================================
# ================================================================================
# Epoch 108 completed
# Average train loss is 0.10008508496917784:
# Average validation loss is 0.09678708039224147
# total running time is 714.8331384062767 minutes
# ================================================================================
# ================================================================================
# Epoch 109 completed
# Average train loss is 0.0945039806328714:
# Average validation loss is 0.13131056010723113
# total running time is 715.6676429748535 minutes
# ================================================================================
# ================================================================================
# Epoch 110 completed
# Average train loss is 0.09488717234693468:
# Average validation loss is 0.10628570633009077
# total running time is 716.5019607742628 minutes
# ================================================================================
# ================================================================================
# Epoch 111 completed
# Average train loss is 0.09952657995279879:
# Average validation loss is 0.1145611946284771
# total running time is 767.836754433314 minutes
# ================================================================================
# ================================================================================
# Epoch 112 completed
# Average train loss is 0.09544200765900314:
# Average validation loss is 0.1016580718383193
# total running time is 768.6712736447652 minutes
# ================================================================================
# ================================================================================
# Epoch 113 completed
# Average train loss is 0.09482431445270777:
# Average validation loss is 0.1378123664110899
# total running time is 769.5061122020086 minutes
# ================================================================================
# ================================================================================
# Epoch 114 completed
# Average train loss is 0.0986225312948227:
# Average validation loss is 0.11322612319141627
# total running time is 770.3405213634173 minutes
# ================================================================================
# ================================================================================
# Epoch 115 completed
# Average train loss is 0.09606089593842626:
# Average validation loss is 0.10260771991685033
# total running time is 771.1742631276448 minutes
# ================================================================================
# ================================================================================
# Epoch 116 completed
# Average train loss is 0.0976776059344411:
# Average validation loss is 0.10704795580357312
# total running time is 824.718171453476 minutes
# ================================================================================
# ================================================================================
# Epoch 117 completed
# Average train loss is 0.09427785001695156:
# Average validation loss is 0.14865593336522578
# total running time is 825.5524215459824 minutes
# ================================================================================
# ================================================================================
# Epoch 118 completed
# Average train loss is 0.09335601896047592:
# Average validation loss is 0.12289159787818789
# total running time is 826.3871936400732 minutes
# ================================================================================
# ================================================================================
# Epoch 119 completed
# Average train loss is 0.09544431109912693:
# Average validation loss is 0.12423430155962706
# total running time is 827.2219358166059 minutes
# ================================================================================
# ================================================================================
# Epoch 120 completed
# Average train loss is 0.09556523553561419:
# Average validation loss is 0.11165960725396872
# total running time is 828.0563163042068 minutes
# ================================================================================
# ================================================================================
# Epoch 121 completed
# Average train loss is 0.09257298990618437:
# Average validation loss is 0.18069156851619483
# total running time is 883.7255957841874 minutes
# ================================================================================
# ================================================================================
# Epoch 122 completed
# Average train loss is 0.09353931440971791:
# Average validation loss is 0.100771390106529
# total running time is 884.5606545686721 minutes
# ================================================================================
# ================================================================================
# Epoch 123 completed
# Average train loss is 0.0940666589513421:
# Average validation loss is 0.10105099715292454
# total running time is 885.3956015904745 minutes
# ================================================================================
# ================================================================================
# Epoch 124 completed
# Average train loss is 0.09790585183072835:
# Average validation loss is 0.10236870974302292
# total running time is 886.2315396030743 minutes
# ================================================================================
# ================================================================================
# Epoch 125 completed
# Average train loss is 0.09260223329998553:
# Average validation loss is 0.13904082100838422
# total running time is 887.0663531462352 minutes
# ================================================================================
# ================================================================================
# Epoch 126 completed
# Average train loss is 0.0933455912489444:
# Average validation loss is 0.10495863117277622
# total running time is 945.0666683793067 minutes
# ================================================================================
# ================================================================================
# Epoch 127 completed
# Average train loss is 0.09376369844190777:
# Average validation loss is 0.126417021099478
# total running time is 945.9012905478478 minutes
# ================================================================================
# ================================================================================
# Epoch 128 completed
# Average train loss is 0.09356737909838557:
# Average validation loss is 0.10535952581092715
# total running time is 946.7360932191212 minutes
# ================================================================================
# ================================================================================
# Epoch 129 completed
# Average train loss is 0.09138006820809096:
# Average validation loss is 0.11286386057734489
# total running time is 947.5700921575228 minutes
# ================================================================================
# ================================================================================
# Epoch 130 completed
# Average train loss is 0.09244564706925303:
# Average validation loss is 0.18967365205287934
# total running time is 948.4045193274816 minutes
# ================================================================================
# ================================================================================
# Epoch 131 completed
# Average train loss is 0.09524167571216821:
# Average validation loss is 0.10333038225769997
# total running time is 1008.9277955810229 minutes
# ================================================================================
# ================================================================================
# Epoch 132 completed
# Average train loss is 0.09376056247390807:
# Average validation loss is 0.14215583130717277
# total running time is 1009.7621048927307 minutes
# ================================================================================
# ================================================================================
# Epoch 133 completed
# Average train loss is 0.09454406929202377:
# Average validation loss is 0.09730835925787687
# total running time is 1010.5968841950099 minutes
# ================================================================================
# ================================================================================
# Epoch 134 completed
# Average train loss is 0.09159418137744069:
# Average validation loss is 0.1400636041164398
# total running time is 1011.4313132842382 minutes
# ================================================================================
# ================================================================================
# Epoch 135 completed
# Average train loss is 0.09297365518752486:
# Average validation loss is 0.10487773433327675
# total running time is 1012.2664076050122 minutes
# ================================================================================
# ================================================================================
# Epoch 136 completed
# Average train loss is 0.09201955198310316:
# Average validation loss is 0.11856832902878522
# total running time is 1074.878074491024 minutes
# ================================================================================
# ================================================================================
# Epoch 137 completed
# Average train loss is 0.09304604064673186:
# Average validation loss is 0.10225328139960765
# total running time is 1075.7134747902553 minutes
# ================================================================================
# ================================================================================
# Epoch 138 completed
# Average train loss is 0.09348640330135823:
# Average validation loss is 0.1227194132655859
# total running time is 1076.5485905687015 minutes
# ================================================================================
# ================================================================================
# Epoch 139 completed
# Average train loss is 0.09441082908306271:
# Average validation loss is 0.1076541488058865
# total running time is 1077.3830542206765 minutes
# ================================================================================
# ================================================================================
# Epoch 140 completed
# Average train loss is 0.09454473849385976:
# Average validation loss is 0.11190595228224992
# total running time is 1078.2185243844986 minutes
# ================================================================================
# ================================================================================
# Epoch 141 completed
# Average train loss is 0.0926171356625855:
# Average validation loss is 0.10149980988353491
# total running time is 1143.2307467540106 minutes
# ================================================================================
# ================================================================================
# Epoch 142 completed
# Average train loss is 0.09159874519333243:
# Average validation loss is 0.09211935034021736
# total running time is 1144.0687714099884 minutes
# ================================================================================
# ================================================================================
# Epoch 143 completed
# Average train loss is 0.09254438196774573:
# Average validation loss is 0.10728526454418898
# total running time is 1144.907072309653 minutes
# ================================================================================
# ================================================================================
# Epoch 144 completed
# Average train loss is 0.09040795778855681:
# Average validation loss is 0.13998431272804737
# total running time is 1145.74541066885 minutes
# ================================================================================
# ================================================================================
# Epoch 145 completed
# Average train loss is 0.09073063136544078:
# Average validation loss is 0.09513251677155495
# total running time is 1146.5821220358214 minutes
# ================================================================================
# ================================================================================
# Epoch 146 completed
# Average train loss is 0.08912026819773018:
# Average validation loss is 0.09399565137922763
# total running time is 1213.9735378146172 minutes
# ================================================================================
# ================================================================================
# Epoch 147 completed
# Average train loss is 0.08902572974562645:
# Average validation loss is 0.10495318505913019
# total running time is 1214.8087760766348 minutes
# ================================================================================
# ================================================================================
# Epoch 148 completed
# Average train loss is 0.09138089953921735:
# Average validation loss is 0.0975070733577013
# total running time is 1215.6439881205558 minutes
# ================================================================================
# ================================================================================
# Epoch 149 completed
# Average train loss is 0.08814357365947217:
# Average validation loss is 0.10353999216109515
# total running time is 1216.4788212060928 minutes
# ================================================================================
# ================================================================================
# Epoch 150 completed
# Average train loss is 0.090951441898942:
# Average validation loss is 0.10887981042265892
# total running time is 1217.3118063529332 minutes
# ================================================================================
# /opt/tljh/user/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/tljh/user/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /opt/tljh/user/lib/python3.9/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~/.local/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2312                 # force the figure dpi to 72), so we need to set it again here.
#    2313                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2314                     result = print_method(
#    2315                         filename,
#    2316                         facecolor=facecolor,
#
# ~/.local/lib/python3.9/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1641             kwargs.pop(arg)
#    1642
# -> 1643         return func(*args, **kwargs)
#    1644
#    1645     return wrapper
#
# ~/.local/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                          else deprecation_addendum,
#     411                 **kwargs)
# --> 412         return func(*inner_args, **inner_kwargs)
#     413
#     414     DECORATORS[wrapper] = decorator
#
# ~/.local/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     538             *metadata*, including the default 'Software' key.
#     539         """
# --> 540         FigureCanvasAgg.draw(self)
#     541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# ~/.local/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     429     def draw(self):
#     430         # docstring inherited
# --> 431         self.renderer = self.get_renderer(cleared=True)
#     432         # Acquire a lock on the shared font cache.
#     433         with RendererAgg.lock, \
#
# ~/.local/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     445                           and getattr(self, "_lastKey", None) == key)
#     446         if not reuse_renderer:
# --> 447             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     448             self._lastKey = key
#     449         elif cleared:
#
# ~/.local/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      91         self.width = width
#      92         self.height = height
# ---> 93         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      94         self._filter_renderers = []
#      95
#
# ValueError: Image size of 372x360022 pixels is too large. It must be less than 2^16 in each direction.

# %%
torch.save(model,"Models/MFP_Cos_Schedular_150_epoches.pt")

# %%
plt.plot(train_running_loss_history, label = 'Train Loss')
plt.plot(validation_running_loss_history, label = 'Validation Loss')
plt.legend()

# %%
model.eval()
X_train.size()

# %%
out = (y_pred + 0.5).int().float()

# %%
print(dice_index(y_train, out))
print(dice_loss(y_train, out))

# %%
# pig = plt.figure(figsize = (15, 6))

# a = pig.add_subplot(2, 3, 1)
# plt.imshow(im_converterX(X_train[0]))

# a = pig.add_subplot(2, 3, 2)
# plt.imshow(im_converterY(y_train[0]))

# a = pig.add_subplot(2, 3, 3)
# plt.imshow(im_converterY(out[0]))


# a = pig.add_subplot(2, 3, 4)
# plt.imshow(im_converterX(X_train[1]))

# a = pig.add_subplot(2, 3, 5)
# plt.imshow(im_converterY(y_train[1]))

# a = pig.add_subplot(2, 3, 6)
# plt.imshow(im_converterY(out[1]))

# %%
gg = dice_index(out, y_train)
print(gg)
print(dice_loss(out, y_train))

# %%
class HC18_test(Dataset):
    def __init__(self, root_dir, transformX = None):
        self.pixel_file = pd.read_csv(os.path.join(root_dir, 'test_set_pixel_size.csv'))
        self.root_dir = root_dir
        self.transformX = transformX
        
    def __len__(self):
        return len(self.pixel_file)
    
    def __getitem__(self, index):
        imx_name = os.path.join(self.root_dir, 'test_set', self.pixel_file.iloc[index, 0])
        
        imx = Image.open(imx_name)
        
        f_name = self.pixel_file.iloc[index, 0]
        
        if self.transformX :
            imx = self.transformX(imx)
        
        sample = {'image': imx, 'f_name': f_name}
        return sample

# %%
test_data = HC18_test('', transformX = tx_X)

# %%
test_data

# %%
test_loader = DataLoader(dataset = test_data, batch_size = 2, shuffle = True)

# %%
test_loader

# %%
## Here we loop through our train_loader and see the images
## Looks good
fig = plt.figure(figsize = (15,6))
#model.to('cpu')
for ith_batch, sample_batched in enumerate(test_loader):
  
    X_test = sample_batched['image'].to('cuda')
    print(ith_batch, X_test.size())
    
    y_test = (model(X_test) + 0.5).int().float()
    
    
    
    for index in range(2):
        ax = fig.add_subplot(2, 2 , index + 1)  # subplot index starts from 1
        plt.imshow(im_converterX(X_test[index]))
        
        ax  = fig.add_subplot(2, 2, index + 3)
        plt.imshow(im_converterY(y_test[index]))
    break

# %%
def avg_dice_index(dataloader):
  
    dice = 0.0
    model.eval()
    with torch.no_grad():
    
        for ith_batch, sample_batched in enumerate(dataloader):
  
            X_train = sample_batched['image'].to('cuda')
            y_train = sample_batched['annotation'].to('cuda')
            
            y_predict = (model(X_train) + 0.5).int().float()
            
            dice += dice_index(y_predict, y_train)
            
            
            
    avg_dice = dice / len(dataloader)
    return avg_dice.item()

# %%
avg_dice_index(validation_loader)    #### Dice index of validation data

# %%
avg_dice_index(train_loader)        ### Dice index of training data

# %%
test_loader = DataLoader(dataset = test_data, batch_size = 1, shuffle = True) # to write image files

# %% [markdown]
# ## **Warning!!!**
# ### Your are about to write on drive

# %%
transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((540, 800)),
        transforms.ToTensor()
        ])
    
with torch.no_grad():
      #model.eval()
      for ith_batch , sample in enumerate(test_loader):
        X_test = sample['image'].to('cuda')
        y_pred = (model(X_test) + 0.5).int().float().cpu()
#         print(335-ith_batch)
        
        file_names = sample['f_name']
        pankaj = transform(y_pred[0])
        #singh = transform(y_pred[1])
        torchvision.utils.save_image(pankaj , os.path.join('segmented', file_names[0]))
        #torchvision.utils.save_image(singh, os.path.join('/content/drive/My Drive/HC18/test_set', file_names[1].replace('.png','_Annotation.png')))
      print("Segmentation files written")

# %%
def fit_ellipse(im):    
    imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
    ret,thresh = cv2.threshold(imgray,127,255,0)
    contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    contour_sizes = [len(contour) for contour in contours]
    ellipse = cv2.fitEllipse(contours[np.argmax(contour_sizes)])
    return ellipse

# %%
file_names = sorted([file for _,_,files in os.walk('segmented/') for file in files])

# %%
df_pixel_size = pd.read_csv('test_set_pixel_size.csv')
submission = {'filename': [], 'center_x_mm': [], 'center_y_mm': [], 'semi_axes_a_mm': [],
             'semi_axes_b_mm': [], 'angle_rad': [], 'Index': []}

file_names = sorted([file for _,_,files in os.walk('segmented/') for file in files])

for i, file_name in enumerate(file_names):
    im = cv2.imread('segmented/'+file_name)
   # file_name = file_name.replace('_Segmented', '')
    ellipse = fit_ellipse(im)
    im_mask = cv2.ellipse(np.zeros_like(im),ellipse,(255,255,255),-1)
    image_name = file_name.split('.')[0] + '_Annotation_fit.png'
    #cv2.imwrite('/content/drive/My Drive/HC18/test_set/'+image_name, im_mask)
    
    pixel_size = df_pixel_size.loc[df_pixel_size['filename'] == file_name, 'pixel size(mm)'].iloc[0]
    submission['filename'].extend([file_name])
    submission['Index'].extend([int(file_name.split('_')[0])])
    center_x,  center_y = ellipse[0]
    submission['center_x_mm'].extend([pixel_size*center_x])
    submission['center_y_mm'].extend([pixel_size*center_y])
    semi_axes_b, semi_axes_a = ellipse[1]
    if semi_axes_b > semi_axes_a:
        semi_axes_b = semi_axes_b + semi_axes_a
        semi_axes_a = semi_axes_b - semi_axes_a
        semi_axes_b -= semi_axes_a
    submission['semi_axes_a_mm'].extend([semi_axes_a*pixel_size/2])
    submission['semi_axes_b_mm'].extend([semi_axes_b*pixel_size/2])
    angle = ellipse[2]
    if angle < 90:
        angle += 90
    else:
        angle -= 90
    submission['angle_rad'].extend([np.deg2rad(angle)])
    
submission = pd.DataFrame(submission)
submission = submission[['filename', 'center_x_mm', 'center_y_mm', 
                         'semi_axes_a_mm', 'semi_axes_b_mm', 'angle_rad', 'Index']]    
submission = submission.sort_values(['Index'])
submission = submission.drop('Index', axis=1)
submission.to_csv("MFP_Cos_150.csv", index=False)
print('Required .csv file generated')

# %%
q = pd.read_csv('MFP_Cos_150.csv')  ## to check theck the generated csv

# %%
print('Length of csv file: ',len(q))

# %%
submission.head()
