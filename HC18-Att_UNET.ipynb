# %% [markdown]
# <a href="https://colab.research.google.com/github/Pankaj1357/HC18-Grand-Challenge/blob/master/HC18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import os
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # **Mask Generation**
# Done only once and replaced that  annotation with masks permanently
# Did not changed the annotation file name though

# %% [markdown]
# ## **Warning!!!**
# Do not run below cells as task is already completed

# %%
train_pixel_file = pd.read_csv('training_set_pixel_size_and_HC.csv')
train_pixel_file.head()
# This Dataframe will be used to extract image names hence by doing image_name + '_Annotation' we will get annotation names
# Out:
#      filename  pixel size(mm)  head circumference (mm)
# 0  000_HC.png        0.069136                    44.30
# 1  001_HC.png        0.089659                    56.81
# 2  002_HC.png        0.062033                    68.75
# 3  003_HC.png        0.091291                    69.00
# 4  004_HC.png        0.061240                    59.81

# %%
# This function takes annotation and spits out corresponding mask
def masking(image):
    imgray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(imgray, 127, 255, 0)
    contours,useless = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    ellipse = cv2.fitEllipse(contours[0])
    return cv2.ellipse(image, ellipse, (255,255,255), -1)

# %%
# to check if our masking function is working correctly
fig = plt.figure(figsize = (30,7))
for index in range(7):
  file_path = os.path.join('training_set', train_pixel_file.iloc[index, 0].replace('.png','_Annotation.png'))
  print(file_path)
  ax = fig.add_subplot(2, 7, index+1)             ## annoted plot
  plt.imshow(cv2.imread(file_path))
    
  ax = fig.add_subplot(2, 7, index+8)
  plt.imshow(masking(cv2.imread(file_path)))        ## mask plot
# Out:
# training_set/000_HC_Annotation.png
# training_set/001_HC_Annotation.png
# training_set/002_HC_Annotation.png
# training_set/003_HC_Annotation.png
# training_set/004_HC_Annotation.png
# training_set/005_HC_Annotation.png
# training_set/006_HC_Annotation.png

# %%
# Here we loop through training set and  take annotations one by one and replace them with corresponding masks
fig = plt.figure(figsize = (30,7))
for index in range(len(train_pixel_file)):
    file_path = os.path.join('training_set', train_pixel_file.iloc[index, 0].replace('.png','_Annotation.png'))
    image = cv2.imread(file_path)
    mask = masking(image)
    cv2.imwrite(file_path, mask)

# %% [markdown]
# ## **Warning!!!**
# **Done with mask generation. Don't run above cells ever again**

# %% [markdown]
# ### **Do all the imports in below cell**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from skimage import io, color
from PIL import Image
import cv2

import os
import random

import torch
from torch.utils.data  import Dataset, DataLoader
from torchvision import transforms
import torchvision.transforms.functional as TF
import torch.nn as nn
import torch.nn.functional as F
import torchvision

# %%
validation_set_size = 0.20            # fraction of dataset used for validation which will be splited randomly

# %%
# our dataset class
class HC18(Dataset):
  #""" train and validation dataset class"""
    def __init__(self, root_dir, train = True, transformX = None, transformY = None):
        self.pixel_file = pd.read_csv(os.path.join(root_dir, 'training_set_pixel_size_and_HC.csv'))
        self.root_dir = root_dir
        self.transformX = transformX
        self.transformY = transformY
        self.train = train
        
        # lets split the dataset in train and validation
        self.train_data, self.validation_data = train_test_split(self.pixel_file, test_size = validation_set_size, random_state = 5)
        
    def __len__(self):
        
        if self.train:
          length = len(self.train_data)
        else:
          length = len(self.validation_data)
        return length
    
    def __getitem__(self, index):
      
        if self.train:
          imx_name = os.path.join(self.root_dir, 'training_set', self.train_data.iloc[index, 0])
          imy_name = os.path.join(self.root_dir, 'training_set',self.train_data.iloc[index, 0].replace('.png','_Annotation.png'))

        else:
          imx_name = os.path.join(self.root_dir, 'training_set', self.validation_data.iloc[index, 0])
          imy_name = os.path.join(self.root_dir, 'training_set',self.validation_data.iloc[index, 0].replace('.png','_Annotation.png'))
        
        
        imx = Image.open(imx_name)
        imy = Image.open(imy_name).convert('L')
        
        ## tried some data augmentation techniques
        if self.train:
          # Random horizontal flipping
          if random.random() > 0.5:
              imx = TF.hflip(imx)
              imy = TF.hflip(imy)

          # Random vertical flipping
          if random.random() > 0.5:
              imx = TF.vflip(imx)
              imy = TF.vflip(imy)


          # Random rotation
          if random.random() > 0.8:
            angle = random.choice([-30, -90, -60, -45 -15, 0, 15, 30, 45, 60, 90])
            imx = TF.rotate(imx, angle)
            imy = TF.rotate(imy, angle)
        
        
        
        
        
        
        if self.transformX :
            imx = self.transformX(imx)
            imy = self.transformY(imy)
        
        sample = {'image': imx, 'annotation': imy}
        return sample

# %%
# our datasets
tx_X = transforms.Compose([ transforms.Resize((572, 572)),
                              transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,))
                              ])
tx_Y = transforms.Compose([ transforms.Resize((572, 572)),
                              transforms.ToTensor(),  ################ no need to normalize the maskk
                             # transforms.Normalize((0.5,), (0.5,))
                              ])
train_data = HC18('', train = True, transformX = tx_X, transformY = tx_Y)
validation_data = HC18('', train = False, transformX = tx_X, transformY = tx_Y )

# %%
# our dataloaders
train_loader = DataLoader(dataset = train_data, batch_size = 2, shuffle = True, num_workers = 2 )
validation_loader = DataLoader(dataset = validation_data, batch_size = 2, shuffle = True, num_workers = 2)

# %%
# this function will return numpy array from the transformed tensors which were
# obtained from our train_loader. Just to plot them and see if they are intact :) ha ha
def im_converterX(tensor):
    image = tensor.cpu().clone().detach().numpy() # make copy of tensor and converting it to numpy as we will need original later
    image = image.transpose(1,2,0) # swapping axes making (1, 28, 28) image to a (28, 28, 1)
 # print(image.shape)
    image = image * np.array((0.5, 0.5, 0.5)) + np.array((0.5, 0.5, 0.5)) # unnormalizing the image # this also outputs (28, 28, 3) which seems important for plt.imshow
    image = image.clip(0, 1) # to make sure final values are in range 0 to 1 as .ToTensor outputed
    return image

# %%
# this function will return numpy array from the transformed tensors which were
# obtained from our train_loader. Just to plot them and see if they are intact :) ha ha
def im_converterY(tensor):
    image = tensor.cpu().clone().detach().numpy() # make copy of tensor and converting it to numpy as we will need original later
    image = image.transpose(1,2,0) # swapping axes making (1, 28, 28) image to a (28, 28, 1)
 # print(image.shape)
    image = image * np.array((1, 1, 1)) # unnormalizing the image  not needed# this also outputs (28, 28, 3) which seems important for plt.imshow
    image = image.clip(0, 1) # to make sure final values are in range 0 to 1 as .ToTensor outputed
    return image

# %%
## Here we loop through our train_loader and see the images
## Looks good
fig = plt.figure(figsize = (15,6))
for ith_batch, sample_batched in enumerate(train_loader):
    print(ith_batch, sample_batched['image'].size(), sample_batched['annotation'].size())
    
    for index in range(2):
        ax = fig.add_subplot(2, 2 , index + 1)  # subplot index starts from 1
        plt.imshow(im_converterX(sample_batched['image'][index]))
        ax = fig.add_subplot(2, 2, index + 3)
        plt.imshow(im_converterY(sample_batched['annotation'][index]))
    break
# Out:
# 0 torch.Size([2, 1, 572, 572]) torch.Size([2, 1, 572, 572])

# %%
from __future__ import print_function, division
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data
import torch
import torchvision.transforms.functional as TF


class conv_block(nn.Module):
    """
    Convolution Block 
    """
    def __init__(self, in_ch, out_ch):
        super(conv_block, self).__init__()
        
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size=3, stride=1, padding=1, bias=True),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, kernel_size=3, stride=1, padding=1, bias=True),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True))

    def forward(self, x):

        x = self.conv(x)
        return x


class up_conv(nn.Module):
    """
    Up Convolution Block
    """
    def __init__(self, in_ch, out_ch):
        super(up_conv, self).__init__()
        self.up = nn.Sequential(
            nn.Upsample(scale_factor=2),
            nn.Conv2d(in_ch, out_ch, kernel_size=3, stride=1, padding=1, bias=True),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x = self.up(x)
        return x


class Attention_block(nn.Module):
    """
    Attention Block
    """

    def __init__(self, F_g, F_l, F_int):
        super(Attention_block, self).__init__()

        self.W_g = nn.Sequential(
            nn.Conv2d(F_l, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )

        self.W_x = nn.Sequential(
            nn.Conv2d(F_g, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )

        self.psi = nn.Sequential(
            nn.Conv2d(F_int, 1, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )

        self.relu = nn.ReLU(inplace=True)

    def forward(self, g, x):
        g1 = self.W_g(g)
        x1 = self.W_x(x)
        if(g1.shape != x1.shape):
            g1 = TF.resize(g1,size = x1.shape[2])
#         print(g1.shape)
#         print(x1.shape)
        psi = self.relu(g1 + x1)
        psi = self.psi(psi)
        out = x * psi
        return out


class AttU_Net(nn.Module):
    """
    Attention Unet implementation
    Paper: https://arxiv.org/abs/1804.03999
    """
    def __init__(self, img_ch=3, output_ch=1):
        super(AttU_Net, self).__init__()

        n1 = 64
        filters = [n1, n1 * 2, n1 * 4, n1 * 8, n1 * 16]

        self.Maxpool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.Maxpool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.Maxpool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.Maxpool4 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.Conv1 = conv_block(img_ch, filters[0])
        self.Conv2 = conv_block(filters[0], filters[1])
        self.Conv3 = conv_block(filters[1], filters[2])
        self.Conv4 = conv_block(filters[2], filters[3])
        self.Conv5 = conv_block(filters[3], filters[4])

        self.dropout = torch.nn.Dropout2d(0.1)
        self.Up5 = up_conv(filters[4], filters[3])
        self.Att5 = Attention_block(F_g=filters[3], F_l=filters[3], F_int=filters[2])
        self.Up_conv5 = conv_block(filters[4], filters[3])

        self.Up4 = up_conv(filters[3], filters[2])
        self.Att4 = Attention_block(F_g=filters[2], F_l=filters[2], F_int=filters[1])
        self.Up_conv4 = conv_block(filters[3], filters[2])

        self.Up3 = up_conv(filters[2], filters[1])
        self.Att3 = Attention_block(F_g=filters[1], F_l=filters[1], F_int=filters[0])
        self.Up_conv3 = conv_block(filters[2], filters[1])

        self.Up2 = up_conv(filters[1], filters[0])
        self.Att2 = Attention_block(F_g=filters[0], F_l=filters[0], F_int=32)
        self.Up_conv2 = conv_block(filters[1], filters[0])

        self.Conv = nn.Sequential(
        nn.Conv2d(filters[0], output_ch, kernel_size=1, stride=1, padding=0),
        nn.BatchNorm2d(output_ch),
        nn.Sigmoid()
        )
        #self.active = torch.nn.Sigmoid()


    def forward(self, x):

        e1 = self.Conv1(x)
        e1 = self.dropout(e1)
        e2 = self.Maxpool1(e1)
        e2 = self.Conv2(e2)
        e2 = self.dropout(e2)

        e3 = self.Maxpool2(e2)
        e3 = self.Conv3(e3)
        e3 = self.dropout(e3)

        e4 = self.Maxpool3(e3)
        e4 = self.Conv4(e4)
        e4 = self.dropout(e4)
        e5 = self.Maxpool4(e4)
        e5 = self.Conv5(e5)
        e5 = self.dropout(e5)
        d5 = self.Up5(e5)
        x4 = self.Att5(g=d5, x=e4)

        if d5.shape != x4.shape:
            d5 = TF.resize(x4,x4.shape[2])
            
        d5 = torch.cat((x4, d5), dim=1)
        d5 = self.Up_conv5(d5)

        d4 = self.Up4(d5)
        x3 = self.Att4(g=d4, x=e3)
        
        if d4.shape != x3.shape:
            d4 = TF.resize(x3,x3.shape[2])
            
        d4 = torch.cat((x3, d4), dim=1)
        d4 = self.Up_conv4(d4)

        d3 = self.Up3(d4)
        x2 = self.Att3(g=d3, x=e2)
        
        if d3.shape != x2.shape:
            d3 = TF.resize(x2,x2.shape[2])
        
        d3 = torch.cat((x2, d3), dim=1)
        d3 = self.Up_conv3(d3)

        d2 = self.Up2(d3)
        x1 = self.Att2(g=d2, x=e1)
        if d2.shape != x1.shape:
            d2 = TF.resize(x1,x1.shape[2])
        d2 = torch.cat((x1, d2), dim=1)
        d2 = self.Up_conv2(d2)

        out = self.Conv(d2)


      #  out = self.active(out)

        return out


model = AttU_Net(1,1)
model.to('cuda')
print("Model Loaded to GPU")
# Out:
# Model Loaded to GPU

# %%
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0077)

# %%
# calculates similarity index between predicted and actual segmentation
def dice_index(y_pred, y_actual):
    smooth = 0.000001
    size_of_batch = y_pred.size(0)
    
    p1 = y_pred.view(size_of_batch, -1)
    p2 = y_actual.view(size_of_batch, -1)
    
    intersection = (p1 * p2).sum()
    
    dice =  ((2.0 * intersection )+ smooth) / (p1.sum() + p2.sum() + smooth)
    #dice.requires_grad = True
    
    return dice

# %%
# calculate dice loss which will be later used in loss function calculation
def dice_loss(y_predict, y_train): ## to add in bce looss
  
  dice_loss = 1 -(dice_index(y_predict, y_train))
  
  return dice_loss

# %%
epochs = 150
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

train_running_loss_history = []
validation_running_loss_history =[]

for e in range(epochs):
  train_running_loss = 0.0
  validation_running_loss = 0.0
  
  model.train()
  
  for ith_batch, sample_batched in enumerate(train_loader):
    X_train = sample_batched['image'].to('cuda')
    y_train = sample_batched['annotation'].to('cuda')
    
    #X_train.requires_grad = True
    #y_train.requires_grad = True

    #print(ith_batch) #, X_train.size(), y_train.size())

    optimizer.zero_grad()
    y_pred = model(X_train)
   # out = (y_pred + 0.5).int().float()
    
    loss = 0.30 * dice_loss(y_pred, y_train) +  0.70 * criterion(y_pred, y_train)
    #loss = criterion(y_pred, y_train)
    loss.backward()
    optimizer.step()
    
    if ith_batch % 50 == 0:
      print('Epoch: ', e + 1, 'Batch: ', ith_batch, 'Current Loss: ', loss.item())
      
    train_running_loss += loss.item()
    
    
    
    
  else:
    with torch.no_grad():
      
      model.eval()
      
      for ith_batch, sample_batched in enumerate(validation_loader):
          X_val = sample_batched['image'].to('cuda')
          y_val = sample_batched['annotation'].to('cuda')
          
          
          
          y_out = model(X_val)
          out_val = (y_out + 0.5).int().float()
          
          val_loss = 0.3 * dice_loss(out_val, y_val)  + 0.7 * criterion(y_out, y_val)
          
          #val_loss = criterion(y_out, y_val)
          
          validation_running_loss += val_loss.item()
      print("================================================================================")
      print("Epoch {} completed".format(e + 1))
      
      train_epoch_loss = train_running_loss / len(train_loader)
      validation_epoch_loss = validation_running_loss / len(validation_loader)
      
      print("Average train loss is {}: ".format(train_epoch_loss))
      print("Average validation loss is {}".format(validation_epoch_loss))
      print("================================================================================")
      train_running_loss_history.append(train_epoch_loss)
      validation_running_loss_history.append(validation_epoch_loss)
  
  torch.cuda.empty_cache()
      #print(y_pred.shape)

    #y_pred = y_pred.to('cpu')
    #X_train = X_train.to('cpu')

    #del y_train
    #torch.cuda.empty_cache()
    #if ith_batch ==100:
    #break
  #for index in range(2):
  #         ax = gig.add_subplot(2, 2 , index + 1)  # subplot index starts from 1
   #         plt.imshow(im_converter(X_train[index]))
    #        ax = gig.add_subplot(2, 2, index + 3)
     #       plt.imshow(im_converter(y_pred[index]))
  
torch.save(model,"Models/test.pt")
# Out:
# Epoch:  1 Batch:  0 Current Loss:  0.7395423650741577
# Epoch:  1 Batch:  50 Current Loss:  0.5881130695343018
# Epoch:  1 Batch:  100 Current Loss:  0.4942976236343384
# Epoch:  1 Batch:  150 Current Loss:  0.4340192675590515
# Epoch:  1 Batch:  200 Current Loss:  0.3224125802516937
# Epoch:  1 Batch:  250 Current Loss:  0.28093212842941284
# Epoch:  1 Batch:  300 Current Loss:  0.3656717836856842
# Epoch:  1 Batch:  350 Current Loss:  0.3641835153102875
# ================================================================================
# Epoch 1 completed
# Average train loss is 0.4177673874795437:
# Average validation loss is 0.32754468932747843
# ================================================================================
# Epoch:  2 Batch:  0 Current Loss:  0.43571749329566956
# Epoch:  2 Batch:  50 Current Loss:  0.23972947895526886
# Epoch:  2 Batch:  100 Current Loss:  0.40329185128211975
# Epoch:  2 Batch:  150 Current Loss:  0.384621798992157
# Epoch:  2 Batch:  200 Current Loss:  0.28184089064598083
# Epoch:  2 Batch:  250 Current Loss:  0.27150794863700867
# Epoch:  2 Batch:  300 Current Loss:  0.28737154603004456
# Epoch:  2 Batch:  350 Current Loss:  0.1927649974822998
# ================================================================================
# Epoch 2 completed
# Average train loss is 0.2900612396933138:
# Average validation loss is 0.23151070110499858
# ================================================================================
# Epoch:  3 Batch:  0 Current Loss:  0.37423062324523926
# Epoch:  3 Batch:  50 Current Loss:  0.42188742756843567
# Epoch:  3 Batch:  100 Current Loss:  0.2064829021692276
# Epoch:  3 Batch:  150 Current Loss:  0.1822667419910431
# Epoch:  3 Batch:  200 Current Loss:  0.35445165634155273
# Epoch:  3 Batch:  250 Current Loss:  0.27031973004341125
# Epoch:  3 Batch:  300 Current Loss:  0.21101391315460205
# Epoch:  3 Batch:  350 Current Loss:  0.22580181062221527
# ================================================================================
# Epoch 3 completed
# Average train loss is 0.23449731171131133:
# Average validation loss is 0.29066038198769095
# ================================================================================
# Epoch:  4 Batch:  0 Current Loss:  0.20065750181674957
# Epoch:  4 Batch:  50 Current Loss:  0.1895633488893509
# Epoch:  4 Batch:  100 Current Loss:  0.11246908456087112
# Epoch:  4 Batch:  150 Current Loss:  0.14747655391693115
# Epoch:  4 Batch:  200 Current Loss:  0.2541031539440155
# Epoch:  4 Batch:  250 Current Loss:  0.20542363822460175
# Epoch:  4 Batch:  300 Current Loss:  0.3416077792644501
# Epoch:  4 Batch:  350 Current Loss:  0.1171218678355217
# ================================================================================
# Epoch 4 completed
# Average train loss is 0.20543944889679552:
# Average validation loss is 0.20797946393489838
# ================================================================================
# Epoch:  5 Batch:  0 Current Loss:  0.12605804204940796
# Epoch:  5 Batch:  50 Current Loss:  0.15837369859218597
# Epoch:  5 Batch:  100 Current Loss:  0.312832772731781
# Epoch:  5 Batch:  150 Current Loss:  0.2518876791000366
# Epoch:  5 Batch:  200 Current Loss:  0.07237455248832703
# Epoch:  5 Batch:  250 Current Loss:  0.1477338969707489
# Epoch:  5 Batch:  300 Current Loss:  0.13016349077224731
# Epoch:  5 Batch:  350 Current Loss:  0.27969270944595337
# ================================================================================
# Epoch 5 completed
# Average train loss is 0.18372268866747618:
# Average validation loss is 0.13930532891303302
# ================================================================================
# Epoch:  6 Batch:  0 Current Loss:  0.21446412801742554
# Epoch:  6 Batch:  50 Current Loss:  0.06116329878568649
# Epoch:  6 Batch:  100 Current Loss:  0.17961448431015015
# Epoch:  6 Batch:  150 Current Loss:  0.08919171988964081
# Epoch:  6 Batch:  200 Current Loss:  0.18368113040924072
# Epoch:  6 Batch:  250 Current Loss:  0.1238269954919815
# Epoch:  6 Batch:  300 Current Loss:  0.10306332260370255
# Epoch:  6 Batch:  350 Current Loss:  0.06915885955095291
# ================================================================================
# Epoch 6 completed
# Average train loss is 0.1556278365198523:
# Average validation loss is 0.46862452626228335
# ================================================================================
# Epoch:  7 Batch:  0 Current Loss:  0.10299969464540482
# Epoch:  7 Batch:  50 Current Loss:  0.15260152518749237
# Epoch:  7 Batch:  100 Current Loss:  0.10934081673622131
# Epoch:  7 Batch:  150 Current Loss:  0.1601683795452118
# Epoch:  7 Batch:  200 Current Loss:  0.20156143605709076
# Epoch:  7 Batch:  250 Current Loss:  0.26025909185409546
# Epoch:  7 Batch:  300 Current Loss:  0.08156399428844452
# Epoch:  7 Batch:  350 Current Loss:  0.09536275267601013
# ================================================================================
# Epoch 7 completed
# Average train loss is 0.13746854884549975:
# Average validation loss is 0.1714251372218132
# ================================================================================
# Epoch:  8 Batch:  0 Current Loss:  0.09894074499607086
# Epoch:  8 Batch:  50 Current Loss:  0.1827220916748047
# Epoch:  8 Batch:  100 Current Loss:  0.06216776371002197
# Epoch:  8 Batch:  150 Current Loss:  0.10373730957508087
# Epoch:  8 Batch:  200 Current Loss:  0.0739298090338707
# Epoch:  8 Batch:  250 Current Loss:  0.105818971991539
# Epoch:  8 Batch:  300 Current Loss:  0.09129522740840912
# Epoch:  8 Batch:  350 Current Loss:  0.06623708456754684
# ================================================================================
# Epoch 8 completed
# Average train loss is 0.1221991522796452:
# Average validation loss is 0.21592874441295862
# ================================================================================
# Epoch:  9 Batch:  0 Current Loss:  0.12318262457847595
# Epoch:  9 Batch:  50 Current Loss:  0.09651829302310944
# Epoch:  9 Batch:  100 Current Loss:  0.10388875752687454
# Epoch:  9 Batch:  150 Current Loss:  0.12193717807531357
# Epoch:  9 Batch:  200 Current Loss:  0.11463028192520142
# Epoch:  9 Batch:  250 Current Loss:  0.10101127624511719
# Epoch:  9 Batch:  300 Current Loss:  0.13853704929351807
# Epoch:  9 Batch:  350 Current Loss:  0.062195368111133575
# ================================================================================
# Epoch 9 completed
# Average train loss is 0.10811235397122801:
# Average validation loss is 2.7068050953745844
# ================================================================================
# Epoch:  10 Batch:  0 Current Loss:  0.09178914874792099
# Epoch:  10 Batch:  50 Current Loss:  0.0693058967590332
# Epoch:  10 Batch:  100 Current Loss:  0.10511994361877441
# Epoch:  10 Batch:  150 Current Loss:  0.18006978929042816
# Epoch:  10 Batch:  200 Current Loss:  0.08080524206161499
# Epoch:  10 Batch:  250 Current Loss:  0.3214258551597595
# Epoch:  10 Batch:  300 Current Loss:  0.05185147002339363
# Epoch:  10 Batch:  350 Current Loss:  0.04832522198557854
# ================================================================================
# Epoch 10 completed
# Average train loss is 0.10460230248048902:
# Average validation loss is 0.08560790546238423
# ================================================================================
# Epoch:  11 Batch:  0 Current Loss:  0.24907420575618744
# Epoch:  11 Batch:  50 Current Loss:  0.09172244369983673
# Epoch:  11 Batch:  100 Current Loss:  0.05373138561844826
# Epoch:  11 Batch:  150 Current Loss:  0.05071069672703743
# Epoch:  11 Batch:  200 Current Loss:  0.15195685625076294
# Epoch:  11 Batch:  250 Current Loss:  0.0652630627155304
# Epoch:  11 Batch:  300 Current Loss:  0.11859685927629471
# Epoch:  11 Batch:  350 Current Loss:  0.04628298431634903
# ================================================================================
# Epoch 11 completed
# Average train loss is 0.0912696679821238:
# Average validation loss is 0.14332412522286175
# ================================================================================
# Epoch:  12 Batch:  0 Current Loss:  0.07302071154117584
# Epoch:  12 Batch:  50 Current Loss:  0.07620465010404587
# Epoch:  12 Batch:  100 Current Loss:  0.06391259282827377
# Epoch:  12 Batch:  150 Current Loss:  0.09427401423454285
# Epoch:  12 Batch:  200 Current Loss:  0.05255904793739319
# Epoch:  12 Batch:  250 Current Loss:  0.07164733111858368
# Epoch:  12 Batch:  300 Current Loss:  0.0876404345035553
# Epoch:  12 Batch:  350 Current Loss:  0.11505576223134995
# ================================================================================
# Epoch 12 completed
# Average train loss is 0.08775934991426766:
# Average validation loss is 0.08974777918308974
# ================================================================================
# Epoch:  13 Batch:  0 Current Loss:  0.06834256649017334
# Epoch:  13 Batch:  50 Current Loss:  0.07165712118148804
# Epoch:  13 Batch:  100 Current Loss:  0.07890897989273071
# Epoch:  13 Batch:  150 Current Loss:  0.07886806130409241
# Epoch:  13 Batch:  200 Current Loss:  0.061742156744003296
# Epoch:  13 Batch:  250 Current Loss:  0.11183948069810867
# Epoch:  13 Batch:  300 Current Loss:  0.11235712468624115
# Epoch:  13 Batch:  350 Current Loss:  0.07710560411214828
# ================================================================================
# Epoch 13 completed
# Average train loss is 0.08601466345600783:
# Average validation loss is 0.11280874939635396
# ================================================================================
# Epoch:  14 Batch:  0 Current Loss:  0.05877301096916199
# Epoch:  14 Batch:  50 Current Loss:  0.13856084644794464
# Epoch:  14 Batch:  100 Current Loss:  0.04638337343931198
# Epoch:  14 Batch:  150 Current Loss:  0.10726673156023026
# Epoch:  14 Batch:  200 Current Loss:  0.12390895187854767
# Epoch:  14 Batch:  250 Current Loss:  0.09849061071872711
# Epoch:  14 Batch:  300 Current Loss:  0.04697946831583977
# Epoch:  14 Batch:  350 Current Loss:  0.06734465807676315
# ================================================================================
# Epoch 14 completed
# Average train loss is 0.08656024159863591:
# Average validation loss is 0.08487762667238713
# ================================================================================
# Epoch:  15 Batch:  0 Current Loss:  0.09377893805503845
# Epoch:  15 Batch:  50 Current Loss:  0.20993737876415253
# Epoch:  15 Batch:  100 Current Loss:  0.05995456501841545
# Epoch:  15 Batch:  150 Current Loss:  0.19650901854038239
# Epoch:  15 Batch:  200 Current Loss:  0.04733601585030556
# Epoch:  15 Batch:  250 Current Loss:  0.03634953498840332
# Epoch:  15 Batch:  300 Current Loss:  0.07019627094268799
# Epoch:  15 Batch:  350 Current Loss:  0.09771201014518738
# ================================================================================
# Epoch 15 completed
# Average train loss is 0.07909192830789834:
# Average validation loss is 0.3500774385035038
# ================================================================================
# Epoch:  16 Batch:  0 Current Loss:  0.04400869458913803
# Epoch:  16 Batch:  50 Current Loss:  0.21837835013866425
# Epoch:  16 Batch:  100 Current Loss:  0.05520687252283096
# Epoch:  16 Batch:  150 Current Loss:  0.05177432671189308
# Epoch:  16 Batch:  200 Current Loss:  0.11904792487621307
# Epoch:  16 Batch:  250 Current Loss:  0.05002813786268234
# Epoch:  16 Batch:  300 Current Loss:  0.06950816512107849
# Epoch:  16 Batch:  350 Current Loss:  0.06470569223165512
# ================================================================================
# Epoch 16 completed
# Average train loss is 0.07354278042446821:
# Average validation loss is 0.2757933621481061
# ================================================================================
# Epoch:  17 Batch:  0 Current Loss:  0.06549656391143799
# Epoch:  17 Batch:  50 Current Loss:  0.04860889911651611
# Epoch:  17 Batch:  100 Current Loss:  0.042851705104112625
# Epoch:  17 Batch:  150 Current Loss:  0.045545000582933426
# Epoch:  17 Batch:  200 Current Loss:  0.11410870403051376
# Epoch:  17 Batch:  250 Current Loss:  0.07879102230072021
# Epoch:  17 Batch:  300 Current Loss:  0.08149775117635727
# Epoch:  17 Batch:  350 Current Loss:  0.07567209750413895
# ================================================================================
# Epoch 17 completed
# Average train loss is 0.07617613637354224:
# Average validation loss is 0.08120183315128088
# ================================================================================
# Epoch:  18 Batch:  0 Current Loss:  0.09979745745658875
# Epoch:  18 Batch:  50 Current Loss:  0.11335882544517517
# Epoch:  18 Batch:  100 Current Loss:  0.04121307283639908
# Epoch:  18 Batch:  150 Current Loss:  0.04958292469382286
# Epoch:  18 Batch:  200 Current Loss:  0.12892545759677887
# Epoch:  18 Batch:  250 Current Loss:  0.06068010255694389
# Epoch:  18 Batch:  300 Current Loss:  0.0553913488984108
# Epoch:  18 Batch:  350 Current Loss:  0.034386493265628815
# ================================================================================
# Epoch 18 completed
# Average train loss is 0.07017613981384783:
# Average validation loss is 0.068181570507586
# ================================================================================
# Epoch:  19 Batch:  0 Current Loss:  0.056835781782865524
# Epoch:  19 Batch:  50 Current Loss:  0.06307326257228851
# Epoch:  19 Batch:  100 Current Loss:  0.08191476762294769
# Epoch:  19 Batch:  150 Current Loss:  0.13358952105045319
# Epoch:  19 Batch:  200 Current Loss:  0.04913698881864548
# Epoch:  19 Batch:  250 Current Loss:  0.40954264998435974
# Epoch:  19 Batch:  300 Current Loss:  0.0558772087097168
# Epoch:  19 Batch:  350 Current Loss:  0.056936733424663544
# ================================================================================
# Epoch 19 completed
# Average train loss is 0.07568862615153193:
# Average validation loss is 0.08155687291175127
# ================================================================================
# Epoch:  20 Batch:  0 Current Loss:  0.035605136305093765
# Epoch:  20 Batch:  50 Current Loss:  0.02381475456058979
# Epoch:  20 Batch:  100 Current Loss:  0.0607270672917366
# Epoch:  20 Batch:  150 Current Loss:  0.10455706715583801
# Epoch:  20 Batch:  200 Current Loss:  0.05161726102232933
# Epoch:  20 Batch:  250 Current Loss:  0.06434797495603561
# Epoch:  20 Batch:  300 Current Loss:  0.0340457558631897
# Epoch:  20 Batch:  350 Current Loss:  0.03204674646258354
# ================================================================================
# Epoch 20 completed
# Average train loss is 0.07601666828617454:
# Average validation loss is 0.08641354747116566
# ================================================================================
# Epoch:  21 Batch:  0 Current Loss:  0.06721934676170349
# Epoch:  21 Batch:  50 Current Loss:  0.04416194185614586
# Epoch:  21 Batch:  100 Current Loss:  0.04584244266152382
# Epoch:  21 Batch:  150 Current Loss:  0.05978908762335777
# Epoch:  21 Batch:  200 Current Loss:  0.16222162544727325
# Epoch:  21 Batch:  250 Current Loss:  0.07144586741924286
# Epoch:  21 Batch:  300 Current Loss:  0.04017007723450661
# Epoch:  21 Batch:  350 Current Loss:  0.038842394948005676
# ================================================================================
# Epoch 21 completed
# Average train loss is 0.06761162245646118:
# Average validation loss is 0.1307126406021416
# ================================================================================
# Epoch:  22 Batch:  0 Current Loss:  0.15688921511173248
# Epoch:  22 Batch:  50 Current Loss:  0.05046791955828667
# Epoch:  22 Batch:  100 Current Loss:  0.03844655305147171
# Epoch:  22 Batch:  150 Current Loss:  0.0728774145245552
# Epoch:  22 Batch:  200 Current Loss:  0.04745107516646385
# Epoch:  22 Batch:  250 Current Loss:  0.046189092099666595
# Epoch:  22 Batch:  300 Current Loss:  0.11148664355278015
# Epoch:  22 Batch:  350 Current Loss:  0.03772876039147377
# ================================================================================
# Epoch 22 completed
# Average train loss is 0.06902456200681627:
# Average validation loss is 0.06496031858026981
# ================================================================================
# Epoch:  23 Batch:  0 Current Loss:  0.033864740282297134
# Epoch:  23 Batch:  50 Current Loss:  0.04676339030265808
# Epoch:  23 Batch:  100 Current Loss:  0.06585058569908142
# Epoch:  23 Batch:  150 Current Loss:  0.0327865406870842
# Epoch:  23 Batch:  200 Current Loss:  0.1265387237071991
# Epoch:  23 Batch:  250 Current Loss:  0.09090045094490051
# Epoch:  23 Batch:  300 Current Loss:  0.051942966878414154
# Epoch:  23 Batch:  350 Current Loss:  0.04785778000950813
# ================================================================================
# Epoch 23 completed
# Average train loss is 0.06938635314349086:
# Average validation loss is 0.08109399342909455
# ================================================================================
# Epoch:  24 Batch:  0 Current Loss:  0.05476630479097366
# Epoch:  24 Batch:  50 Current Loss:  0.09659874439239502
# Epoch:  24 Batch:  100 Current Loss:  0.031710751354694366
# Epoch:  24 Batch:  150 Current Loss:  0.044596992433071136
# Epoch:  24 Batch:  200 Current Loss:  0.09683459997177124
# Epoch:  24 Batch:  250 Current Loss:  0.0562470480799675
# Epoch:  24 Batch:  300 Current Loss:  0.09829696267843246
# Epoch:  24 Batch:  350 Current Loss:  0.06183984503149986
# ================================================================================
# Epoch 24 completed
# Average train loss is 0.06348882620222866:
# Average validation loss is 0.08703202055767179
# ================================================================================
# Epoch:  25 Batch:  0 Current Loss:  0.04245434328913689
# Epoch:  25 Batch:  50 Current Loss:  0.13621672987937927
# Epoch:  25 Batch:  100 Current Loss:  0.041505780071020126
# Epoch:  25 Batch:  150 Current Loss:  0.06734421849250793
# Epoch:  25 Batch:  200 Current Loss:  0.053107328712940216
# Epoch:  25 Batch:  250 Current Loss:  0.057729221880435944
# Epoch:  25 Batch:  300 Current Loss:  0.025318585336208344
# Epoch:  25 Batch:  350 Current Loss:  0.03283960744738579
# ================================================================================
# Epoch 25 completed
# Average train loss is 0.05952487643808126:
# Average validation loss is 0.06201122358441353
# ================================================================================
# Epoch:  26 Batch:  0 Current Loss:  0.03747977316379547
# Epoch:  26 Batch:  50 Current Loss:  0.08177822083234787
# Epoch:  26 Batch:  100 Current Loss:  0.03622066229581833
# Epoch:  26 Batch:  150 Current Loss:  0.047609154134988785
# Epoch:  26 Batch:  200 Current Loss:  0.040855005383491516
# Epoch:  26 Batch:  250 Current Loss:  0.03793467953801155
# Epoch:  26 Batch:  300 Current Loss:  0.031447894871234894
# Epoch:  26 Batch:  350 Current Loss:  0.03393702208995819
# ================================================================================
# Epoch 26 completed
# Average train loss is 0.06068726458121091:
# Average validation loss is 0.18733127787709236
# ================================================================================
# Epoch:  27 Batch:  0 Current Loss:  0.034330740571022034
# Epoch:  27 Batch:  50 Current Loss:  0.04842681065201759
# Epoch:  27 Batch:  100 Current Loss:  0.09350741654634476
# Epoch:  27 Batch:  150 Current Loss:  0.03165241330862045
# Epoch:  27 Batch:  200 Current Loss:  0.08533516526222229
# Epoch:  27 Batch:  250 Current Loss:  0.05929595232009888
# Epoch:  27 Batch:  300 Current Loss:  0.06919708847999573
# Epoch:  27 Batch:  350 Current Loss:  0.039098791778087616
# ================================================================================
# Epoch 27 completed
# Average train loss is 0.06847630817908794:
# Average validation loss is 0.0652216493524611
# ================================================================================
# Epoch:  28 Batch:  0 Current Loss:  0.03457368165254593
# Epoch:  28 Batch:  50 Current Loss:  0.050632454454898834
# Epoch:  28 Batch:  100 Current Loss:  0.0486786812543869
# Epoch:  28 Batch:  150 Current Loss:  0.04126152768731117
# Epoch:  28 Batch:  200 Current Loss:  0.059521470218896866
# Epoch:  28 Batch:  250 Current Loss:  0.12553060054779053
# Epoch:  28 Batch:  300 Current Loss:  0.031509995460510254
# Epoch:  28 Batch:  350 Current Loss:  0.06581778079271317
# ================================================================================
# Epoch 28 completed
# Average train loss is 0.059144265209324656:
# Average validation loss is 0.06677254201844335
# ================================================================================
# Epoch:  29 Batch:  0 Current Loss:  0.057562801986932755
# Epoch:  29 Batch:  50 Current Loss:  0.07460586726665497
# Epoch:  29 Batch:  100 Current Loss:  0.0673854872584343
# Epoch:  29 Batch:  150 Current Loss:  0.025515172630548477
# Epoch:  29 Batch:  200 Current Loss:  0.05987190082669258
# Epoch:  29 Batch:  250 Current Loss:  0.10784363001585007
# Epoch:  29 Batch:  300 Current Loss:  0.04459591209888458
# Epoch:  29 Batch:  350 Current Loss:  0.03400669991970062
# ================================================================================
# Epoch 29 completed
# Average train loss is 0.06126314924564213:
# Average validation loss is 0.06276004491373896
# ================================================================================
# Epoch:  30 Batch:  0 Current Loss:  0.027365582063794136
# Epoch:  30 Batch:  50 Current Loss:  0.15482884645462036
# Epoch:  30 Batch:  100 Current Loss:  0.07044951617717743
# Epoch:  30 Batch:  150 Current Loss:  0.04231759160757065
# Epoch:  30 Batch:  200 Current Loss:  0.04071030020713806
# Epoch:  30 Batch:  250 Current Loss:  0.03173543140292168
# Epoch:  30 Batch:  300 Current Loss:  0.08305202424526215
# Epoch:  30 Batch:  350 Current Loss:  0.03792137652635574
# ================================================================================
# Epoch 30 completed
# Average train loss is 0.05895502172876149:
# Average validation loss is 0.06190661026164889
# ================================================================================
# Epoch:  31 Batch:  0 Current Loss:  0.03944423049688339
# Epoch:  31 Batch:  50 Current Loss:  0.03416639193892479
# Epoch:  31 Batch:  100 Current Loss:  0.0427454337477684
# Epoch:  31 Batch:  150 Current Loss:  0.16542646288871765
# Epoch:  31 Batch:  200 Current Loss:  0.05072084814310074
# Epoch:  31 Batch:  250 Current Loss:  0.04302917793393135
# Epoch:  31 Batch:  300 Current Loss:  0.04866772145032883
# Epoch:  31 Batch:  350 Current Loss:  0.04170313477516174
# ================================================================================
# Epoch 31 completed
# Average train loss is 0.059871577154845:
# Average validation loss is 0.15261741925030947
# ================================================================================
# Epoch:  32 Batch:  0 Current Loss:  0.24392247200012207
# Epoch:  32 Batch:  50 Current Loss:  0.04061996564269066
# Epoch:  32 Batch:  100 Current Loss:  0.07007072865962982
# Epoch:  32 Batch:  150 Current Loss:  0.08101123571395874
# Epoch:  32 Batch:  200 Current Loss:  0.06039724871516228
# Epoch:  32 Batch:  250 Current Loss:  0.05080012232065201
# Epoch:  32 Batch:  300 Current Loss:  0.07224591821432114
# Epoch:  32 Batch:  350 Current Loss:  0.07671324908733368
# ================================================================================
# Epoch 32 completed
# Average train loss is 0.055826445631682875:
# Average validation loss is 0.07165152868255972
# ================================================================================
# Epoch:  33 Batch:  0 Current Loss:  0.05182346701622009
# Epoch:  33 Batch:  50 Current Loss:  0.08187009394168854
# Epoch:  33 Batch:  100 Current Loss:  0.03363877907395363
# Epoch:  33 Batch:  150 Current Loss:  0.07764893770217896
# Epoch:  33 Batch:  200 Current Loss:  0.05013376101851463
# Epoch:  33 Batch:  250 Current Loss:  0.04921134188771248
# Epoch:  33 Batch:  300 Current Loss:  0.14550940692424774
# Epoch:  33 Batch:  350 Current Loss:  0.0900462418794632
# ================================================================================
# Epoch 33 completed
# Average train loss is 0.05832117661368102:
# Average validation loss is 0.05824055023491383
# ================================================================================
# Epoch:  34 Batch:  0 Current Loss:  0.05377572402358055
# Epoch:  34 Batch:  50 Current Loss:  0.05369997024536133
# Epoch:  34 Batch:  100 Current Loss:  0.04439235106110573
# Epoch:  34 Batch:  150 Current Loss:  0.026628581807017326
# Epoch:  34 Batch:  200 Current Loss:  0.1002320796251297
# Epoch:  34 Batch:  250 Current Loss:  0.09619060903787613
# Epoch:  34 Batch:  300 Current Loss:  0.11819521337747574
# Epoch:  34 Batch:  350 Current Loss:  0.07096849381923676
# ================================================================================
# Epoch 34 completed
# Average train loss is 0.05688521860633045:
# Average validation loss is 0.07150014324113727
# ================================================================================
# Epoch:  35 Batch:  0 Current Loss:  0.05364975333213806
# Epoch:  35 Batch:  50 Current Loss:  0.04320178180932999
# Epoch:  35 Batch:  100 Current Loss:  0.06792508810758591
# Epoch:  35 Batch:  150 Current Loss:  0.03504451364278793
# Epoch:  35 Batch:  200 Current Loss:  0.08909735083580017
# Epoch:  35 Batch:  250 Current Loss:  0.03238045796751976
# Epoch:  35 Batch:  300 Current Loss:  0.03410304710268974
# Epoch:  35 Batch:  350 Current Loss:  0.06398922204971313
# ================================================================================
# Epoch 35 completed
# Average train loss is 0.054903550897724925:
# Average validation loss is 0.1810702182725072
# ================================================================================
# Epoch:  36 Batch:  0 Current Loss:  0.05994035676121712
# Epoch:  36 Batch:  50 Current Loss:  0.0815342366695404
# Epoch:  36 Batch:  100 Current Loss:  0.034622643142938614
# Epoch:  36 Batch:  150 Current Loss:  0.027582015842199326
# Epoch:  36 Batch:  200 Current Loss:  0.04330926388502121
# Epoch:  36 Batch:  250 Current Loss:  0.04311661794781685
# Epoch:  36 Batch:  300 Current Loss:  0.06606976687908173
# Epoch:  36 Batch:  350 Current Loss:  0.062395788729190826
# ================================================================================
# Epoch 36 completed
# Average train loss is 0.05508920604363084:
# Average validation loss is 0.07641917457804084
# ================================================================================
# Epoch:  37 Batch:  0 Current Loss:  0.04678862541913986
# Epoch:  37 Batch:  50 Current Loss:  0.03213869035243988
# Epoch:  37 Batch:  100 Current Loss:  0.18378600478172302
# Epoch:  37 Batch:  150 Current Loss:  0.029371656477451324
# Epoch:  37 Batch:  200 Current Loss:  0.05711174011230469
# Epoch:  37 Batch:  250 Current Loss:  0.03624078258872032
# Epoch:  37 Batch:  300 Current Loss:  0.05181727558374405
# Epoch:  37 Batch:  350 Current Loss:  0.042364709079265594
# ================================================================================
# Epoch 37 completed
# Average train loss is 0.05334054511971772:
# Average validation loss is 0.0838085469789803
# ================================================================================
# Epoch:  38 Batch:  0 Current Loss:  0.053203098475933075
# Epoch:  38 Batch:  50 Current Loss:  0.06888971477746964
# Epoch:  38 Batch:  100 Current Loss:  0.0319950245320797
# Epoch:  38 Batch:  150 Current Loss:  0.030695371329784393
# Epoch:  38 Batch:  200 Current Loss:  0.057121746242046356
# Epoch:  38 Batch:  250 Current Loss:  0.03588677942752838
# Epoch:  38 Batch:  300 Current Loss:  0.039045725017786026
# Epoch:  38 Batch:  350 Current Loss:  0.052268944680690765
# ================================================================================
# Epoch 38 completed
# Average train loss is 0.05299629492685199:
# Average validation loss is 0.06365032777190209
# ================================================================================
# Epoch:  39 Batch:  0 Current Loss:  0.03519148752093315
# Epoch:  39 Batch:  50 Current Loss:  0.05685441941022873
# Epoch:  39 Batch:  100 Current Loss:  0.027629777789115906
# Epoch:  39 Batch:  150 Current Loss:  0.03638441488146782
# Epoch:  39 Batch:  200 Current Loss:  0.0409519225358963
# Epoch:  39 Batch:  250 Current Loss:  0.09393013268709183
# Epoch:  39 Batch:  300 Current Loss:  0.026852551847696304
# Epoch:  39 Batch:  350 Current Loss:  0.030517281964421272
# ================================================================================
# Epoch 39 completed
# Average train loss is 0.05392952186986804:
# Average validation loss is 0.06967626683413983
# ================================================================================
# Epoch:  40 Batch:  0 Current Loss:  0.05862543731927872
# Epoch:  40 Batch:  50 Current Loss:  0.10932272672653198
# Epoch:  40 Batch:  100 Current Loss:  0.05668291449546814
# Epoch:  40 Batch:  150 Current Loss:  0.029476923868060112
# Epoch:  40 Batch:  200 Current Loss:  0.0537395253777504
# Epoch:  40 Batch:  250 Current Loss:  0.08321481943130493
# Epoch:  40 Batch:  300 Current Loss:  0.04730277508497238
# Epoch:  40 Batch:  350 Current Loss:  0.07403311878442764
# ================================================================================
# Epoch 40 completed
# Average train loss is 0.04934904096648097:
# Average validation loss is 0.069009929895401
# ================================================================================
# Epoch:  41 Batch:  0 Current Loss:  0.08259600400924683
# Epoch:  41 Batch:  50 Current Loss:  0.04191166162490845
# Epoch:  41 Batch:  100 Current Loss:  0.04090144485235214
# Epoch:  41 Batch:  150 Current Loss:  0.06742273271083832
# Epoch:  41 Batch:  200 Current Loss:  0.05539758503437042
# Epoch:  41 Batch:  250 Current Loss:  0.05594778060913086
# Epoch:  41 Batch:  300 Current Loss:  0.11108608543872833
# Epoch:  41 Batch:  350 Current Loss:  0.06850093603134155
# ================================================================================
# Epoch 41 completed
# Average train loss is 0.05474601061083376:
# Average validation loss is 0.06730940200388431
# ================================================================================
# Epoch:  42 Batch:  0 Current Loss:  0.03948341682553291
# Epoch:  42 Batch:  50 Current Loss:  0.04566634073853493
# Epoch:  42 Batch:  100 Current Loss:  0.07207751274108887
# Epoch:  42 Batch:  150 Current Loss:  0.04854577034711838
# Epoch:  42 Batch:  200 Current Loss:  0.03267629072070122
# Epoch:  42 Batch:  250 Current Loss:  0.04214394837617874
# Epoch:  42 Batch:  300 Current Loss:  0.09026135504245758
# Epoch:  42 Batch:  350 Current Loss:  0.038995396345853806
# ================================================================================
# Epoch 42 completed
# Average train loss is 0.04893762368708849:
# Average validation loss is 0.05069476587697864
# ================================================================================
# Epoch:  43 Batch:  0 Current Loss:  0.04960356652736664
# Epoch:  43 Batch:  50 Current Loss:  0.04344477504491806
# Epoch:  43 Batch:  100 Current Loss:  0.20754340291023254
# Epoch:  43 Batch:  150 Current Loss:  0.0743316188454628
# Epoch:  43 Batch:  200 Current Loss:  0.034534137696027756
# Epoch:  43 Batch:  250 Current Loss:  0.04999946057796478
# Epoch:  43 Batch:  300 Current Loss:  0.051085442304611206
# Epoch:  43 Batch:  350 Current Loss:  0.027616899460554123
# ================================================================================
# Epoch 43 completed
# Average train loss is 0.050421607387252154:
# Average validation loss is 0.17494756605476142
# ================================================================================
# Epoch:  44 Batch:  0 Current Loss:  0.043791111558675766
# Epoch:  44 Batch:  50 Current Loss:  0.058214470744132996
# Epoch:  44 Batch:  100 Current Loss:  0.04749608784914017
# Epoch:  44 Batch:  150 Current Loss:  0.10098835825920105
# Epoch:  44 Batch:  200 Current Loss:  0.03767068311572075
# Epoch:  44 Batch:  250 Current Loss:  0.06439417600631714
# Epoch:  44 Batch:  300 Current Loss:  0.03784831613302231
# Epoch:  44 Batch:  350 Current Loss:  0.06017895042896271
# ================================================================================
# Epoch 44 completed
# Average train loss is 0.049903343957848845:
# Average validation loss is 0.05761300390586257
# ================================================================================
# Epoch:  45 Batch:  0 Current Loss:  0.03473110869526863
# Epoch:  45 Batch:  50 Current Loss:  0.03497375547885895
# Epoch:  45 Batch:  100 Current Loss:  0.04356919229030609
# Epoch:  45 Batch:  150 Current Loss:  0.03259442001581192
# Epoch:  45 Batch:  200 Current Loss:  0.03908362239599228
# Epoch:  45 Batch:  250 Current Loss:  0.03081618994474411

# %%
plt.plot(train_running_loss_history, label = 'Train Loss')
plt.plot(validation_running_loss_history, label = 'Validation Loss')
plt.legend()

# %%
model.eval()
X_train.size()

# %%
out = (y_pred + 0.5).int().float()

# %%
print(dice_index(y_train, out))
print(dice_loss(y_train, out))

# %%
# pig = plt.figure(figsize = (15, 6))

# a = pig.add_subplot(2, 3, 1)
# plt.imshow(im_converterX(X_train[0]))

# a = pig.add_subplot(2, 3, 2)
# plt.imshow(im_converterY(y_train[0]))

# a = pig.add_subplot(2, 3, 3)
# plt.imshow(im_converterY(out[0]))


# a = pig.add_subplot(2, 3, 4)
# plt.imshow(im_converterX(X_train[1]))

# a = pig.add_subplot(2, 3, 5)
# plt.imshow(im_converterY(y_train[1]))

# a = pig.add_subplot(2, 3, 6)
# plt.imshow(im_converterY(out[1]))

# %%
gg = dice_index(out, y_train)
print(gg)
print(dice_loss(out, y_train))

# %%
class HC18_test(Dataset):
    def __init__(self, root_dir, transformX = None):
        self.pixel_file = pd.read_csv(os.path.join(root_dir, 'test_set_pixel_size.csv'))
        self.root_dir = root_dir
        self.transformX = transformX
        
    def __len__(self):
        return len(self.pixel_file)
    
    def __getitem__(self, index):
        imx_name = os.path.join(self.root_dir, 'test_set', self.pixel_file.iloc[index, 0])
        
        imx = Image.open(imx_name)
        
        f_name = self.pixel_file.iloc[index, 0]
        
        if self.transformX :
            imx = self.transformX(imx)
        
        sample = {'image': imx, 'f_name': f_name}
        return sample

# %%
test_data = HC18_test('', transformX = tx_X)

# %%
test_data

# %%
test_loader = DataLoader(dataset = test_data, batch_size = 2, shuffle = True)

# %%
test_loader

# %%
## Here we loop through our train_loader and see the images
## Looks good
fig = plt.figure(figsize = (15,6))
#model.to('cpu')
for ith_batch, sample_batched in enumerate(test_loader):
  
    X_test = sample_batched['image'].to('cuda')
    print(ith_batch, X_test.size())
    
    y_test = (model(X_test) + 0.5).int().float()
    
    
    
    for index in range(2):
        ax = fig.add_subplot(2, 2 , index + 1)  # subplot index starts from 1
        plt.imshow(im_converterX(X_test[index]))
        
        ax  = fig.add_subplot(2, 2, index + 3)
        plt.imshow(im_converterY(y_test[index]))
    break

# %%
def avg_dice_index(dataloader):
  
    dice = 0.0
    model.eval()
    with torch.no_grad():
    
        for ith_batch, sample_batched in enumerate(dataloader):
  
            X_train = sample_batched['image'].to('cuda')
            y_train = sample_batched['annotation'].to('cuda')
            
            y_predict = (model(X_train) + 0.5).int().float()
            
            dice += dice_index(y_predict, y_train)
            
            
            
    avg_dice = dice / len(dataloader)
    return avg_dice.item()

# %%
avg_dice_index(validation_loader)    #### Dice index of validation data

# %%
avg_dice_index(train_loader)        ### Dice index of training data

# %%
test_loader = DataLoader(dataset = test_data, batch_size = 1, shuffle = True) # to write image files

# %% [markdown]
# ## **Warning!!!**
# ### Your are about to write on drive

# %%
transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((540, 800)),
        transforms.ToTensor()
        ])
    
with torch.no_grad():
      #model.eval()
      for ith_batch , sample in enumerate(test_loader):
        X_test = sample['image'].to('cuda')
        y_pred = (model(X_test) + 0.5).int().float().cpu()
#         print(335-ith_batch)
        
        file_names = sample['f_name']
        pankaj = transform(y_pred[0])
        #singh = transform(y_pred[1])
        torchvision.utils.save_image(pankaj , os.path.join('segmented', file_names[0]))
        #torchvision.utils.save_image(singh, os.path.join('/content/drive/My Drive/HC18/test_set', file_names[1].replace('.png','_Annotation.png')))
      print("Segmentation files written")

# %%
def fit_ellipse(im):    
    imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
    ret,thresh = cv2.threshold(imgray,127,255,0)
    contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    contour_sizes = [len(contour) for contour in contours]
    ellipse = cv2.fitEllipse(contours[np.argmax(contour_sizes)])
    return ellipse

# %%
file_names = sorted([file for _,_,files in os.walk('segmented/') for file in files])

# %%
df_pixel_size = pd.read_csv('test_set_pixel_size.csv')
submission = {'filename': [], 'center_x_mm': [], 'center_y_mm': [], 'semi_axes_a_mm': [],
             'semi_axes_b_mm': [], 'angle_rad': [], 'Index': []}

file_names = sorted([file for _,_,files in os.walk('segmented/') for file in files])

for i, file_name in enumerate(file_names):
    im = cv2.imread('segmented/'+file_name)
   # file_name = file_name.replace('_Segmented', '')
    ellipse = fit_ellipse(im)
    im_mask = cv2.ellipse(np.zeros_like(im),ellipse,(255,255,255),-1)
    image_name = file_name.split('.')[0] + '_Annotation_fit.png'
    #cv2.imwrite('/content/drive/My Drive/HC18/test_set/'+image_name, im_mask)
    
    pixel_size = df_pixel_size.loc[df_pixel_size['filename'] == file_name, 'pixel size(mm)'].iloc[0]
    submission['filename'].extend([file_name])
    submission['Index'].extend([int(file_name.split('_')[0])])
    center_x,  center_y = ellipse[0]
    submission['center_x_mm'].extend([pixel_size*center_x])
    submission['center_y_mm'].extend([pixel_size*center_y])
    semi_axes_b, semi_axes_a = ellipse[1]
    if semi_axes_b > semi_axes_a:
        semi_axes_b = semi_axes_b + semi_axes_a
        semi_axes_a = semi_axes_b - semi_axes_a
        semi_axes_b -= semi_axes_a
    submission['semi_axes_a_mm'].extend([semi_axes_a*pixel_size/2])
    submission['semi_axes_b_mm'].extend([semi_axes_b*pixel_size/2])
    angle = ellipse[2]
    if angle < 90:
        angle += 90
    else:
        angle -= 90
    submission['angle_rad'].extend([np.deg2rad(angle)])
    
submission = pd.DataFrame(submission)
submission = submission[['filename', 'center_x_mm', 'center_y_mm', 
                         'semi_axes_a_mm', 'semi_axes_b_mm', 'angle_rad', 'Index']]    
submission = submission.sort_values(['Index'])
submission = submission.drop('Index', axis=1)
submission.to_csv("Att_UNET_150.csv", index=False)
print('Required .csv file generated')

# %%
q = pd.read_csv('Att_UNET_150.csv')  ## to check theck the generated csv

# %%
print('Length of csv file: ',len(q))

# %%
submission.head()
